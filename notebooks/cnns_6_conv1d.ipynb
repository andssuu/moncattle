# %% [markdown]
# <a href="https://colab.research.google.com/github/andssuu/moncattle/blob/master/notebooks/cnns_6_conv1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de bibliotecas

# %%
# !pip install --user tensorflow-addons
# restart runtime
import os
os.kill(os.getpid(), 9)
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 14.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
import pandas as pd
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#%matplotlib inline
plt.style.use('default')

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold, StratifiedShuffleSplit
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn import metrics

import tensorflow_addons as tfa

from imblearn.over_sampling import SMOTE

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Reshape, BatchNormalization, Dropout, LayerNormalization, Activation, Input, ReLU, Add, DepthwiseConv2D, Conv1D
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import *
from tensorflow.keras.activations import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow.keras import initializers
from tensorflow import Tensor
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.initializers import glorot_uniform

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
from collections import Counter

seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# # Leitura dos dados

# %%
# !git clone https://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@github.com/andssuu/moncattle.git
# Out:
# Cloning into 'moncattle'...
# remote: Enumerating objects: 1299, done.
# remote: Counting objects: 100% (1299/1299), done.
# remote: Compressing objects: 100% (1149/1149), done.
# remote: Total 1299 (delta 809), reused 167 (delta 65), pack-reused 0
# Receiving objects: 100% (1299/1299), 39.52 MiB | 5.42 MiB/s, done.
# Resolving deltas: 100% (809/809), done.

# %%
df = pd.read_csv("moncattle/data/dataset_6.csv", float_precision='high')
df_data = df.loc[:, ['acc_x', 'acc_y', 'acc_z', 'gir_x', 'gir_y', 'gir_z', 'mag_x', 'mag_y', 'mag_z', 'displacement_speed', 'label']]
df_data
# Out:
#        acc_x  acc_y  acc_z  gir_x  gir_y  gir_z  mag_x  mag_y  mag_z  \
# 0       1157   9002 -12840    243    195   -466   -460   1575   -205
# 1       1226   9986 -12546   -492   2209  -2189   -463   1585   -264
# 2        870   8224 -13117    590   -712    179   -527   1537   -248
# 3       2024   9428 -12521    212    662   -893   -515   1544   -226
# 4       1698   8163 -12980   1409     81    826   -501   1553   -281
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13083  -1776   3679  -8874  -1623  -1838  -7536    615   1048   -310
# 13084   3468  14178 -12207  -3882   7653   2397    299    -25  -1089
# 13085  -6229  11638 -11286   1982  -1144    359  -1047   1164    599
# 13086  -2267  12908  -7665   2458  -1275  -1757  -1498    940    223
# 13087   2152   7619  -7736  -2980   3678  -1357  -1650    788     43
#
#        displacement_speed           label
# 0                     0.0  EmPe-Ruminando
# 1                     0.0  EmPe-Ruminando
# 2                     0.0  EmPe-Ruminando
# 3                     0.0  EmPe-Ruminando
# 4                     0.0  EmPe-Ruminando
# ...                   ...             ...
# 13083                 0.0        Pastando
# 13084                 0.0        Pastando
# 13085                 0.0        Pastando
# 13086                 0.0        Pastando
# 13087                 0.0        Pastando
#
# [13088 rows x 11 columns]

# %% [markdown]
# # Bases de treino e teste

# %%
data_train, data_test=train_test_split(df_data, test_size=0.4, random_state=seed, shuffle=True, stratify=df_data.iloc[:, -1])

# %%
data_train
# Out:
#        acc_x  acc_y  acc_z  gir_x  gir_y  gir_z  mag_x  mag_y  mag_z  \
# 10828   2597   4332 -13120    165   -303    297   -859   -943   -901
# 2917   -4986   5327 -12556   3847  -2034   2658    233   1628   -808
# 4901    4584   6297 -13411    301   -365    235   -662    -71  -1327
# 7789    9484   7361  -9784    360    908    138    734    724    538
# 514   -10408   9109 -12190  -1080  -5284  -1800   1032   1336   -529
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2029    1272  12118  -9678   3302   3764   1273    707    122  -1399
# 7620    6900   8807 -10525    -30    903    103  -1074    205  -1036
# 3736    5875   9050 -11423    518   -200     52    315   2395    704
# 4184   -6550   3759 -14521   1561   -917  -1021    759   1522   -457
# 7760    8419   7450 -10174   -133    914    291    776    706    449
#
#        displacement_speed              label
# 10828                 0.0        EmPe-Parado
# 2917                  0.0           Pastando
# 4901                  0.0        EmPe-Parado
# 7789                  0.0  Deitado-Ruminando
# 514                   0.0           Pastando
# ...                   ...                ...
# 2029                  2.9            Andando
# 7620                  0.0        EmPe-Parado
# 3736                  0.0  Deitado-Ruminando
# 4184                  0.0           Pastando
# 7760                  0.0  Deitado-Ruminando
#
# [7852 rows x 11 columns]

# %%
data_test
# Out:
#        acc_x  acc_y  acc_z  gir_x  gir_y  gir_z  mag_x  mag_y  mag_z  \
# 10910  -7029   -925 -14211   5011  -4076   5066   -536  -1126   -783
# 12352   5342   8473  -9971    558    385   -185  -1404    229   -861
# 5426    8846   7370 -10938    166   -420    229    737   1590   -113
# 6095    7820   9234  -9384   -677    648    351   -833     63  -1189
# 8312    1230   5861 -13535  -2821   -444   1281    815   -629   -541
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2281  -10243   3254  -8512   -828    984  -2425    -96   1586   -686
# 9329    2721   7331 -12368    404    276     28   1027    231   -236
# 12090   5305   7863 -11373     80     98     56  -1363    654   -624
# 7193    6456  10383  -9458    207    972    180   -562   1504    452
# 4797  -12538  13197 -10616  -2211  -9130   3770    -67   1361    119
#
#        displacement_speed           label
# 10910                 0.0        Pastando
# 12352                 0.0     EmPe-Parado
# 5426                  0.0  Deitado-Parado
# 6095                  0.0     EmPe-Parado
# 8312                  2.5         Andando
# ...                   ...             ...
# 2281                  0.0        Pastando
# 9329                  0.0  EmPe-Ruminando
# 12090                 0.0     EmPe-Parado
# 7193                  0.0  Deitado-Parado
# 4797                  0.0        Pastando
#
# [5236 rows x 11 columns]

# %% [markdown]
# ## Quantidade total de amostras na base completa

# %%
df_data['label'].value_counts()
# Out:
# Pastando             5732
# Deitado-Ruminando    2034
# Deitado-Parado       1702
# EmPe-Parado          1559
# Andando              1229
# EmPe-Ruminando        832
# Name: label, dtype: int64

# %% [markdown]
# ## Quantidade total de amostras na base de treino

# %%
data_train['label'].value_counts()
# Out:
# Pastando             3439
# Deitado-Ruminando    1220
# Deitado-Parado       1021
# EmPe-Parado           935
# Andando               738
# EmPe-Ruminando        499
# Name: label, dtype: int64

# %% [markdown]
# ## Quantidade total de amostras na base de teste

# %%
data_test['label'].value_counts()
# Out:
# Pastando             2293
# Deitado-Ruminando     814
# Deitado-Parado        681
# EmPe-Parado           624
# Andando               491
# EmPe-Ruminando        333
# Name: label, dtype: int64

# %% [markdown]
# ## Formatação dos tensores

# %%
labels_map = {"Pastando": 0, "Deitado-Ruminando": 1, "Deitado-Parado": 2, "EmPe-Parado": 3, "Andando": 4, "EmPe-Ruminando": 5}
r_reshape, c_reshape = 1, 10

# normalizaçao dos dados da base original
_data_train, _data_test = data_train.copy(), data_test.copy()
_mean = _data_train.iloc[:, :-1].mean()
_std = _data_test.iloc[:, :-1].std()
_data_train.iloc[:, :-1] = (_data_train.iloc[:, :-1] - _mean) / _std
_data_test.iloc[:, :-1] = (_data_test.iloc[:, :-1] - _mean) / _std

# reshape data to fit model
t_data_train = _data_train.iloc[:, :-1].values.reshape(_data_train.shape[0], r_reshape, c_reshape, 1)
t_data_test = _data_test.iloc[:, :-1].values.reshape(_data_test.shape[0], r_reshape, c_reshape, 1)
print(t_data_train.shape, t_data_test.shape)

_labels_train = np.array(list(map(lambda x: labels_map[x], data_train.iloc[:, -1])))
c_labels_train = to_categorical(_labels_train)

_labels_test = np.array(list(map(lambda x: labels_map[x], data_test.iloc[:, -1])))
c_labels_test = to_categorical(_labels_test)
# Out:
# (7852, 1, 10, 1) (5236, 1, 10, 1)

# %% [markdown]
# ### Reamostragem BOOTSTRAP

# %%
# BOOTSTRAP
_data=data_train.copy()
count_class_0, count_class_1, count_class_2, count_class_3, count_class_4, count_class_5 = _data['label'].value_counts()
# print(count_class_0, count_class_1, count_class_2, count_class_3)

df_class_0=_data[_data['label']=='Pastando']
df_class_1=_data[_data['label']=='Deitado-Ruminando']
df_class_2=_data[_data['label']=='Deitado-Parado']
df_class_3=_data[_data['label']=='EmPe-Parado']
df_class_4=_data[_data['label']=='Andando']
df_class_5=_data[_data['label']=='EmPe-Ruminando']

df_class_1_under=df_class_1.sample(count_class_0, replace=True, random_state=seed)
df_class_2_under=df_class_2.sample(count_class_0, replace=True, random_state=seed)
df_class_3_under=df_class_3.sample(count_class_0, replace=True, random_state=seed)
df_class_4_under=df_class_4.sample(count_class_0, replace=True, random_state=seed)
df_class_5_under=df_class_5.sample(count_class_0, replace=True, random_state=seed)

data_balanced_bootstrap=pd.concat([df_class_0, df_class_1_under, df_class_2_under, df_class_3_under, df_class_4_under, df_class_5_under], axis=0).reset_index(drop=True)
_mean = data_balanced_bootstrap.iloc[:, :-1].mean()
_std = data_balanced_bootstrap.iloc[:, :-1].std()
data_balanced_bootstrap.iloc[:, :-1] = (data_balanced_bootstrap.iloc[:, :-1] - _mean) / _std
_shuffle_bootstrap=np.random.RandomState(seed=seed).permutation(len(data_balanced_bootstrap))
t_data_train_balanced_bootstrap=data_balanced_bootstrap.iloc[:, :-1].values[_shuffle_bootstrap].reshape(data_balanced_bootstrap.shape[0], r_reshape, c_reshape, 1)
labels_train_balanced_bootstrap=np.array(list(map(lambda x: labels_map[x], data_balanced_bootstrap.iloc[:, -1].values[_shuffle_bootstrap])))
c_labels_train_balanced_bootstrap=to_categorical(labels_train_balanced_bootstrap)

data_test_bootstrap = data_test.copy()
data_test_bootstrap.iloc[:, :-1] = (data_test_bootstrap.iloc[:, :-1] - _mean) / _std
t_data_test_bootstrap = data_test_bootstrap.iloc[:, :-1].values.reshape(data_test_bootstrap.shape[0], r_reshape, c_reshape, 1)

print(t_data_train_balanced_bootstrap.shape, c_labels_train_balanced_bootstrap.shape, t_data_test_bootstrap.shape, c_labels_test.shape)
# Out:
# (20634, 1, 10, 1) (20634, 6) (5236, 1, 10, 1) (5236, 6)

# %% [markdown]
# ### Reamostragem SMOTE

# %%
# SMOTE
_data = data_train.copy()
smote = SMOTE(sampling_strategy='not majority', random_state=seed, k_neighbors=5)
data_balanced_smote, _label_balanced_smote = smote.fit_resample(_data.iloc[:, :-1].values, _data.iloc[:, -1].values)
_shuffle_smote = np.random.RandomState(seed=seed).permutation(len(data_balanced_smote))

data_balanced_smote = pd.DataFrame(data_balanced_smote[_shuffle_smote], columns=data_train.columns[:-1])
_mean = data_balanced_smote.mean()
_std = data_balanced_smote.std()
data_balanced_smote = (data_balanced_smote- _mean) / _std

t_data_train_balanced_smote = data_balanced_smote.values.reshape(data_balanced_smote.shape[0], r_reshape, c_reshape, 1)
label_balanced_smote = np.array(list(map(lambda x: labels_map[x], _label_balanced_smote[_shuffle_smote])))
c_labels_train_balanced_smote = to_categorical(label_balanced_smote)

data_test_smote = data_test.copy()
data_test_smote.iloc[:, :-1] = (data_test_smote.iloc[:, :-1] - _mean) / _std
t_data_test_smote = data_test_smote.iloc[:, :-1].values.reshape(data_test_smote.shape[0], r_reshape, c_reshape, 1)

print(t_data_train_balanced_smote.shape, c_labels_train_balanced_smote.shape, t_data_test_smote.shape, c_labels_test.shape)
_l = pd.DataFrame(_label_balanced_smote, columns=['label'])
print(_l.value_counts())
_l.value_counts().plot(kind='bar', title='Reamostragem com classe majoritária')
# Out:
# (20634, 1, 10, 1) (20634, 6) (5236, 1, 10, 1) (5236, 6)
# label
# Andando              3439
# Deitado-Parado       3439
# Deitado-Ruminando    3439
# EmPe-Parado          3439
# EmPe-Ruminando       3439
# Pastando             3439
# dtype: int64

# %% [markdown]
# ### Visualização dos inputs

# %%
plt.style.use('default')
fig = plt.figure()
for i in range(6):
  plt.subplot(3, 2, i+1)
  plt.tight_layout()
  plt.imshow(t_data_train[i].reshape(r_reshape, c_reshape), cmap='gray', interpolation='none')
  plt.title("Rótulo: {}".format(list(labels_map.keys())[list(labels_map.values()).index(argmax(c_labels_train[i]))]))
  plt.xticks([])
  plt.yticks([])

# %%
plt.style.use('default')
plt.imshow(t_data_train[0].reshape(r_reshape, c_reshape), cmap='gray')
plt.title(list(labels_map.keys())[list(labels_map.values()).index(argmax(c_labels_train[0]))])
# Out:
# Text(0.5, 1.0, 'EmPe-Parado')

# %%
def visualize_input(window, ax): 
    window = window * 255
    img = np.uint8(window)
    ax.imshow(img, cmap='gray')
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            #ax.annotate(str(round(img[x][y],2)), xy=(y,x),
            ax.annotate(str(img[x][y]), xy=(y,x),
                        horizontalalignment='center',
                        verticalalignment='center',
                        color='white' if img[x][y]<thresh else 'black')
plt.style.use('default')
fig = plt.figure(figsize = (12,12))
plt.title('Label: {}'.format(list(labels_map.keys())[list(labels_map.values()).index(argmax(c_labels_train[0]))]))
ax=fig.add_subplot(111)
visualize_input(t_data_train[0].reshape(r_reshape, c_reshape), ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# # CNN (dissertação) - VETOR 1X10

# %%
epochs=100
batch_size=64
feature_dimensions=1024
input_shape=(1, 10, 1)
n_classes=6
labels_map = {"Pastando": 0, "Deitado-Ruminando": 1, "Deitado-Parado": 2, "EmPe-Parado": 3, "Andando": 4, "EmPe-Ruminando": 5}

def create_cnn():
    model = Sequential([
        #Flatten(input_shape=(1, 10, 1)),
        #Dense(feature_dimensions, activation='relu', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        #BatchNormalization(),
        #Reshape(input_shape, input_shape=(feature_dimensions,)),
        Conv1D(32, kernel_size=10, input_shape=input_shape, activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='same'),
        Dropout(0.2, seed=seed),
        Conv1D(96, kernel_size=5, activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='same'),
        Dropout(0.2, seed=seed),
        Flatten(),
        Dense(384, activation='relu', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Dropout(0.2, seed=seed),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Dropout(0.2, seed=seed),
        Dense(n_classes, activation='softmax', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed))
    ])
    model.reset_metrics()
    optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
    #optimizer=SGD(learning_rate=0.005, momentum=0.9, nesterov=False, name="SGD")
    #optimizer=RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07, centered=False, name="RMSprop")
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc', tfa.metrics.F1Score(num_classes=n_classes, name='f1_score', average='macro')])
    return model

def show_classification_report(results, n_splits):
    #print("Acurácia média: {:.4f}".format(np.mean(acc_per_fold)))
    #print("Desvio Padrão: {:}\n\n".format(np.std(acc_per_fold)))
    print('''\t\t        precision      recall     f1-score\n
        Pastando          {:.2f}        {:.2f}      {:.2f}
        Deitado-Ruminando {:.2f}        {:.2f}      {:.2f}
        Deitado-Parado    {:.2f}        {:.2f}      {:.2f}
        EmPe-Parado       {:.2f}        {:.2f}      {:.2f}
        Andando           {:.2f}        {:.2f}      {:.2f}
        EmPe-Ruminando    {:.2f}        {:.2f}      {:.2f}
        macro avg         {:.2f}        {:.2f}      {:.2f}
        accuracy          {:.2f}
    '''.format(
        100*results['Pastando']['precision']/n_splits, 100*results['Pastando']['recall']/n_splits, 100*results['Pastando']['f1-score']/n_splits,
        100*results['Deitado-Ruminando']['precision']/n_splits, 100*results['Deitado-Ruminando']['recall']/n_splits, 100*results['Deitado-Ruminando']['f1-score']/n_splits,
        100*results['Deitado-Parado']['precision']/n_splits, 100*results['Deitado-Parado']['recall']/n_splits, 100*results['Deitado-Parado']['f1-score']/n_splits,
        100*results['EmPe-Parado']['precision']/n_splits, 100*results['EmPe-Parado']['recall']/n_splits, 100*results['EmPe-Parado']['f1-score']/n_splits,
        100*results['Andando']['precision']/n_splits, 100*results['Andando']['recall']/n_splits, 100*results['Andando']['f1-score']/n_splits,
        100*results['EmPe-Ruminando']['precision']/n_splits, 100*results['EmPe-Ruminando']['recall']/n_splits, 100*results['EmPe-Ruminando']['f1-score']/n_splits,
        100*results['macro avg']['precision']/n_splits, 100*results['macro avg']['recall']/n_splits, 100*results['macro avg']['f1-score']/n_splits,
        100*results['accuracy']/n_splits
        )
    )

def update_report(results, new_results):
    for k in new_results.keys():
        if type(new_results[k]) is dict:
            for _k in results[k].keys():
                results[k][_k]+=new_results[k][_k]
        else:
            results[k] += new_results[k]
create_cnn().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1, 10, 32)         352
#
#  batch_normalization (BatchN  (None, 1, 10, 32)        128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 1, 5, 32)         0
#  )
#
#  dropout (Dropout)           (None, 1, 5, 32)          0
#
#  conv1d_1 (Conv1D)           (None, 1, 5, 96)          15456
#
#  batch_normalization_1 (Batc  (None, 1, 5, 96)         384
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 3, 96)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 1, 3, 96)          0
#
#  flatten (Flatten)           (None, 288)               0
#
#  dense (Dense)               (None, 384)               110976
#
#  batch_normalization_2 (Batc  (None, 384)              1536
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 384)               0
#
#  dense_1 (Dense)             (None, 128)               49280
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 179,398
# Trainable params: 178,118
# Non-trainable params: 1,280
# _________________________________________________________________

# %% [markdown]
# ## Base original

# %%
# ORIGINAL
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train, c_labels_train, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 99/99 [==============================] - 4s 17ms/step - loss: 43.7924 - acc: 0.6252 - f1_score: 0.5012 - val_loss: 16.0642 - val_acc: 0.4246 - val_f1_score: 0.0993
# Epoch 2/100
# 99/99 [==============================] - 1s 14ms/step - loss: 7.5492 - acc: 0.6929 - f1_score: 0.5632 - val_loss: 4.9315 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 3/100
# 99/99 [==============================] - 1s 12ms/step - loss: 3.5258 - acc: 0.6948 - f1_score: 0.5618 - val_loss: 3.5600 - val_acc: 0.4246 - val_f1_score: 0.0993
# Epoch 4/100
# 99/99 [==============================] - 1s 13ms/step - loss: 2.4157 - acc: 0.7101 - f1_score: 0.5576 - val_loss: 2.7057 - val_acc: 0.4411 - val_f1_score: 0.1433
# Epoch 5/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.9677 - acc: 0.7260 - f1_score: 0.5713 - val_loss: 2.0797 - val_acc: 0.6111 - val_f1_score: 0.3704
# Epoch 6/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.7304 - acc: 0.7292 - f1_score: 0.5639 - val_loss: 1.7400 - val_acc: 0.7161 - val_f1_score: 0.5386
# Epoch 7/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.6605 - acc: 0.7292 - f1_score: 0.5639 - val_loss: 1.6099 - val_acc: 0.7556 - val_f1_score: 0.6038
# Epoch 8/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.5808 - acc: 0.7424 - f1_score: 0.5811 - val_loss: 1.4500 - val_acc: 0.7658 - val_f1_score: 0.6168
# Epoch 9/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.5234 - acc: 0.7548 - f1_score: 0.5948 - val_loss: 1.4922 - val_acc: 0.7581 - val_f1_score: 0.5934
# Epoch 10/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.5054 - acc: 0.7507 - f1_score: 0.5890 - val_loss: 1.5404 - val_acc: 0.7428 - val_f1_score: 0.5793
# Epoch 11/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.5303 - acc: 0.7470 - f1_score: 0.5902 - val_loss: 1.4311 - val_acc: 0.7664 - val_f1_score: 0.6086
# Epoch 12/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.5348 - acc: 0.7489 - f1_score: 0.5873 - val_loss: 1.5317 - val_acc: 0.7524 - val_f1_score: 0.6022
# Epoch 13/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.5076 - acc: 0.7572 - f1_score: 0.6042 - val_loss: 1.3833 - val_acc: 0.7868 - val_f1_score: 0.6311
# Epoch 14/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.4474 - acc: 0.7550 - f1_score: 0.5967 - val_loss: 1.4531 - val_acc: 0.7823 - val_f1_score: 0.6303
# Epoch 15/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.4778 - acc: 0.7596 - f1_score: 0.6030 - val_loss: 1.4671 - val_acc: 0.7785 - val_f1_score: 0.6320
# Epoch 16/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.5294 - acc: 0.7574 - f1_score: 0.5998 - val_loss: 1.3921 - val_acc: 0.7817 - val_f1_score: 0.6322
# Epoch 17/100
# 99/99 [==============================] - 2s 18ms/step - loss: 1.4620 - acc: 0.7609 - f1_score: 0.6086 - val_loss: 1.4041 - val_acc: 0.7715 - val_f1_score: 0.6081
# Epoch 18/100
# 99/99 [==============================] - 2s 16ms/step - loss: 1.4077 - acc: 0.7720 - f1_score: 0.6268 - val_loss: 1.3989 - val_acc: 0.7734 - val_f1_score: 0.6122
# Epoch 19/100
# 99/99 [==============================] - 1s 14ms/step - loss: 1.4221 - acc: 0.7717 - f1_score: 0.6363 - val_loss: 1.3665 - val_acc: 0.7950 - val_f1_score: 0.6453
# Epoch 20/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.4159 - acc: 0.7734 - f1_score: 0.6405 - val_loss: 1.3675 - val_acc: 0.7919 - val_f1_score: 0.6766
# Epoch 21/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.4443 - acc: 0.7699 - f1_score: 0.6525 - val_loss: 1.3379 - val_acc: 0.7931 - val_f1_score: 0.6853
# Epoch 22/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.4757 - acc: 0.7706 - f1_score: 0.6591 - val_loss: 1.3251 - val_acc: 0.8313 - val_f1_score: 0.7627
# Epoch 23/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.3906 - acc: 0.7798 - f1_score: 0.6660 - val_loss: 1.3445 - val_acc: 0.8020 - val_f1_score: 0.6615
# Epoch 24/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3767 - acc: 0.7832 - f1_score: 0.6698 - val_loss: 1.3180 - val_acc: 0.8294 - val_f1_score: 0.7499
# Epoch 25/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.4376 - acc: 0.7793 - f1_score: 0.6682 - val_loss: 1.2743 - val_acc: 0.8065 - val_f1_score: 0.6777
# Epoch 26/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3661 - acc: 0.7819 - f1_score: 0.6657 - val_loss: 1.3329 - val_acc: 0.8141 - val_f1_score: 0.7041
# Epoch 27/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.3469 - acc: 0.7847 - f1_score: 0.6807 - val_loss: 1.3259 - val_acc: 0.8071 - val_f1_score: 0.6819
# Epoch 28/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3606 - acc: 0.7801 - f1_score: 0.6687 - val_loss: 1.2864 - val_acc: 0.7976 - val_f1_score: 0.6689
# Epoch 29/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3479 - acc: 0.7798 - f1_score: 0.6640 - val_loss: 1.2605 - val_acc: 0.7899 - val_f1_score: 0.6382
# Epoch 30/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2922 - acc: 0.7886 - f1_score: 0.6743 - val_loss: 1.2027 - val_acc: 0.8109 - val_f1_score: 0.7093
# Epoch 31/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3231 - acc: 0.7894 - f1_score: 0.6827 - val_loss: 1.2876 - val_acc: 0.8199 - val_f1_score: 0.7449
# Epoch 32/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3697 - acc: 0.7905 - f1_score: 0.6872 - val_loss: 1.2646 - val_acc: 0.7931 - val_f1_score: 0.6727
# Epoch 33/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2835 - acc: 0.7881 - f1_score: 0.6850 - val_loss: 1.3035 - val_acc: 0.7957 - val_f1_score: 0.7050
# Epoch 34/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3157 - acc: 0.7940 - f1_score: 0.6821 - val_loss: 1.2080 - val_acc: 0.8250 - val_f1_score: 0.7407
# Epoch 35/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2832 - acc: 0.7921 - f1_score: 0.6903 - val_loss: 1.2832 - val_acc: 0.7658 - val_f1_score: 0.6318
# Epoch 36/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.2882 - acc: 0.7913 - f1_score: 0.6808 - val_loss: 1.2147 - val_acc: 0.8205 - val_f1_score: 0.7474
# Epoch 37/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2804 - acc: 0.7968 - f1_score: 0.6967 - val_loss: 1.2531 - val_acc: 0.7861 - val_f1_score: 0.6356
# Epoch 38/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2769 - acc: 0.7879 - f1_score: 0.6779 - val_loss: 1.1986 - val_acc: 0.8027 - val_f1_score: 0.6640
# Epoch 39/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2432 - acc: 0.7978 - f1_score: 0.6961 - val_loss: 1.2150 - val_acc: 0.8383 - val_f1_score: 0.7789
# Epoch 40/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2641 - acc: 0.7981 - f1_score: 0.6956 - val_loss: 1.1731 - val_acc: 0.8230 - val_f1_score: 0.7435
# Epoch 41/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.2194 - acc: 0.7962 - f1_score: 0.6957 - val_loss: 1.2273 - val_acc: 0.8109 - val_f1_score: 0.7164
# Epoch 42/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.2421 - acc: 0.7997 - f1_score: 0.7007 - val_loss: 1.1339 - val_acc: 0.8307 - val_f1_score: 0.7600
# Epoch 43/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2187 - acc: 0.8043 - f1_score: 0.7134 - val_loss: 1.1119 - val_acc: 0.8148 - val_f1_score: 0.6934
# Epoch 44/100
# 99/99 [==============================] - 2s 15ms/step - loss: 1.2208 - acc: 0.8008 - f1_score: 0.7014 - val_loss: 1.1597 - val_acc: 0.8116 - val_f1_score: 0.6866
# Epoch 45/100
# 99/99 [==============================] - 2s 24ms/step - loss: 1.2374 - acc: 0.7983 - f1_score: 0.6973 - val_loss: 1.2108 - val_acc: 0.7899 - val_f1_score: 0.6774
# Epoch 46/100
# 99/99 [==============================] - 1s 15ms/step - loss: 1.2324 - acc: 0.7962 - f1_score: 0.6976 - val_loss: 1.1124 - val_acc: 0.8390 - val_f1_score: 0.7790
# Epoch 47/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.1922 - acc: 0.7991 - f1_score: 0.7067 - val_loss: 1.2127 - val_acc: 0.7817 - val_f1_score: 0.6230
# Epoch 48/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1404 - acc: 0.8118 - f1_score: 0.7179 - val_loss: 1.2612 - val_acc: 0.7791 - val_f1_score: 0.6876
# Epoch 49/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3274 - acc: 0.8023 - f1_score: 0.7146 - val_loss: 1.1973 - val_acc: 0.8052 - val_f1_score: 0.6861
# Epoch 50/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.2166 - acc: 0.8013 - f1_score: 0.7071 - val_loss: 1.1180 - val_acc: 0.8358 - val_f1_score: 0.7726
# Epoch 51/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2192 - acc: 0.8040 - f1_score: 0.7125 - val_loss: 1.1425 - val_acc: 0.8326 - val_f1_score: 0.7611
# Epoch 52/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.2322 - acc: 0.8070 - f1_score: 0.7221 - val_loss: 1.1213 - val_acc: 0.8281 - val_f1_score: 0.7630
# Epoch 53/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.1567 - acc: 0.8058 - f1_score: 0.7156 - val_loss: 1.0704 - val_acc: 0.8269 - val_f1_score: 0.7540
# Epoch 54/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1460 - acc: 0.8088 - f1_score: 0.7220 - val_loss: 1.1338 - val_acc: 0.8320 - val_f1_score: 0.7600
# Epoch 55/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.1735 - acc: 0.8102 - f1_score: 0.7226 - val_loss: 1.1077 - val_acc: 0.8154 - val_f1_score: 0.6990
# Epoch 56/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.1670 - acc: 0.8056 - f1_score: 0.7169 - val_loss: 1.1146 - val_acc: 0.8109 - val_f1_score: 0.6828
# Epoch 57/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1329 - acc: 0.8153 - f1_score: 0.7251 - val_loss: 1.0351 - val_acc: 0.8377 - val_f1_score: 0.7763
# Epoch 58/100
# 99/99 [==============================] - 1s 14ms/step - loss: 1.1253 - acc: 0.8134 - f1_score: 0.7285 - val_loss: 1.0462 - val_acc: 0.8434 - val_f1_score: 0.7870
# Epoch 59/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1142 - acc: 0.8077 - f1_score: 0.7220 - val_loss: 1.0463 - val_acc: 0.8313 - val_f1_score: 0.7531
# Epoch 60/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.1113 - acc: 0.8094 - f1_score: 0.7170 - val_loss: 1.1089 - val_acc: 0.8358 - val_f1_score: 0.7628
# Epoch 61/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1762 - acc: 0.8121 - f1_score: 0.7290 - val_loss: 1.1088 - val_acc: 0.8320 - val_f1_score: 0.7661
# Epoch 62/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1559 - acc: 0.8174 - f1_score: 0.7339 - val_loss: 1.2183 - val_acc: 0.8154 - val_f1_score: 0.7507
# Epoch 63/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.3678 - acc: 0.8046 - f1_score: 0.7101 - val_loss: 1.1669 - val_acc: 0.8339 - val_f1_score: 0.7731
# Epoch 64/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1854 - acc: 0.8129 - f1_score: 0.7288 - val_loss: 1.1061 - val_acc: 0.8447 - val_f1_score: 0.7877
# Epoch 65/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1310 - acc: 0.8102 - f1_score: 0.7248 - val_loss: 1.0616 - val_acc: 0.8472 - val_f1_score: 0.7906
# Epoch 66/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1309 - acc: 0.8091 - f1_score: 0.7243 - val_loss: 1.0290 - val_acc: 0.8396 - val_f1_score: 0.7758
# Epoch 67/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1191 - acc: 0.8134 - f1_score: 0.7301 - val_loss: 1.0630 - val_acc: 0.8440 - val_f1_score: 0.7898
# Epoch 68/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0839 - acc: 0.8244 - f1_score: 0.7446 - val_loss: 1.0269 - val_acc: 0.8409 - val_f1_score: 0.7832
# Epoch 69/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1222 - acc: 0.8185 - f1_score: 0.7375 - val_loss: 1.0588 - val_acc: 0.8281 - val_f1_score: 0.7218
# Epoch 70/100
# 99/99 [==============================] - 1s 14ms/step - loss: 1.0946 - acc: 0.8172 - f1_score: 0.7361 - val_loss: 1.0272 - val_acc: 0.8498 - val_f1_score: 0.7941
# Epoch 71/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0529 - acc: 0.8185 - f1_score: 0.7350 - val_loss: 1.0386 - val_acc: 0.8358 - val_f1_score: 0.7828
# Epoch 72/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.1483 - acc: 0.8104 - f1_score: 0.7182 - val_loss: 1.0651 - val_acc: 0.8370 - val_f1_score: 0.7743
# Epoch 73/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0562 - acc: 0.8174 - f1_score: 0.7290 - val_loss: 1.0251 - val_acc: 0.8326 - val_f1_score: 0.7572
# Epoch 74/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0359 - acc: 0.8210 - f1_score: 0.7399 - val_loss: 1.0027 - val_acc: 0.8326 - val_f1_score: 0.7709
# Epoch 75/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0601 - acc: 0.8110 - f1_score: 0.7223 - val_loss: 1.0057 - val_acc: 0.8511 - val_f1_score: 0.8005
# Epoch 76/100
# 99/99 [==============================] - 1s 14ms/step - loss: 1.0581 - acc: 0.8134 - f1_score: 0.7339 - val_loss: 1.0122 - val_acc: 0.8504 - val_f1_score: 0.8007
# Epoch 77/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1209 - acc: 0.8156 - f1_score: 0.7315 - val_loss: 0.9973 - val_acc: 0.8294 - val_f1_score: 0.7363
# Epoch 78/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0193 - acc: 0.8190 - f1_score: 0.7296 - val_loss: 0.9976 - val_acc: 0.8256 - val_f1_score: 0.7294
# Epoch 79/100
# 99/99 [==============================] - 1s 14ms/step - loss: 1.1373 - acc: 0.8145 - f1_score: 0.7277 - val_loss: 1.0839 - val_acc: 0.8288 - val_f1_score: 0.7463
# Epoch 80/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.1026 - acc: 0.8226 - f1_score: 0.7429 - val_loss: 0.9716 - val_acc: 0.8536 - val_f1_score: 0.8015
# Epoch 81/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0471 - acc: 0.8198 - f1_score: 0.7350 - val_loss: 0.9441 - val_acc: 0.8517 - val_f1_score: 0.7996
# Epoch 82/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0315 - acc: 0.8228 - f1_score: 0.7412 - val_loss: 0.9618 - val_acc: 0.8358 - val_f1_score: 0.7740
# Epoch 83/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0532 - acc: 0.8161 - f1_score: 0.7289 - val_loss: 0.9850 - val_acc: 0.8243 - val_f1_score: 0.7342
# Epoch 84/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0597 - acc: 0.8147 - f1_score: 0.7326 - val_loss: 1.0566 - val_acc: 0.8364 - val_f1_score: 0.7766
# Epoch 85/100
# 99/99 [==============================] - 1s 14ms/step - loss: 1.1006 - acc: 0.8204 - f1_score: 0.7367 - val_loss: 1.0191 - val_acc: 0.8440 - val_f1_score: 0.7899
# Epoch 86/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0616 - acc: 0.8247 - f1_score: 0.7440 - val_loss: 0.9920 - val_acc: 0.8358 - val_f1_score: 0.7760
# Epoch 87/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0295 - acc: 0.8285 - f1_score: 0.7517 - val_loss: 1.0412 - val_acc: 0.8262 - val_f1_score: 0.7487
# Epoch 88/100
# 99/99 [==============================] - 1s 14ms/step - loss: 0.9778 - acc: 0.8290 - f1_score: 0.7465 - val_loss: 0.9558 - val_acc: 0.8606 - val_f1_score: 0.8118
# Epoch 89/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0043 - acc: 0.8209 - f1_score: 0.7380 - val_loss: 0.9405 - val_acc: 0.8421 - val_f1_score: 0.7782
# Epoch 90/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9969 - acc: 0.8179 - f1_score: 0.7307 - val_loss: 0.9809 - val_acc: 0.8288 - val_f1_score: 0.7515
# Epoch 91/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0350 - acc: 0.8239 - f1_score: 0.7437 - val_loss: 0.9490 - val_acc: 0.8619 - val_f1_score: 0.8129
# Epoch 92/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9808 - acc: 0.8210 - f1_score: 0.7366 - val_loss: 0.9643 - val_acc: 0.8421 - val_f1_score: 0.7873
# Epoch 93/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9841 - acc: 0.8246 - f1_score: 0.7392 - val_loss: 0.9214 - val_acc: 0.8479 - val_f1_score: 0.7961
# Epoch 94/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9523 - acc: 0.8273 - f1_score: 0.7515 - val_loss: 1.0128 - val_acc: 0.8421 - val_f1_score: 0.7820
# Epoch 95/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.0230 - acc: 0.8311 - f1_score: 0.7566 - val_loss: 0.9569 - val_acc: 0.8377 - val_f1_score: 0.7522
# Epoch 96/100
# 99/99 [==============================] - 1s 12ms/step - loss: 1.0102 - acc: 0.8238 - f1_score: 0.7451 - val_loss: 0.9589 - val_acc: 0.8498 - val_f1_score: 0.7912
# Epoch 97/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9933 - acc: 0.8223 - f1_score: 0.7400 - val_loss: 0.9573 - val_acc: 0.8428 - val_f1_score: 0.7764
# Epoch 98/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9858 - acc: 0.8226 - f1_score: 0.7407 - val_loss: 0.9288 - val_acc: 0.8383 - val_f1_score: 0.7726
# Epoch 99/100
# 99/99 [==============================] - 1s 13ms/step - loss: 1.0202 - acc: 0.8266 - f1_score: 0.7473 - val_loss: 0.9338 - val_acc: 0.8370 - val_f1_score: 0.7445
# Epoch 100/100
# 99/99 [==============================] - 1s 13ms/step - loss: 0.9767 - acc: 0.8258 - f1_score: 0.7489 - val_loss: 0.9323 - val_acc: 0.8530 - val_f1_score: 0.8007
# 164/164 [==============================] - 1s 3ms/step - loss: 0.9754 - acc: 0.8478 - f1_score: 0.7805
# 164/164 [==============================] - 1s 2ms/step
# Score: loss of 0.9754380583763123; acc of 84.77845788002014%

# %% [markdown]
# ### Matrix de confusão

# %%
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2207                  4               4           34
# Deitado-Ruminando         5                686              78           36
# Deitado-Parado           17                158             439           60
# EmPe-Parado              32                 37              11          481
# Andando                  28                  0               1            3
# EmPe-Ruminando           10                 26               0          128
#
#                    Andando  EmPe-Ruminando
# Pastando                43               1
# Deitado-Ruminando        0               9
# Deitado-Parado           0               7
# EmPe-Parado              3              60
# Andando                459               0
# EmPe-Ruminando           2             167

# %%
plt.style.use('default')
fig, ax = plt.subplots(figsize=(15, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels_map)
disp.plot(ax=ax, cmap="Reds", values_format='')

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9600    0.9625    0.9612      2293
# Deitado-Ruminando     0.7530    0.8428    0.7954       814
#    Deitado-Parado     0.8236    0.6446    0.7232       681
#       EmPe-Parado     0.6482    0.7708    0.7042       624
#           Andando     0.9053    0.9348    0.9198       491
#    EmPe-Ruminando     0.6844    0.5015    0.5789       333
#
#          accuracy                         0.8478      5236
#         macro avg     0.7958    0.7762    0.7805      5236
#      weighted avg     0.8503    0.8478    0.8457      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# ## Base com Bootstrap

# %%
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train_balanced_bootstrap, c_labels_train_balanced_bootstrap, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test_bootstrap, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test_bootstrap, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test_bootstrap, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 258/258 [==============================] - 5s 14ms/step - loss: 20.4076 - acc: 0.5894 - f1_score: 0.5869 - val_loss: 4.2783 - val_acc: 0.2522 - val_f1_score: 0.1690
# Epoch 2/100
# 258/258 [==============================] - 3s 12ms/step - loss: 2.4103 - acc: 0.6689 - f1_score: 0.6660 - val_loss: 2.1329 - val_acc: 0.7155 - val_f1_score: 0.7001
# Epoch 3/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.7822 - acc: 0.6957 - f1_score: 0.6930 - val_loss: 1.5500 - val_acc: 0.7536 - val_f1_score: 0.7546
# Epoch 4/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.6329 - acc: 0.7174 - f1_score: 0.7156 - val_loss: 1.5092 - val_acc: 0.7688 - val_f1_score: 0.7613
# Epoch 5/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.5811 - acc: 0.7213 - f1_score: 0.7198 - val_loss: 1.4186 - val_acc: 0.7817 - val_f1_score: 0.7804
# Epoch 6/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.5486 - acc: 0.7278 - f1_score: 0.7263 - val_loss: 1.4446 - val_acc: 0.7877 - val_f1_score: 0.7824
# Epoch 7/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.4993 - acc: 0.7418 - f1_score: 0.7409 - val_loss: 1.3155 - val_acc: 0.7972 - val_f1_score: 0.7970
# Epoch 8/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.4719 - acc: 0.7451 - f1_score: 0.7442 - val_loss: 1.3629 - val_acc: 0.8030 - val_f1_score: 0.8019
# Epoch 9/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.4613 - acc: 0.7432 - f1_score: 0.7422 - val_loss: 1.3120 - val_acc: 0.8163 - val_f1_score: 0.8154
# Epoch 10/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.4365 - acc: 0.7564 - f1_score: 0.7558 - val_loss: 1.3290 - val_acc: 0.8032 - val_f1_score: 0.8005
# Epoch 11/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.4158 - acc: 0.7600 - f1_score: 0.7590 - val_loss: 1.2648 - val_acc: 0.7948 - val_f1_score: 0.7929
# Epoch 12/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3814 - acc: 0.7674 - f1_score: 0.7665 - val_loss: 1.2933 - val_acc: 0.7945 - val_f1_score: 0.7902
# Epoch 13/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3787 - acc: 0.7639 - f1_score: 0.7632 - val_loss: 1.2321 - val_acc: 0.8212 - val_f1_score: 0.8209
# Epoch 14/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.3675 - acc: 0.7732 - f1_score: 0.7725 - val_loss: 1.2629 - val_acc: 0.8214 - val_f1_score: 0.8189
# Epoch 15/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3377 - acc: 0.7772 - f1_score: 0.7764 - val_loss: 1.1989 - val_acc: 0.8156 - val_f1_score: 0.8109
# Epoch 16/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3361 - acc: 0.7715 - f1_score: 0.7709 - val_loss: 1.2562 - val_acc: 0.8185 - val_f1_score: 0.8178
# Epoch 17/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3650 - acc: 0.7744 - f1_score: 0.7739 - val_loss: 1.1927 - val_acc: 0.8158 - val_f1_score: 0.8124
# Epoch 18/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2963 - acc: 0.7802 - f1_score: 0.7792 - val_loss: 1.2173 - val_acc: 0.8226 - val_f1_score: 0.8219
# Epoch 19/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2681 - acc: 0.7812 - f1_score: 0.7806 - val_loss: 1.1600 - val_acc: 0.8362 - val_f1_score: 0.8366
# Epoch 20/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2759 - acc: 0.7846 - f1_score: 0.7842 - val_loss: 1.1428 - val_acc: 0.8442 - val_f1_score: 0.8437
# Epoch 21/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.2418 - acc: 0.7904 - f1_score: 0.7898 - val_loss: 1.0768 - val_acc: 0.8253 - val_f1_score: 0.8251
# Epoch 22/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.2080 - acc: 0.7902 - f1_score: 0.7898 - val_loss: 1.0978 - val_acc: 0.8381 - val_f1_score: 0.8384
# Epoch 23/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1931 - acc: 0.7883 - f1_score: 0.7877 - val_loss: 1.0537 - val_acc: 0.8435 - val_f1_score: 0.8426
# Epoch 24/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.2246 - acc: 0.7881 - f1_score: 0.7877 - val_loss: 1.0974 - val_acc: 0.8459 - val_f1_score: 0.8456
# Epoch 25/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1776 - acc: 0.7952 - f1_score: 0.7947 - val_loss: 1.0596 - val_acc: 0.8292 - val_f1_score: 0.8277
# Epoch 26/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1696 - acc: 0.7915 - f1_score: 0.7910 - val_loss: 1.0685 - val_acc: 0.8246 - val_f1_score: 0.8245
# Epoch 27/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1719 - acc: 0.7912 - f1_score: 0.7905 - val_loss: 1.0423 - val_acc: 0.8367 - val_f1_score: 0.8363
# Epoch 28/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1842 - acc: 0.7963 - f1_score: 0.7956 - val_loss: 1.0176 - val_acc: 0.8401 - val_f1_score: 0.8387
# Epoch 29/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1689 - acc: 0.7997 - f1_score: 0.7994 - val_loss: 1.0637 - val_acc: 0.8435 - val_f1_score: 0.8428
# Epoch 30/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1594 - acc: 0.8010 - f1_score: 0.8005 - val_loss: 1.0471 - val_acc: 0.8493 - val_f1_score: 0.8487
# Epoch 31/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.1547 - acc: 0.7973 - f1_score: 0.7968 - val_loss: 0.9885 - val_acc: 0.8597 - val_f1_score: 0.8599
# Epoch 32/100
# 258/258 [==============================] - 3s 10ms/step - loss: 1.1286 - acc: 0.7991 - f1_score: 0.7987 - val_loss: 1.0006 - val_acc: 0.8476 - val_f1_score: 0.8465
# Epoch 33/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.1173 - acc: 0.8041 - f1_score: 0.8036 - val_loss: 1.0164 - val_acc: 0.8573 - val_f1_score: 0.8574
# Epoch 34/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.1564 - acc: 0.7994 - f1_score: 0.7990 - val_loss: 1.0619 - val_acc: 0.8510 - val_f1_score: 0.8510
# Epoch 35/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.1414 - acc: 0.8061 - f1_score: 0.8057 - val_loss: 0.9817 - val_acc: 0.8536 - val_f1_score: 0.8519
# Epoch 36/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.1394 - acc: 0.8043 - f1_score: 0.8037 - val_loss: 0.9983 - val_acc: 0.8515 - val_f1_score: 0.8504
# Epoch 37/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1250 - acc: 0.8040 - f1_score: 0.8036 - val_loss: 0.9824 - val_acc: 0.8512 - val_f1_score: 0.8509
# Epoch 38/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0885 - acc: 0.8072 - f1_score: 0.8069 - val_loss: 0.9605 - val_acc: 0.8406 - val_f1_score: 0.8407
# Epoch 39/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1095 - acc: 0.8120 - f1_score: 0.8117 - val_loss: 0.9692 - val_acc: 0.8507 - val_f1_score: 0.8494
# Epoch 40/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0983 - acc: 0.8032 - f1_score: 0.8027 - val_loss: 1.0499 - val_acc: 0.8202 - val_f1_score: 0.8161
# Epoch 41/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1075 - acc: 0.8145 - f1_score: 0.8142 - val_loss: 0.9814 - val_acc: 0.8675 - val_f1_score: 0.8658
# Epoch 42/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1008 - acc: 0.8125 - f1_score: 0.8121 - val_loss: 0.9866 - val_acc: 0.8626 - val_f1_score: 0.8625
# Epoch 43/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0989 - acc: 0.8095 - f1_score: 0.8089 - val_loss: 1.0179 - val_acc: 0.8597 - val_f1_score: 0.8577
# Epoch 44/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1339 - acc: 0.8094 - f1_score: 0.8092 - val_loss: 0.9953 - val_acc: 0.8612 - val_f1_score: 0.8611
# Epoch 45/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0952 - acc: 0.8115 - f1_score: 0.8112 - val_loss: 0.9849 - val_acc: 0.8570 - val_f1_score: 0.8564
# Epoch 46/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0737 - acc: 0.8110 - f1_score: 0.8105 - val_loss: 0.9596 - val_acc: 0.8595 - val_f1_score: 0.8592
# Epoch 47/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0830 - acc: 0.8124 - f1_score: 0.8119 - val_loss: 0.9509 - val_acc: 0.8624 - val_f1_score: 0.8608
# Epoch 48/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0514 - acc: 0.8128 - f1_score: 0.8125 - val_loss: 0.9004 - val_acc: 0.8665 - val_f1_score: 0.8660
# Epoch 49/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0584 - acc: 0.8156 - f1_score: 0.8151 - val_loss: 0.9544 - val_acc: 0.8587 - val_f1_score: 0.8586
# Epoch 50/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0695 - acc: 0.8125 - f1_score: 0.8121 - val_loss: 0.9565 - val_acc: 0.8621 - val_f1_score: 0.8620
# Epoch 51/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0844 - acc: 0.8132 - f1_score: 0.8128 - val_loss: 0.9957 - val_acc: 0.8629 - val_f1_score: 0.8625
# Epoch 52/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0495 - acc: 0.8144 - f1_score: 0.8141 - val_loss: 0.9070 - val_acc: 0.8713 - val_f1_score: 0.8709
# Epoch 53/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0317 - acc: 0.8161 - f1_score: 0.8159 - val_loss: 0.9012 - val_acc: 0.8725 - val_f1_score: 0.8724
# Epoch 54/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0387 - acc: 0.8187 - f1_score: 0.8184 - val_loss: 0.9253 - val_acc: 0.8471 - val_f1_score: 0.8444
# Epoch 55/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0702 - acc: 0.8142 - f1_score: 0.8136 - val_loss: 0.8901 - val_acc: 0.8721 - val_f1_score: 0.8714
# Epoch 56/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0402 - acc: 0.8195 - f1_score: 0.8192 - val_loss: 0.9635 - val_acc: 0.8551 - val_f1_score: 0.8536
# Epoch 57/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0309 - acc: 0.8161 - f1_score: 0.8157 - val_loss: 0.9290 - val_acc: 0.8653 - val_f1_score: 0.8641
# Epoch 58/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0054 - acc: 0.8240 - f1_score: 0.8237 - val_loss: 0.8890 - val_acc: 0.8675 - val_f1_score: 0.8675
# Epoch 59/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0139 - acc: 0.8191 - f1_score: 0.8188 - val_loss: 0.8879 - val_acc: 0.8764 - val_f1_score: 0.8762
# Epoch 60/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0365 - acc: 0.8213 - f1_score: 0.8209 - val_loss: 0.9062 - val_acc: 0.8687 - val_f1_score: 0.8687
# Epoch 61/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0360 - acc: 0.8223 - f1_score: 0.8220 - val_loss: 0.9283 - val_acc: 0.8612 - val_f1_score: 0.8605
# Epoch 62/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0325 - acc: 0.8212 - f1_score: 0.8209 - val_loss: 0.9372 - val_acc: 0.8575 - val_f1_score: 0.8577
# Epoch 63/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0374 - acc: 0.8208 - f1_score: 0.8205 - val_loss: 0.9246 - val_acc: 0.8716 - val_f1_score: 0.8704
# Epoch 64/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0244 - acc: 0.8210 - f1_score: 0.8205 - val_loss: 0.9235 - val_acc: 0.8662 - val_f1_score: 0.8665
# Epoch 65/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0169 - acc: 0.8213 - f1_score: 0.8210 - val_loss: 0.8785 - val_acc: 0.8813 - val_f1_score: 0.8810
# Epoch 66/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0256 - acc: 0.8219 - f1_score: 0.8216 - val_loss: 0.9353 - val_acc: 0.8694 - val_f1_score: 0.8681
# Epoch 67/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0358 - acc: 0.8220 - f1_score: 0.8215 - val_loss: 0.8847 - val_acc: 0.8682 - val_f1_score: 0.8678
# Epoch 68/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9990 - acc: 0.8254 - f1_score: 0.8251 - val_loss: 0.8987 - val_acc: 0.8650 - val_f1_score: 0.8642
# Epoch 69/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0205 - acc: 0.8196 - f1_score: 0.8194 - val_loss: 0.9055 - val_acc: 0.8793 - val_f1_score: 0.8788
# Epoch 70/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0117 - acc: 0.8231 - f1_score: 0.8228 - val_loss: 0.9028 - val_acc: 0.8723 - val_f1_score: 0.8722
# Epoch 71/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0043 - acc: 0.8263 - f1_score: 0.8260 - val_loss: 0.9138 - val_acc: 0.8556 - val_f1_score: 0.8540
# Epoch 72/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0066 - acc: 0.8298 - f1_score: 0.8295 - val_loss: 0.9193 - val_acc: 0.8461 - val_f1_score: 0.8426
# Epoch 73/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0072 - acc: 0.8248 - f1_score: 0.8244 - val_loss: 0.8641 - val_acc: 0.8788 - val_f1_score: 0.8780
# Epoch 74/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0086 - acc: 0.8255 - f1_score: 0.8251 - val_loss: 0.8942 - val_acc: 0.8670 - val_f1_score: 0.8661
# Epoch 75/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0070 - acc: 0.8281 - f1_score: 0.8280 - val_loss: 0.8718 - val_acc: 0.8818 - val_f1_score: 0.8813
# Epoch 76/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0108 - acc: 0.8307 - f1_score: 0.8305 - val_loss: 0.8877 - val_acc: 0.8786 - val_f1_score: 0.8784
# Epoch 77/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0075 - acc: 0.8266 - f1_score: 0.8263 - val_loss: 0.8988 - val_acc: 0.8616 - val_f1_score: 0.8593
# Epoch 78/100
# 258/258 [==============================] - 3s 11ms/step - loss: 0.9969 - acc: 0.8298 - f1_score: 0.8295 - val_loss: 0.8508 - val_acc: 0.8779 - val_f1_score: 0.8768
# Epoch 79/100
# 258/258 [==============================] - 3s 11ms/step - loss: 1.0082 - acc: 0.8250 - f1_score: 0.8248 - val_loss: 0.8699 - val_acc: 0.8810 - val_f1_score: 0.8805
# Epoch 80/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0160 - acc: 0.8219 - f1_score: 0.8218 - val_loss: 0.9077 - val_acc: 0.8631 - val_f1_score: 0.8630
# Epoch 81/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9643 - acc: 0.8313 - f1_score: 0.8310 - val_loss: 0.8505 - val_acc: 0.8730 - val_f1_score: 0.8727
# Epoch 82/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9757 - acc: 0.8267 - f1_score: 0.8265 - val_loss: 0.8595 - val_acc: 0.8818 - val_f1_score: 0.8820
# Epoch 83/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9647 - acc: 0.8280 - f1_score: 0.8277 - val_loss: 0.8614 - val_acc: 0.8711 - val_f1_score: 0.8699
# Epoch 84/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9860 - acc: 0.8290 - f1_score: 0.8289 - val_loss: 0.8433 - val_acc: 0.8885 - val_f1_score: 0.8883
# Epoch 85/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9802 - acc: 0.8278 - f1_score: 0.8275 - val_loss: 0.8574 - val_acc: 0.8786 - val_f1_score: 0.8782
# Epoch 86/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9738 - acc: 0.8270 - f1_score: 0.8269 - val_loss: 0.8957 - val_acc: 0.8626 - val_f1_score: 0.8590
# Epoch 87/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9809 - acc: 0.8330 - f1_score: 0.8330 - val_loss: 0.9011 - val_acc: 0.8597 - val_f1_score: 0.8591
# Epoch 88/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0053 - acc: 0.8284 - f1_score: 0.8283 - val_loss: 0.8703 - val_acc: 0.8772 - val_f1_score: 0.8767
# Epoch 89/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9920 - acc: 0.8315 - f1_score: 0.8312 - val_loss: 0.8446 - val_acc: 0.8876 - val_f1_score: 0.8878
# Epoch 90/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9801 - acc: 0.8286 - f1_score: 0.8284 - val_loss: 0.8639 - val_acc: 0.8655 - val_f1_score: 0.8641
# Epoch 91/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9645 - acc: 0.8292 - f1_score: 0.8290 - val_loss: 0.8709 - val_acc: 0.8573 - val_f1_score: 0.8544
# Epoch 92/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9942 - acc: 0.8283 - f1_score: 0.8278 - val_loss: 0.8684 - val_acc: 0.8849 - val_f1_score: 0.8845
# Epoch 93/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9901 - acc: 0.8307 - f1_score: 0.8304 - val_loss: 0.8498 - val_acc: 0.8839 - val_f1_score: 0.8841
# Epoch 94/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9679 - acc: 0.8305 - f1_score: 0.8301 - val_loss: 0.8348 - val_acc: 0.8837 - val_f1_score: 0.8835
# Epoch 95/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9635 - acc: 0.8334 - f1_score: 0.8330 - val_loss: 0.8108 - val_acc: 0.8786 - val_f1_score: 0.8785
# Epoch 96/100
# 258/258 [==============================] - 4s 14ms/step - loss: 0.9654 - acc: 0.8326 - f1_score: 0.8324 - val_loss: 0.8022 - val_acc: 0.8953 - val_f1_score: 0.8953
# Epoch 97/100
# 258/258 [==============================] - 6s 24ms/step - loss: 0.9775 - acc: 0.8320 - f1_score: 0.8318 - val_loss: 0.8525 - val_acc: 0.8793 - val_f1_score: 0.8788
# Epoch 98/100
# 258/258 [==============================] - 6s 25ms/step - loss: 0.9694 - acc: 0.8310 - f1_score: 0.8309 - val_loss: 0.8613 - val_acc: 0.8948 - val_f1_score: 0.8943
# Epoch 99/100
# 258/258 [==============================] - 6s 25ms/step - loss: 0.9824 - acc: 0.8310 - f1_score: 0.8308 - val_loss: 0.8957 - val_acc: 0.8711 - val_f1_score: 0.8700
# Epoch 100/100
# 258/258 [==============================] - 5s 18ms/step - loss: 0.9823 - acc: 0.8293 - f1_score: 0.8291 - val_loss: 0.8232 - val_acc: 0.8871 - val_f1_score: 0.8872
# 164/164 [==============================] - 1s 3ms/step - loss: 0.8916 - acc: 0.8535 - f1_score: 0.7999
# 164/164 [==============================] - 1s 3ms/step
# Score: loss of 0.8915795683860779; acc of 85.35141348838806%

# %% [markdown]
# ### Matrix de confusão

# %%
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2164                  5              13           42
# Deitado-Ruminando         5                675              91           20
# Deitado-Parado            9                124             491           36
# EmPe-Parado              32                 34              24          432
# Andando                  19                  0               1            4
# EmPe-Ruminando            6                 16               2           67
#
#                    Andando  EmPe-Ruminando
# Pastando                57              12
# Deitado-Ruminando        0              23
# Deitado-Parado           0              21
# EmPe-Parado              3              99
# Andando                467               0
# EmPe-Ruminando           2             240

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9682    0.9437    0.9558      2293
# Deitado-Ruminando     0.7904    0.8292    0.8094       814
#    Deitado-Parado     0.7894    0.7210    0.7536       681
#       EmPe-Parado     0.7188    0.6923    0.7053       624
#           Andando     0.8828    0.9511    0.9157       491
#    EmPe-Ruminando     0.6076    0.7207    0.6593       333
#
#          accuracy                         0.8535      5236
#         macro avg     0.7929    0.8097    0.7999      5236
#      weighted avg     0.8567    0.8535    0.8543      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# ## Base com SMOTE

# %%
# SMOTE
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train_balanced_smote, c_labels_train_balanced_smote, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test_smote, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test_smote, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test_smote, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 258/258 [==============================] - 5s 14ms/step - loss: 20.3464 - acc: 0.6033 - f1_score: 0.6003 - val_loss: 4.1839 - val_acc: 0.2740 - val_f1_score: 0.1557
# Epoch 2/100
# 258/258 [==============================] - 3s 13ms/step - loss: 2.3910 - acc: 0.6739 - f1_score: 0.6712 - val_loss: 2.0786 - val_acc: 0.7342 - val_f1_score: 0.7371
# Epoch 3/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.7154 - acc: 0.7079 - f1_score: 0.7052 - val_loss: 1.5661 - val_acc: 0.7369 - val_f1_score: 0.7319
# Epoch 4/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.5759 - acc: 0.7234 - f1_score: 0.7214 - val_loss: 1.4249 - val_acc: 0.7802 - val_f1_score: 0.7783
# Epoch 5/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.5003 - acc: 0.7441 - f1_score: 0.7425 - val_loss: 1.4099 - val_acc: 0.7848 - val_f1_score: 0.7795
# Epoch 6/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.4421 - acc: 0.7482 - f1_score: 0.7465 - val_loss: 1.3816 - val_acc: 0.8040 - val_f1_score: 0.8029
# Epoch 7/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.4147 - acc: 0.7603 - f1_score: 0.7584 - val_loss: 1.3277 - val_acc: 0.8069 - val_f1_score: 0.8078
# Epoch 8/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.4127 - acc: 0.7619 - f1_score: 0.7605 - val_loss: 1.3226 - val_acc: 0.8008 - val_f1_score: 0.8009
# Epoch 9/100
# 258/258 [==============================] - 4s 15ms/step - loss: 1.4303 - acc: 0.7623 - f1_score: 0.7608 - val_loss: 1.2417 - val_acc: 0.8251 - val_f1_score: 0.8254
# Epoch 10/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.3651 - acc: 0.7740 - f1_score: 0.7727 - val_loss: 1.3289 - val_acc: 0.8115 - val_f1_score: 0.8107
# Epoch 11/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.3804 - acc: 0.7805 - f1_score: 0.7794 - val_loss: 1.2993 - val_acc: 0.8248 - val_f1_score: 0.8232
# Epoch 12/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3721 - acc: 0.7782 - f1_score: 0.7771 - val_loss: 1.2776 - val_acc: 0.8105 - val_f1_score: 0.8117
# Epoch 13/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.3211 - acc: 0.7847 - f1_score: 0.7836 - val_loss: 1.2163 - val_acc: 0.8088 - val_f1_score: 0.8079
# Epoch 14/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2927 - acc: 0.7895 - f1_score: 0.7882 - val_loss: 1.1534 - val_acc: 0.8292 - val_f1_score: 0.8301
# Epoch 15/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2786 - acc: 0.7921 - f1_score: 0.7911 - val_loss: 1.1541 - val_acc: 0.8202 - val_f1_score: 0.8204
# Epoch 16/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2905 - acc: 0.7949 - f1_score: 0.7938 - val_loss: 1.1037 - val_acc: 0.8374 - val_f1_score: 0.8377
# Epoch 17/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2524 - acc: 0.7928 - f1_score: 0.7915 - val_loss: 1.1634 - val_acc: 0.8284 - val_f1_score: 0.8259
# Epoch 18/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2362 - acc: 0.7955 - f1_score: 0.7945 - val_loss: 1.1217 - val_acc: 0.8352 - val_f1_score: 0.8362
# Epoch 19/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2183 - acc: 0.7993 - f1_score: 0.7981 - val_loss: 1.1311 - val_acc: 0.8343 - val_f1_score: 0.8340
# Epoch 20/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2114 - acc: 0.8012 - f1_score: 0.8003 - val_loss: 1.1430 - val_acc: 0.8284 - val_f1_score: 0.8259
# Epoch 21/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.2088 - acc: 0.8036 - f1_score: 0.8027 - val_loss: 1.0669 - val_acc: 0.8389 - val_f1_score: 0.8399
# Epoch 22/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1904 - acc: 0.8050 - f1_score: 0.8041 - val_loss: 1.0910 - val_acc: 0.8437 - val_f1_score: 0.8439
# Epoch 23/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1734 - acc: 0.8051 - f1_score: 0.8042 - val_loss: 1.1221 - val_acc: 0.8335 - val_f1_score: 0.8313
# Epoch 24/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1800 - acc: 0.8037 - f1_score: 0.8026 - val_loss: 1.0265 - val_acc: 0.8469 - val_f1_score: 0.8473
# Epoch 25/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1805 - acc: 0.8106 - f1_score: 0.8096 - val_loss: 1.1292 - val_acc: 0.8289 - val_f1_score: 0.8274
# Epoch 26/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1668 - acc: 0.8100 - f1_score: 0.8091 - val_loss: 1.0725 - val_acc: 0.8505 - val_f1_score: 0.8505
# Epoch 27/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1479 - acc: 0.8144 - f1_score: 0.8136 - val_loss: 1.0540 - val_acc: 0.8498 - val_f1_score: 0.8490
# Epoch 28/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1380 - acc: 0.8132 - f1_score: 0.8123 - val_loss: 1.0529 - val_acc: 0.8469 - val_f1_score: 0.8478
# Epoch 29/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1227 - acc: 0.8143 - f1_score: 0.8133 - val_loss: 1.0013 - val_acc: 0.8522 - val_f1_score: 0.8525
# Epoch 30/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1056 - acc: 0.8139 - f1_score: 0.8129 - val_loss: 1.0010 - val_acc: 0.8515 - val_f1_score: 0.8524
# Epoch 31/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0936 - acc: 0.8150 - f1_score: 0.8141 - val_loss: 0.9592 - val_acc: 0.8585 - val_f1_score: 0.8590
# Epoch 32/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0916 - acc: 0.8172 - f1_score: 0.8163 - val_loss: 0.9702 - val_acc: 0.8486 - val_f1_score: 0.8498
# Epoch 33/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.1240 - acc: 0.8125 - f1_score: 0.8118 - val_loss: 1.0533 - val_acc: 0.8314 - val_f1_score: 0.8295
# Epoch 34/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0958 - acc: 0.8160 - f1_score: 0.8151 - val_loss: 1.0337 - val_acc: 0.8515 - val_f1_score: 0.8509
# Epoch 35/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0872 - acc: 0.8174 - f1_score: 0.8166 - val_loss: 0.9862 - val_acc: 0.8481 - val_f1_score: 0.8475
# Epoch 36/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0767 - acc: 0.8203 - f1_score: 0.8195 - val_loss: 1.0004 - val_acc: 0.8549 - val_f1_score: 0.8553
# Epoch 37/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0789 - acc: 0.8221 - f1_score: 0.8215 - val_loss: 0.9800 - val_acc: 0.8520 - val_f1_score: 0.8513
# Epoch 38/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0825 - acc: 0.8233 - f1_score: 0.8227 - val_loss: 0.9909 - val_acc: 0.8469 - val_f1_score: 0.8463
# Epoch 39/100
# 258/258 [==============================] - 4s 17ms/step - loss: 1.0748 - acc: 0.8197 - f1_score: 0.8188 - val_loss: 0.9994 - val_acc: 0.8575 - val_f1_score: 0.8564
# Epoch 40/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0622 - acc: 0.8207 - f1_score: 0.8200 - val_loss: 0.9734 - val_acc: 0.8486 - val_f1_score: 0.8493
# Epoch 41/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0638 - acc: 0.8265 - f1_score: 0.8259 - val_loss: 0.9660 - val_acc: 0.8573 - val_f1_score: 0.8580
# Epoch 42/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0636 - acc: 0.8237 - f1_score: 0.8229 - val_loss: 0.9654 - val_acc: 0.8619 - val_f1_score: 0.8619
# Epoch 43/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0664 - acc: 0.8245 - f1_score: 0.8238 - val_loss: 1.0560 - val_acc: 0.8386 - val_f1_score: 0.8364
# Epoch 44/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0721 - acc: 0.8291 - f1_score: 0.8283 - val_loss: 1.0216 - val_acc: 0.8459 - val_f1_score: 0.8474
# Epoch 45/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0654 - acc: 0.8252 - f1_score: 0.8246 - val_loss: 1.0265 - val_acc: 0.8553 - val_f1_score: 0.8552
# Epoch 46/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0548 - acc: 0.8210 - f1_score: 0.8204 - val_loss: 0.9421 - val_acc: 0.8621 - val_f1_score: 0.8620
# Epoch 47/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0273 - acc: 0.8267 - f1_score: 0.8262 - val_loss: 0.9099 - val_acc: 0.8544 - val_f1_score: 0.8539
# Epoch 48/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0183 - acc: 0.8208 - f1_score: 0.8203 - val_loss: 0.9856 - val_acc: 0.8551 - val_f1_score: 0.8555
# Epoch 49/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0243 - acc: 0.8284 - f1_score: 0.8278 - val_loss: 0.9364 - val_acc: 0.8709 - val_f1_score: 0.8705
# Epoch 50/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0406 - acc: 0.8277 - f1_score: 0.8269 - val_loss: 0.9647 - val_acc: 0.8629 - val_f1_score: 0.8623
# Epoch 51/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0292 - acc: 0.8284 - f1_score: 0.8279 - val_loss: 0.9634 - val_acc: 0.8532 - val_f1_score: 0.8547
# Epoch 52/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0218 - acc: 0.8259 - f1_score: 0.8252 - val_loss: 0.9392 - val_acc: 0.8517 - val_f1_score: 0.8537
# Epoch 53/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0130 - acc: 0.8298 - f1_score: 0.8292 - val_loss: 0.8569 - val_acc: 0.8723 - val_f1_score: 0.8728
# Epoch 54/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9952 - acc: 0.8304 - f1_score: 0.8298 - val_loss: 0.8975 - val_acc: 0.8684 - val_f1_score: 0.8681
# Epoch 55/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0294 - acc: 0.8220 - f1_score: 0.8213 - val_loss: 0.9540 - val_acc: 0.8587 - val_f1_score: 0.8576
# Epoch 56/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0179 - acc: 0.8307 - f1_score: 0.8301 - val_loss: 0.9224 - val_acc: 0.8660 - val_f1_score: 0.8656
# Epoch 57/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0136 - acc: 0.8284 - f1_score: 0.8279 - val_loss: 0.9313 - val_acc: 0.8595 - val_f1_score: 0.8592
# Epoch 58/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9898 - acc: 0.8269 - f1_score: 0.8262 - val_loss: 0.9017 - val_acc: 0.8638 - val_f1_score: 0.8635
# Epoch 59/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9920 - acc: 0.8289 - f1_score: 0.8282 - val_loss: 0.8926 - val_acc: 0.8747 - val_f1_score: 0.8748
# Epoch 60/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0045 - acc: 0.8349 - f1_score: 0.8343 - val_loss: 0.9078 - val_acc: 0.8646 - val_f1_score: 0.8649
# Epoch 61/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0191 - acc: 0.8296 - f1_score: 0.8290 - val_loss: 0.9366 - val_acc: 0.8728 - val_f1_score: 0.8721
# Epoch 62/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0472 - acc: 0.8312 - f1_score: 0.8305 - val_loss: 0.9400 - val_acc: 0.8718 - val_f1_score: 0.8723
# Epoch 63/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0128 - acc: 0.8313 - f1_score: 0.8308 - val_loss: 0.8976 - val_acc: 0.8772 - val_f1_score: 0.8777
# Epoch 64/100
# 258/258 [==============================] - 3s 12ms/step - loss: 1.0142 - acc: 0.8303 - f1_score: 0.8296 - val_loss: 0.8961 - val_acc: 0.8670 - val_f1_score: 0.8666
# Epoch 65/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9699 - acc: 0.8355 - f1_score: 0.8349 - val_loss: 0.8894 - val_acc: 0.8515 - val_f1_score: 0.8509
# Epoch 66/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9721 - acc: 0.8359 - f1_score: 0.8352 - val_loss: 0.9056 - val_acc: 0.8725 - val_f1_score: 0.8730
# Epoch 67/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0075 - acc: 0.8333 - f1_score: 0.8326 - val_loss: 0.9377 - val_acc: 0.8595 - val_f1_score: 0.8600
# Epoch 68/100
# 258/258 [==============================] - 3s 13ms/step - loss: 1.0332 - acc: 0.8308 - f1_score: 0.8302 - val_loss: 0.8843 - val_acc: 0.8730 - val_f1_score: 0.8734
# Epoch 69/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9947 - acc: 0.8366 - f1_score: 0.8360 - val_loss: 0.9333 - val_acc: 0.8612 - val_f1_score: 0.8617
# Epoch 70/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9814 - acc: 0.8339 - f1_score: 0.8334 - val_loss: 0.8869 - val_acc: 0.8694 - val_f1_score: 0.8698
# Epoch 71/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9773 - acc: 0.8386 - f1_score: 0.8381 - val_loss: 0.9283 - val_acc: 0.8677 - val_f1_score: 0.8679
# Epoch 72/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9725 - acc: 0.8355 - f1_score: 0.8351 - val_loss: 0.8511 - val_acc: 0.8696 - val_f1_score: 0.8690
# Epoch 73/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9857 - acc: 0.8329 - f1_score: 0.8323 - val_loss: 0.8706 - val_acc: 0.8745 - val_f1_score: 0.8751
# Epoch 74/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9942 - acc: 0.8357 - f1_score: 0.8352 - val_loss: 0.9091 - val_acc: 0.8738 - val_f1_score: 0.8744
# Epoch 75/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9594 - acc: 0.8355 - f1_score: 0.8349 - val_loss: 0.8654 - val_acc: 0.8658 - val_f1_score: 0.8662
# Epoch 76/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9807 - acc: 0.8353 - f1_score: 0.8348 - val_loss: 0.9043 - val_acc: 0.8706 - val_f1_score: 0.8706
# Epoch 77/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9747 - acc: 0.8338 - f1_score: 0.8333 - val_loss: 0.8314 - val_acc: 0.8776 - val_f1_score: 0.8779
# Epoch 78/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9744 - acc: 0.8375 - f1_score: 0.8368 - val_loss: 0.8810 - val_acc: 0.8725 - val_f1_score: 0.8732
# Epoch 79/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9827 - acc: 0.8370 - f1_score: 0.8363 - val_loss: 0.9213 - val_acc: 0.8619 - val_f1_score: 0.8619
# Epoch 80/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9784 - acc: 0.8373 - f1_score: 0.8368 - val_loss: 0.8805 - val_acc: 0.8701 - val_f1_score: 0.8704
# Epoch 81/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9635 - acc: 0.8357 - f1_score: 0.8352 - val_loss: 0.8605 - val_acc: 0.8742 - val_f1_score: 0.8745
# Epoch 82/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9967 - acc: 0.8352 - f1_score: 0.8346 - val_loss: 0.8964 - val_acc: 0.8774 - val_f1_score: 0.8774
# Epoch 83/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9694 - acc: 0.8422 - f1_score: 0.8417 - val_loss: 0.8500 - val_acc: 0.8837 - val_f1_score: 0.8839
# Epoch 84/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9721 - acc: 0.8386 - f1_score: 0.8380 - val_loss: 0.8636 - val_acc: 0.8805 - val_f1_score: 0.8808
# Epoch 85/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9521 - acc: 0.8388 - f1_score: 0.8381 - val_loss: 0.8596 - val_acc: 0.8842 - val_f1_score: 0.8848
# Epoch 86/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9609 - acc: 0.8415 - f1_score: 0.8410 - val_loss: 0.8398 - val_acc: 0.8757 - val_f1_score: 0.8758
# Epoch 87/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9609 - acc: 0.8430 - f1_score: 0.8424 - val_loss: 0.8662 - val_acc: 0.8786 - val_f1_score: 0.8788
# Epoch 88/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9624 - acc: 0.8390 - f1_score: 0.8385 - val_loss: 0.8283 - val_acc: 0.8745 - val_f1_score: 0.8747
# Epoch 89/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9391 - acc: 0.8409 - f1_score: 0.8403 - val_loss: 0.8714 - val_acc: 0.8658 - val_f1_score: 0.8662
# Epoch 90/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9540 - acc: 0.8402 - f1_score: 0.8398 - val_loss: 0.8814 - val_acc: 0.8752 - val_f1_score: 0.8754
# Epoch 91/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9797 - acc: 0.8426 - f1_score: 0.8420 - val_loss: 0.9122 - val_acc: 0.8646 - val_f1_score: 0.8641
# Epoch 92/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9470 - acc: 0.8423 - f1_score: 0.8419 - val_loss: 0.8271 - val_acc: 0.8803 - val_f1_score: 0.8804
# Epoch 93/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9359 - acc: 0.8424 - f1_score: 0.8419 - val_loss: 0.8476 - val_acc: 0.8679 - val_f1_score: 0.8669
# Epoch 94/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9526 - acc: 0.8449 - f1_score: 0.8445 - val_loss: 0.8670 - val_acc: 0.8655 - val_f1_score: 0.8641
# Epoch 95/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9439 - acc: 0.8411 - f1_score: 0.8406 - val_loss: 0.8697 - val_acc: 0.8718 - val_f1_score: 0.8722
# Epoch 96/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9546 - acc: 0.8413 - f1_score: 0.8407 - val_loss: 0.8766 - val_acc: 0.8738 - val_f1_score: 0.8731
# Epoch 97/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9454 - acc: 0.8407 - f1_score: 0.8401 - val_loss: 0.8604 - val_acc: 0.8757 - val_f1_score: 0.8763
# Epoch 98/100
# 258/258 [==============================] - 3s 13ms/step - loss: 0.9473 - acc: 0.8421 - f1_score: 0.8416 - val_loss: 0.8539 - val_acc: 0.8849 - val_f1_score: 0.8853
# Epoch 99/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9664 - acc: 0.8429 - f1_score: 0.8424 - val_loss: 0.8705 - val_acc: 0.8762 - val_f1_score: 0.8766
# Epoch 100/100
# 258/258 [==============================] - 3s 12ms/step - loss: 0.9494 - acc: 0.8391 - f1_score: 0.8386 - val_loss: 0.8247 - val_acc: 0.8718 - val_f1_score: 0.8719
# 164/164 [==============================] - 0s 3ms/step - loss: 0.9551 - acc: 0.8482 - f1_score: 0.7944
# 164/164 [==============================] - 1s 2ms/step
# Score: loss of 0.9551387429237366; acc of 84.81665253639221%

# %% [markdown]
# ### Matrix de confusão

# %%
# matriz de confusao para base balanceada com BOOTSTRAP
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2151                  5              10           49
# Deitado-Ruminando         4                671              77           42
# Deitado-Parado           14                148             452           50
# EmPe-Parado              28                 22               7          464
# Andando                  20                  0               0            4
# EmPe-Ruminando            6                 13               0           75
#
#                    Andando  EmPe-Ruminando
# Pastando                69               9
# Deitado-Ruminando        0              20
# Deitado-Parado           0              17
# EmPe-Parado              4              99
# Andando                466               1
# EmPe-Ruminando           2             237

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9676    0.9381    0.9526      2293
# Deitado-Ruminando     0.7811    0.8243    0.8022       814
#    Deitado-Parado     0.8278    0.6637    0.7368       681
#       EmPe-Parado     0.6784    0.7436    0.7095       624
#           Andando     0.8614    0.9491    0.9031       491
#    EmPe-Ruminando     0.6188    0.7117    0.6620       333
#
#          accuracy                         0.8482      5236
#         macro avg     0.7892    0.8051    0.7944      5236
#      weighted avg     0.8538    0.8482    0.8490      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# # CNN (dissertação) - VETOR EXPANDIDO 32X32 (APENAS TESTE)

# %%
epochs=100
batch_size=64
feature_dimensions=1024
input_shape=(32, 32, 1)
n_classes=6
labels_map = {"Pastando": 0, "Deitado-Ruminando": 1, "Deitado-Parado": 2, "EmPe-Parado": 3, "Andando": 4, "EmPe-Ruminando": 5}

def create_cnn():
    model = Sequential([
        Flatten(input_shape=(1, 10, 1)),
        Dense(feature_dimensions, activation='relu', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Reshape(input_shape, input_shape=(feature_dimensions,)),
        Conv1D(32, kernel_size=32, activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='same'),
        Dropout(0.2, seed=seed),
        Conv1D(96, kernel_size=16, activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='same'),
        Dropout(0.2, seed=seed),
        Flatten(),
        Dense(384, activation='relu', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Dropout(0.2, seed=seed),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Dropout(0.2, seed=seed),
        Dense(n_classes, activation='softmax', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed))
    ])
    model.reset_metrics()
    optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
    #optimizer=SGD(learning_rate=0.005, momentum=0.9, nesterov=False, name="SGD")
    #optimizer=RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07, centered=False, name="RMSprop")
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc', tfa.metrics.F1Score(num_classes=n_classes, name='f1_score', average='macro')])
    return model

def show_classification_report(results, n_splits):
    #print("Acurácia média: {:.4f}".format(np.mean(acc_per_fold)))
    #print("Desvio Padrão: {:}\n\n".format(np.std(acc_per_fold)))
    print('''\t\t        precision      recall     f1-score\n
        Pastando          {:.2f}        {:.2f}      {:.2f}
        Deitado-Ruminando {:.2f}        {:.2f}      {:.2f}
        Deitado-Parado    {:.2f}        {:.2f}      {:.2f}
        EmPe-Parado       {:.2f}        {:.2f}      {:.2f}
        Andando           {:.2f}        {:.2f}      {:.2f}
        EmPe-Ruminando    {:.2f}        {:.2f}      {:.2f}
        macro avg         {:.2f}        {:.2f}      {:.2f}
        accuracy          {:.2f}
    '''.format(
        100*results['Pastando']['precision']/n_splits, 100*results['Pastando']['recall']/n_splits, 100*results['Pastando']['f1-score']/n_splits,
        100*results['Deitado-Ruminando']['precision']/n_splits, 100*results['Deitado-Ruminando']['recall']/n_splits, 100*results['Deitado-Ruminando']['f1-score']/n_splits,
        100*results['Deitado-Parado']['precision']/n_splits, 100*results['Deitado-Parado']['recall']/n_splits, 100*results['Deitado-Parado']['f1-score']/n_splits,
        100*results['EmPe-Parado']['precision']/n_splits, 100*results['EmPe-Parado']['recall']/n_splits, 100*results['EmPe-Parado']['f1-score']/n_splits,
        100*results['Andando']['precision']/n_splits, 100*results['Andando']['recall']/n_splits, 100*results['Andando']['f1-score']/n_splits,
        100*results['EmPe-Ruminando']['precision']/n_splits, 100*results['EmPe-Ruminando']['recall']/n_splits, 100*results['EmPe-Ruminando']['f1-score']/n_splits,
        100*results['macro avg']['precision']/n_splits, 100*results['macro avg']['recall']/n_splits, 100*results['macro avg']['f1-score']/n_splits,
        100*results['accuracy']/n_splits
        )
    )

def update_report(results, new_results):
    for k in new_results.keys():
        if type(new_results[k]) is dict:
            for _k in results[k].keys():
                results[k][_k]+=new_results[k][_k]
        else:
            results[k] += new_results[k]
create_cnn().summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 10)                0
#
#  dense_12 (Dense)            (None, 1024)              11264
#
#  batch_normalization_16 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  reshape (Reshape)           (None, 32, 32, 1)         0
#
#  conv1d_8 (Conv1D)           (None, 32, 32, 32)        1056
#
#  batch_normalization_17 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_16 (Dropout)        (None, 16, 16, 32)        0
#
#  conv1d_9 (Conv1D)           (None, 16, 16, 96)        49248
#
#  batch_normalization_18 (Bat  (None, 16, 16, 96)       384
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  dropout_17 (Dropout)        (None, 8, 8, 96)          0
#
#  flatten_5 (Flatten)         (None, 6144)              0
#
#  dense_13 (Dense)            (None, 384)               2359680
#
#  batch_normalization_19 (Bat  (None, 384)              1536
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 384)               0
#
#  dense_14 (Dense)            (None, 128)               49280
#
#  batch_normalization_20 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 2,477,958
# Trainable params: 2,474,630
# Non-trainable params: 3,328
# _________________________________________________________________

# %% [markdown]
# ## Base original

# %%
# ORIGINAL
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train, c_labels_train, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 99/99 [==============================] - 30s 283ms/step - loss: 84.1029 - acc: 0.6674 - f1_score: 0.5416 - val_loss: 23.3966 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 2/100
# 99/99 [==============================] - 27s 275ms/step - loss: 16.6900 - acc: 0.7051 - f1_score: 0.5829 - val_loss: 12.5585 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 3/100
# 99/99 [==============================] - 27s 276ms/step - loss: 9.7142 - acc: 0.7384 - f1_score: 0.6210 - val_loss: 9.0606 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 4/100
# 99/99 [==============================] - 27s 276ms/step - loss: 7.1319 - acc: 0.7520 - f1_score: 0.6306 - val_loss: 8.1958 - val_acc: 0.4946 - val_f1_score: 0.2248
# Epoch 5/100
# 99/99 [==============================] - 28s 279ms/step - loss: 7.1077 - acc: 0.7714 - f1_score: 0.6590 - val_loss: 7.2582 - val_acc: 0.6003 - val_f1_score: 0.3605
# Epoch 6/100
# 99/99 [==============================] - 28s 279ms/step - loss: 6.5358 - acc: 0.7755 - f1_score: 0.6654 - val_loss: 6.2852 - val_acc: 0.7320 - val_f1_score: 0.5712
# Epoch 7/100
# 99/99 [==============================] - 28s 287ms/step - loss: 6.0461 - acc: 0.7841 - f1_score: 0.6712 - val_loss: 6.1502 - val_acc: 0.7683 - val_f1_score: 0.6461
# Epoch 8/100
# 99/99 [==============================] - 29s 296ms/step - loss: 5.8001 - acc: 0.7961 - f1_score: 0.7010 - val_loss: 5.4203 - val_acc: 0.7046 - val_f1_score: 0.5990
# Epoch 9/100
# 99/99 [==============================] - 29s 293ms/step - loss: 5.5482 - acc: 0.7994 - f1_score: 0.7080 - val_loss: 6.0958 - val_acc: 0.7791 - val_f1_score: 0.6320
# Epoch 10/100
# 99/99 [==============================] - 29s 291ms/step - loss: 5.7358 - acc: 0.7991 - f1_score: 0.7029 - val_loss: 7.0716 - val_acc: 0.4220 - val_f1_score: 0.3676
# Epoch 11/100
# 99/99 [==============================] - 29s 291ms/step - loss: 5.8221 - acc: 0.7961 - f1_score: 0.6977 - val_loss: 5.5453 - val_acc: 0.7454 - val_f1_score: 0.5806
# Epoch 12/100
# 99/99 [==============================] - 29s 293ms/step - loss: 5.5085 - acc: 0.8045 - f1_score: 0.7088 - val_loss: 7.4981 - val_acc: 0.4017 - val_f1_score: 0.4762
# Epoch 13/100
# 99/99 [==============================] - 30s 299ms/step - loss: 5.7503 - acc: 0.8102 - f1_score: 0.7222 - val_loss: 5.5863 - val_acc: 0.8180 - val_f1_score: 0.7564
# Epoch 14/100
# 99/99 [==============================] - 28s 280ms/step - loss: 5.4370 - acc: 0.8059 - f1_score: 0.7139 - val_loss: 5.4125 - val_acc: 0.7912 - val_f1_score: 0.7001
# Epoch 15/100
# 99/99 [==============================] - 29s 289ms/step - loss: 5.3886 - acc: 0.8085 - f1_score: 0.7202 - val_loss: 8.4624 - val_acc: 0.2419 - val_f1_score: 0.3023
# Epoch 16/100
# 99/99 [==============================] - 29s 293ms/step - loss: 6.3412 - acc: 0.8099 - f1_score: 0.7171 - val_loss: 5.9068 - val_acc: 0.8046 - val_f1_score: 0.7236
# Epoch 17/100
# 99/99 [==============================] - 29s 290ms/step - loss: 5.3845 - acc: 0.8180 - f1_score: 0.7331 - val_loss: 5.6567 - val_acc: 0.8173 - val_f1_score: 0.7262
# Epoch 18/100
# 99/99 [==============================] - 29s 288ms/step - loss: 5.3947 - acc: 0.8257 - f1_score: 0.7421 - val_loss: 5.4603 - val_acc: 0.8090 - val_f1_score: 0.6950
# Epoch 19/100
# 99/99 [==============================] - 28s 288ms/step - loss: 5.2869 - acc: 0.8269 - f1_score: 0.7464 - val_loss: 5.8191 - val_acc: 0.7963 - val_f1_score: 0.6927
# Epoch 20/100
# 99/99 [==============================] - 28s 287ms/step - loss: 5.5962 - acc: 0.8242 - f1_score: 0.7407 - val_loss: 6.5153 - val_acc: 0.6525 - val_f1_score: 0.6229
# Epoch 21/100
# 99/99 [==============================] - 29s 288ms/step - loss: 5.7717 - acc: 0.8226 - f1_score: 0.7417 - val_loss: 6.1631 - val_acc: 0.7696 - val_f1_score: 0.7091
# Epoch 22/100
# 99/99 [==============================] - 28s 288ms/step - loss: 5.7721 - acc: 0.8300 - f1_score: 0.7502 - val_loss: 5.8546 - val_acc: 0.7938 - val_f1_score: 0.7522
# Epoch 23/100
# 99/99 [==============================] - 28s 288ms/step - loss: 5.2459 - acc: 0.8355 - f1_score: 0.7650 - val_loss: 5.3973 - val_acc: 0.7931 - val_f1_score: 0.6576
# Epoch 24/100
# 99/99 [==============================] - 28s 288ms/step - loss: 5.0677 - acc: 0.8346 - f1_score: 0.7566 - val_loss: 6.1825 - val_acc: 0.7199 - val_f1_score: 0.7029
# Epoch 25/100
# 99/99 [==============================] - 29s 290ms/step - loss: 5.2352 - acc: 0.8333 - f1_score: 0.7552 - val_loss: 5.3485 - val_acc: 0.8141 - val_f1_score: 0.6993
# Epoch 26/100
# 99/99 [==============================] - 29s 298ms/step - loss: 5.2703 - acc: 0.8387 - f1_score: 0.7645 - val_loss: 5.7528 - val_acc: 0.7721 - val_f1_score: 0.7303
# Epoch 27/100
# 99/99 [==============================] - 29s 292ms/step - loss: 5.3084 - acc: 0.8376 - f1_score: 0.7612 - val_loss: 5.2560 - val_acc: 0.8027 - val_f1_score: 0.7382
# Epoch 28/100
# 99/99 [==============================] - 28s 286ms/step - loss: 5.0438 - acc: 0.8445 - f1_score: 0.7713 - val_loss: 6.0540 - val_acc: 0.7817 - val_f1_score: 0.7261
# Epoch 29/100
# 99/99 [==============================] - 29s 291ms/step - loss: 5.4491 - acc: 0.8449 - f1_score: 0.7745 - val_loss: 5.1985 - val_acc: 0.8122 - val_f1_score: 0.7275
# Epoch 30/100
# 99/99 [==============================] - 29s 291ms/step - loss: 5.0535 - acc: 0.8465 - f1_score: 0.7759 - val_loss: 6.0425 - val_acc: 0.4659 - val_f1_score: 0.5360
# Epoch 31/100
# 99/99 [==============================] - 29s 289ms/step - loss: 5.3164 - acc: 0.8467 - f1_score: 0.7775 - val_loss: 7.0730 - val_acc: 0.5391 - val_f1_score: 0.5997
# Epoch 32/100
# 99/99 [==============================] - 29s 288ms/step - loss: 5.7521 - acc: 0.8476 - f1_score: 0.7784 - val_loss: 5.7441 - val_acc: 0.7167 - val_f1_score: 0.5757
# Epoch 33/100
# 99/99 [==============================] - 29s 290ms/step - loss: 5.2817 - acc: 0.8491 - f1_score: 0.7835 - val_loss: 5.4004 - val_acc: 0.7778 - val_f1_score: 0.6873
# Epoch 34/100
# 99/99 [==============================] - 29s 293ms/step - loss: 4.9220 - acc: 0.8408 - f1_score: 0.7647 - val_loss: 4.9326 - val_acc: 0.8364 - val_f1_score: 0.7825
# Epoch 35/100
# 99/99 [==============================] - 29s 293ms/step - loss: 4.9205 - acc: 0.8462 - f1_score: 0.7752 - val_loss: 4.9451 - val_acc: 0.8230 - val_f1_score: 0.7576
# Epoch 36/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.8680 - acc: 0.8472 - f1_score: 0.7770 - val_loss: 5.5089 - val_acc: 0.8205 - val_f1_score: 0.7541
# Epoch 37/100
# 99/99 [==============================] - 29s 290ms/step - loss: 5.0784 - acc: 0.8492 - f1_score: 0.7820 - val_loss: 4.9203 - val_acc: 0.8046 - val_f1_score: 0.7052
# Epoch 38/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.7608 - acc: 0.8454 - f1_score: 0.7759 - val_loss: 5.9675 - val_acc: 0.7893 - val_f1_score: 0.6931
# Epoch 39/100
# 99/99 [==============================] - 29s 292ms/step - loss: 5.3065 - acc: 0.8478 - f1_score: 0.7822 - val_loss: 5.4151 - val_acc: 0.8472 - val_f1_score: 0.7884
# Epoch 40/100
# 99/99 [==============================] - 29s 289ms/step - loss: 5.0120 - acc: 0.8502 - f1_score: 0.7861 - val_loss: 5.2840 - val_acc: 0.8033 - val_f1_score: 0.7318
# Epoch 41/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.8717 - acc: 0.8577 - f1_score: 0.7926 - val_loss: 5.1057 - val_acc: 0.7969 - val_f1_score: 0.7051
# Epoch 42/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.8143 - acc: 0.8530 - f1_score: 0.7846 - val_loss: 5.4107 - val_acc: 0.8351 - val_f1_score: 0.7721
# Epoch 43/100
# 99/99 [==============================] - 29s 291ms/step - loss: 5.2625 - acc: 0.8510 - f1_score: 0.7890 - val_loss: 5.4939 - val_acc: 0.7180 - val_f1_score: 0.7165
# Epoch 44/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.9543 - acc: 0.8556 - f1_score: 0.7891 - val_loss: 5.9460 - val_acc: 0.7034 - val_f1_score: 0.6921
# Epoch 45/100
# 99/99 [==============================] - 29s 289ms/step - loss: 5.0611 - acc: 0.8575 - f1_score: 0.7952 - val_loss: 7.3476 - val_acc: 0.3094 - val_f1_score: 0.3143
# Epoch 46/100
# 99/99 [==============================] - 29s 290ms/step - loss: 5.5397 - acc: 0.8489 - f1_score: 0.7829 - val_loss: 4.7371 - val_acc: 0.8377 - val_f1_score: 0.7845
# Epoch 47/100
# 99/99 [==============================] - 29s 291ms/step - loss: 4.6720 - acc: 0.8508 - f1_score: 0.7842 - val_loss: 6.2032 - val_acc: 0.3921 - val_f1_score: 0.4573
# Epoch 48/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.9004 - acc: 0.8499 - f1_score: 0.7812 - val_loss: 6.3188 - val_acc: 0.7772 - val_f1_score: 0.7245
# Epoch 49/100
# 99/99 [==============================] - 29s 290ms/step - loss: 5.5964 - acc: 0.8616 - f1_score: 0.8027 - val_loss: 4.6339 - val_acc: 0.8421 - val_f1_score: 0.7888
# Epoch 50/100
# 99/99 [==============================] - 29s 291ms/step - loss: 4.6609 - acc: 0.8644 - f1_score: 0.8025 - val_loss: 4.8287 - val_acc: 0.8536 - val_f1_score: 0.8033
# Epoch 51/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.6638 - acc: 0.8588 - f1_score: 0.7943 - val_loss: 6.5026 - val_acc: 0.6047 - val_f1_score: 0.5528
# Epoch 52/100
# 99/99 [==============================] - 29s 292ms/step - loss: 5.3998 - acc: 0.8620 - f1_score: 0.7984 - val_loss: 5.6232 - val_acc: 0.8269 - val_f1_score: 0.7725
# Epoch 53/100
# 99/99 [==============================] - 29s 292ms/step - loss: 5.0907 - acc: 0.8632 - f1_score: 0.8021 - val_loss: 4.9315 - val_acc: 0.8326 - val_f1_score: 0.7607
# Epoch 54/100
# 99/99 [==============================] - 29s 292ms/step - loss: 4.6626 - acc: 0.8687 - f1_score: 0.8093 - val_loss: 5.0178 - val_acc: 0.8511 - val_f1_score: 0.8030
# Epoch 55/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.6531 - acc: 0.8722 - f1_score: 0.8144 - val_loss: 4.6217 - val_acc: 0.8275 - val_f1_score: 0.7139
# Epoch 56/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.5981 - acc: 0.8667 - f1_score: 0.8067 - val_loss: 5.3713 - val_acc: 0.8364 - val_f1_score: 0.7671
# Epoch 57/100
# 99/99 [==============================] - 28s 285ms/step - loss: 4.8417 - acc: 0.8666 - f1_score: 0.8059 - val_loss: 4.9452 - val_acc: 0.8199 - val_f1_score: 0.7747
# Epoch 58/100
# 99/99 [==============================] - 28s 281ms/step - loss: 4.6331 - acc: 0.8669 - f1_score: 0.8056 - val_loss: 5.1728 - val_acc: 0.7753 - val_f1_score: 0.6882
# Epoch 59/100
# 99/99 [==============================] - 27s 278ms/step - loss: 4.4782 - acc: 0.8715 - f1_score: 0.8142 - val_loss: 5.9632 - val_acc: 0.7447 - val_f1_score: 0.6248
# Epoch 60/100
# 99/99 [==============================] - 27s 278ms/step - loss: 5.3655 - acc: 0.8691 - f1_score: 0.8102 - val_loss: 7.4658 - val_acc: 0.4137 - val_f1_score: 0.4947
# Epoch 61/100
# 99/99 [==============================] - 27s 278ms/step - loss: 5.3126 - acc: 0.8663 - f1_score: 0.8046 - val_loss: 5.2870 - val_acc: 0.8046 - val_f1_score: 0.7302
# Epoch 62/100
# 99/99 [==============================] - 27s 278ms/step - loss: 4.8799 - acc: 0.8701 - f1_score: 0.8087 - val_loss: 6.3325 - val_acc: 0.8383 - val_f1_score: 0.7713
# Epoch 63/100
# 99/99 [==============================] - 29s 289ms/step - loss: 5.9483 - acc: 0.8616 - f1_score: 0.7965 - val_loss: 5.2226 - val_acc: 0.8281 - val_f1_score: 0.7717
# Epoch 64/100
# 99/99 [==============================] - 29s 291ms/step - loss: 4.8250 - acc: 0.8647 - f1_score: 0.8053 - val_loss: 4.4485 - val_acc: 0.8364 - val_f1_score: 0.7762
# Epoch 65/100
# 99/99 [==============================] - 29s 293ms/step - loss: 4.3928 - acc: 0.8741 - f1_score: 0.8140 - val_loss: 5.6649 - val_acc: 0.8288 - val_f1_score: 0.7718
# Epoch 66/100
# 99/99 [==============================] - 29s 291ms/step - loss: 4.9399 - acc: 0.8664 - f1_score: 0.8079 - val_loss: 5.1564 - val_acc: 0.8262 - val_f1_score: 0.7614
# Epoch 67/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.9173 - acc: 0.8784 - f1_score: 0.8197 - val_loss: 4.7921 - val_acc: 0.8269 - val_f1_score: 0.7636
# Epoch 68/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.4861 - acc: 0.8701 - f1_score: 0.8094 - val_loss: 5.2406 - val_acc: 0.8536 - val_f1_score: 0.8026
# Epoch 69/100
# 99/99 [==============================] - 28s 287ms/step - loss: 4.9186 - acc: 0.8687 - f1_score: 0.8075 - val_loss: 4.7600 - val_acc: 0.8619 - val_f1_score: 0.8151
# Epoch 70/100
# 99/99 [==============================] - 28s 287ms/step - loss: 4.5794 - acc: 0.8782 - f1_score: 0.8229 - val_loss: 5.7996 - val_acc: 0.7906 - val_f1_score: 0.7122
# Epoch 71/100
# 99/99 [==============================] - 28s 287ms/step - loss: 5.2209 - acc: 0.8672 - f1_score: 0.8056 - val_loss: 5.7598 - val_acc: 0.8262 - val_f1_score: 0.7653
# Epoch 72/100
# 99/99 [==============================] - 28s 287ms/step - loss: 5.3686 - acc: 0.8722 - f1_score: 0.8132 - val_loss: 4.4682 - val_acc: 0.8619 - val_f1_score: 0.8150
# Epoch 73/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.3850 - acc: 0.8704 - f1_score: 0.8080 - val_loss: 4.8918 - val_acc: 0.8721 - val_f1_score: 0.8292
# Epoch 74/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.5787 - acc: 0.8677 - f1_score: 0.8077 - val_loss: 4.8677 - val_acc: 0.8568 - val_f1_score: 0.8141
# Epoch 75/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.3913 - acc: 0.8725 - f1_score: 0.8147 - val_loss: 5.4303 - val_acc: 0.8230 - val_f1_score: 0.7691
# Epoch 76/100
# 99/99 [==============================] - 28s 286ms/step - loss: 4.7486 - acc: 0.8769 - f1_score: 0.8201 - val_loss: 4.9825 - val_acc: 0.7944 - val_f1_score: 0.7112
# Epoch 77/100
# 99/99 [==============================] - 28s 286ms/step - loss: 4.6571 - acc: 0.8699 - f1_score: 0.8105 - val_loss: 4.6441 - val_acc: 0.7893 - val_f1_score: 0.6870
# Epoch 78/100
# 99/99 [==============================] - 28s 287ms/step - loss: 4.2988 - acc: 0.8855 - f1_score: 0.8316 - val_loss: 4.9023 - val_acc: 0.8549 - val_f1_score: 0.8080
# Epoch 79/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.5729 - acc: 0.8682 - f1_score: 0.8100 - val_loss: 5.2900 - val_acc: 0.8453 - val_f1_score: 0.7783
# Epoch 80/100
# 99/99 [==============================] - 28s 286ms/step - loss: 4.8809 - acc: 0.8755 - f1_score: 0.8177 - val_loss: 4.3376 - val_acc: 0.8574 - val_f1_score: 0.8150
# Epoch 81/100
# 99/99 [==============================] - 30s 307ms/step - loss: 4.2669 - acc: 0.8820 - f1_score: 0.8270 - val_loss: 5.0528 - val_acc: 0.8440 - val_f1_score: 0.7856
# Epoch 82/100
# 99/99 [==============================] - 29s 293ms/step - loss: 4.6411 - acc: 0.8726 - f1_score: 0.8160 - val_loss: 4.2436 - val_acc: 0.8453 - val_f1_score: 0.7876
# Epoch 83/100
# 99/99 [==============================] - 30s 300ms/step - loss: 4.1581 - acc: 0.8822 - f1_score: 0.8301 - val_loss: 6.0220 - val_acc: 0.7518 - val_f1_score: 0.7061
# Epoch 84/100
# 99/99 [==============================] - 29s 294ms/step - loss: 5.1200 - acc: 0.8808 - f1_score: 0.8254 - val_loss: 6.4634 - val_acc: 0.7804 - val_f1_score: 0.7244
# Epoch 85/100
# 99/99 [==============================] - 29s 289ms/step - loss: 5.7090 - acc: 0.8782 - f1_score: 0.8235 - val_loss: 4.5591 - val_acc: 0.8440 - val_f1_score: 0.7875
# Epoch 86/100
# 99/99 [==============================] - 30s 299ms/step - loss: 4.2257 - acc: 0.8827 - f1_score: 0.8282 - val_loss: 4.3512 - val_acc: 0.8555 - val_f1_score: 0.8047
# Epoch 87/100
# 99/99 [==============================] - 28s 288ms/step - loss: 4.1738 - acc: 0.8868 - f1_score: 0.8354 - val_loss: 4.8893 - val_acc: 0.7931 - val_f1_score: 0.6973
# Epoch 88/100
# 99/99 [==============================] - 28s 287ms/step - loss: 4.2906 - acc: 0.8819 - f1_score: 0.8279 - val_loss: 4.4124 - val_acc: 0.8453 - val_f1_score: 0.7832
# Epoch 89/100
# 99/99 [==============================] - 29s 295ms/step - loss: 4.1435 - acc: 0.8887 - f1_score: 0.8363 - val_loss: 4.3626 - val_acc: 0.8517 - val_f1_score: 0.8094
# Epoch 90/100
# 99/99 [==============================] - 28s 286ms/step - loss: 4.1539 - acc: 0.8882 - f1_score: 0.8361 - val_loss: 4.3928 - val_acc: 0.8370 - val_f1_score: 0.7925
# Epoch 91/100
# 99/99 [==============================] - 29s 293ms/step - loss: 4.1719 - acc: 0.8892 - f1_score: 0.8397 - val_loss: 4.5441 - val_acc: 0.8218 - val_f1_score: 0.7746
# Epoch 92/100
# 99/99 [==============================] - 29s 294ms/step - loss: 4.1775 - acc: 0.8886 - f1_score: 0.8386 - val_loss: 4.3369 - val_acc: 0.8307 - val_f1_score: 0.7787
# Epoch 93/100
# 99/99 [==============================] - 29s 290ms/step - loss: 4.1314 - acc: 0.8835 - f1_score: 0.8299 - val_loss: 4.4573 - val_acc: 0.8409 - val_f1_score: 0.7929
# Epoch 94/100
# 99/99 [==============================] - 28s 288ms/step - loss: 4.1203 - acc: 0.8855 - f1_score: 0.8326 - val_loss: 4.9506 - val_acc: 0.8326 - val_f1_score: 0.7769
# Epoch 95/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.3144 - acc: 0.8854 - f1_score: 0.8342 - val_loss: 4.6559 - val_acc: 0.8530 - val_f1_score: 0.7894
# Epoch 96/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.2670 - acc: 0.8868 - f1_score: 0.8327 - val_loss: 4.6760 - val_acc: 0.8466 - val_f1_score: 0.7991
# Epoch 97/100
# 99/99 [==============================] - 28s 288ms/step - loss: 4.2483 - acc: 0.8863 - f1_score: 0.8344 - val_loss: 4.4842 - val_acc: 0.8460 - val_f1_score: 0.7970
# Epoch 98/100
# 99/99 [==============================] - 28s 288ms/step - loss: 4.1221 - acc: 0.8889 - f1_score: 0.8358 - val_loss: 4.7580 - val_acc: 0.8211 - val_f1_score: 0.7515
# Epoch 99/100
# 99/99 [==============================] - 29s 291ms/step - loss: 4.3365 - acc: 0.8884 - f1_score: 0.8340 - val_loss: 4.1721 - val_acc: 0.8498 - val_f1_score: 0.7941
# Epoch 100/100
# 99/99 [==============================] - 29s 289ms/step - loss: 4.0159 - acc: 0.8908 - f1_score: 0.8412 - val_loss: 4.7655 - val_acc: 0.8167 - val_f1_score: 0.7593
# 164/164 [==============================] - 7s 45ms/step - loss: 4.9314 - acc: 0.8440 - f1_score: 0.7787
# 164/164 [==============================] - 8s 45ms/step
# Score: loss of 4.9314165115356445; acc of 84.39648747444153%

# %% [markdown]
# ### Matrix de confusão

# %%
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2216                  6               1           21
# Deitado-Ruminando         7                698              81           17
# Deitado-Parado           20                154             467           29
# EmPe-Parado              32                 60              37          383
# Andando                  43                  1               0            2
# EmPe-Ruminando            8                 29               3           80
#
#                    Andando  EmPe-Ruminando
# Pastando                38              11
# Deitado-Ruminando        0              11
# Deitado-Parado           0              11
# EmPe-Parado              3             109
# Andando                444               1
# EmPe-Ruminando           2             211

# %%
plt.style.use('default')
fig, ax = plt.subplots(figsize=(15, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels_map)
disp.plot(ax=ax, cmap="Reds", values_format='')

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9527    0.9664    0.9595      2293
# Deitado-Ruminando     0.7363    0.8575    0.7923       814
#    Deitado-Parado     0.7929    0.6858    0.7354       681
#       EmPe-Parado     0.7199    0.6138    0.6626       624
#           Andando     0.9117    0.9043    0.9080       491
#    EmPe-Ruminando     0.5960    0.6336    0.6143       333
#
#          accuracy                         0.8440      5236
#         macro avg     0.7849    0.7769    0.7787      5236
#      weighted avg     0.8440    0.8440    0.8422      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# ## Base com Bootstrap

# %%
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train_balanced_bootstrap, c_labels_train_balanced_bootstrap, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test_bootstrap, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test_bootstrap, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test_bootstrap, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 258/258 [==============================] - 79s 300ms/step - loss: 40.9853 - acc: 0.6522 - f1_score: 0.6494 - val_loss: 10.0464 - val_acc: 0.1631 - val_f1_score: 0.0467
# Epoch 2/100
# 258/258 [==============================] - 75s 289ms/step - loss: 7.3865 - acc: 0.7211 - f1_score: 0.7191 - val_loss: 6.8025 - val_acc: 0.6482 - val_f1_score: 0.6233
# Epoch 3/100
# 258/258 [==============================] - 74s 288ms/step - loss: 6.1820 - acc: 0.7588 - f1_score: 0.7569 - val_loss: 6.2771 - val_acc: 0.7463 - val_f1_score: 0.7328
# Epoch 4/100
# 258/258 [==============================] - 73s 283ms/step - loss: 5.8712 - acc: 0.7825 - f1_score: 0.7811 - val_loss: 5.6765 - val_acc: 0.8011 - val_f1_score: 0.7970
# Epoch 5/100
# 258/258 [==============================] - 76s 295ms/step - loss: 5.6825 - acc: 0.7868 - f1_score: 0.7856 - val_loss: 5.5232 - val_acc: 0.7524 - val_f1_score: 0.7460
# Epoch 6/100
# 258/258 [==============================] - 76s 293ms/step - loss: 5.5661 - acc: 0.8006 - f1_score: 0.7999 - val_loss: 5.3887 - val_acc: 0.8287 - val_f1_score: 0.8253
# Epoch 7/100
# 258/258 [==============================] - 76s 296ms/step - loss: 5.4091 - acc: 0.8088 - f1_score: 0.8080 - val_loss: 5.2633 - val_acc: 0.8488 - val_f1_score: 0.8486
# Epoch 8/100
# 258/258 [==============================] - 76s 296ms/step - loss: 5.3605 - acc: 0.8212 - f1_score: 0.8207 - val_loss: 5.3521 - val_acc: 0.8401 - val_f1_score: 0.8384
# Epoch 9/100
# 258/258 [==============================] - 75s 292ms/step - loss: 5.2726 - acc: 0.8243 - f1_score: 0.8237 - val_loss: 5.1449 - val_acc: 0.8406 - val_f1_score: 0.8403
# Epoch 10/100
# 258/258 [==============================] - 74s 287ms/step - loss: 5.1470 - acc: 0.8340 - f1_score: 0.8336 - val_loss: 4.9759 - val_acc: 0.8626 - val_f1_score: 0.8612
# Epoch 11/100
# 258/258 [==============================] - 74s 287ms/step - loss: 5.0516 - acc: 0.8368 - f1_score: 0.8363 - val_loss: 5.0379 - val_acc: 0.8583 - val_f1_score: 0.8571
# Epoch 12/100
# 258/258 [==============================] - 75s 293ms/step - loss: 4.9493 - acc: 0.8432 - f1_score: 0.8426 - val_loss: 4.8517 - val_acc: 0.8769 - val_f1_score: 0.8762
# Epoch 13/100
# 258/258 [==============================] - 73s 284ms/step - loss: 4.9179 - acc: 0.8465 - f1_score: 0.8462 - val_loss: 4.5863 - val_acc: 0.8759 - val_f1_score: 0.8751
# Epoch 14/100
# 258/258 [==============================] - 73s 282ms/step - loss: 4.8913 - acc: 0.8530 - f1_score: 0.8527 - val_loss: 4.6737 - val_acc: 0.8728 - val_f1_score: 0.8725
# Epoch 15/100
# 258/258 [==============================] - 73s 283ms/step - loss: 4.8332 - acc: 0.8515 - f1_score: 0.8512 - val_loss: 4.5932 - val_acc: 0.8709 - val_f1_score: 0.8705
# Epoch 16/100
# 258/258 [==============================] - 73s 282ms/step - loss: 4.7282 - acc: 0.8619 - f1_score: 0.8617 - val_loss: 4.5001 - val_acc: 0.8905 - val_f1_score: 0.8899
# Epoch 17/100
# 258/258 [==============================] - 73s 284ms/step - loss: 4.7186 - acc: 0.8618 - f1_score: 0.8616 - val_loss: 4.6489 - val_acc: 0.8934 - val_f1_score: 0.8926
# Epoch 18/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.6561 - acc: 0.8627 - f1_score: 0.8624 - val_loss: 4.5845 - val_acc: 0.8907 - val_f1_score: 0.8898
# Epoch 19/100
# 258/258 [==============================] - 76s 296ms/step - loss: 4.6546 - acc: 0.8643 - f1_score: 0.8640 - val_loss: 4.7364 - val_acc: 0.8837 - val_f1_score: 0.8831
# Epoch 20/100
# 258/258 [==============================] - 78s 301ms/step - loss: 4.6248 - acc: 0.8687 - f1_score: 0.8685 - val_loss: 4.7126 - val_acc: 0.8607 - val_f1_score: 0.8566
# Epoch 21/100
# 258/258 [==============================] - 75s 290ms/step - loss: 4.5548 - acc: 0.8734 - f1_score: 0.8733 - val_loss: 4.3504 - val_acc: 0.8895 - val_f1_score: 0.8901
# Epoch 22/100
# 258/258 [==============================] - 75s 292ms/step - loss: 4.5169 - acc: 0.8774 - f1_score: 0.8772 - val_loss: 4.4706 - val_acc: 0.8898 - val_f1_score: 0.8893
# Epoch 23/100
# 258/258 [==============================] - 75s 291ms/step - loss: 4.4753 - acc: 0.8735 - f1_score: 0.8732 - val_loss: 4.3748 - val_acc: 0.8975 - val_f1_score: 0.8973
# Epoch 24/100
# 258/258 [==============================] - 75s 292ms/step - loss: 4.4787 - acc: 0.8776 - f1_score: 0.8773 - val_loss: 4.4030 - val_acc: 0.8961 - val_f1_score: 0.8962
# Epoch 25/100
# 258/258 [==============================] - 75s 293ms/step - loss: 4.4908 - acc: 0.8834 - f1_score: 0.8832 - val_loss: 4.4687 - val_acc: 0.8890 - val_f1_score: 0.8891
# Epoch 26/100
# 258/258 [==============================] - 76s 295ms/step - loss: 4.4641 - acc: 0.8808 - f1_score: 0.8807 - val_loss: 4.6618 - val_acc: 0.8856 - val_f1_score: 0.8835
# Epoch 27/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.3625 - acc: 0.8879 - f1_score: 0.8877 - val_loss: 4.4406 - val_acc: 0.9036 - val_f1_score: 0.9037
# Epoch 28/100
# 258/258 [==============================] - 75s 292ms/step - loss: 4.4039 - acc: 0.8873 - f1_score: 0.8871 - val_loss: 4.5427 - val_acc: 0.8902 - val_f1_score: 0.8905
# Epoch 29/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.3625 - acc: 0.8884 - f1_score: 0.8882 - val_loss: 4.2129 - val_acc: 0.9118 - val_f1_score: 0.9115
# Epoch 30/100
# 258/258 [==============================] - 77s 300ms/step - loss: 4.3262 - acc: 0.8847 - f1_score: 0.8846 - val_loss: 4.2526 - val_acc: 0.9154 - val_f1_score: 0.9152
# Epoch 31/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.2971 - acc: 0.8916 - f1_score: 0.8915 - val_loss: 4.3400 - val_acc: 0.9072 - val_f1_score: 0.9073
# Epoch 32/100
# 258/258 [==============================] - 76s 296ms/step - loss: 4.2761 - acc: 0.8969 - f1_score: 0.8967 - val_loss: 4.2393 - val_acc: 0.9055 - val_f1_score: 0.9055
# Epoch 33/100
# 258/258 [==============================] - 78s 301ms/step - loss: 4.2738 - acc: 0.8931 - f1_score: 0.8929 - val_loss: 4.2902 - val_acc: 0.9108 - val_f1_score: 0.9111
# Epoch 34/100
# 258/258 [==============================] - 76s 296ms/step - loss: 4.2708 - acc: 0.8962 - f1_score: 0.8961 - val_loss: 4.2902 - val_acc: 0.9215 - val_f1_score: 0.9212
# Epoch 35/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.2380 - acc: 0.8942 - f1_score: 0.8940 - val_loss: 4.1720 - val_acc: 0.9239 - val_f1_score: 0.9240
# Epoch 36/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.1964 - acc: 0.8991 - f1_score: 0.8991 - val_loss: 4.2878 - val_acc: 0.9140 - val_f1_score: 0.9140
# Epoch 37/100
# 258/258 [==============================] - 75s 292ms/step - loss: 4.1420 - acc: 0.9003 - f1_score: 0.9001 - val_loss: 4.0079 - val_acc: 0.9256 - val_f1_score: 0.9256
# Epoch 38/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.1089 - acc: 0.9018 - f1_score: 0.9017 - val_loss: 3.9892 - val_acc: 0.9215 - val_f1_score: 0.9218
# Epoch 39/100
# 258/258 [==============================] - 76s 294ms/step - loss: 4.0852 - acc: 0.9036 - f1_score: 0.9035 - val_loss: 3.9747 - val_acc: 0.9072 - val_f1_score: 0.9069
# Epoch 40/100
# 258/258 [==============================] - 75s 293ms/step - loss: 4.0622 - acc: 0.9033 - f1_score: 0.9031 - val_loss: 4.2466 - val_acc: 0.9157 - val_f1_score: 0.9159
# Epoch 41/100
# 258/258 [==============================] - 77s 297ms/step - loss: 4.0451 - acc: 0.9077 - f1_score: 0.9076 - val_loss: 4.0535 - val_acc: 0.9239 - val_f1_score: 0.9239
# Epoch 42/100
# 258/258 [==============================] - 75s 291ms/step - loss: 3.9936 - acc: 0.9029 - f1_score: 0.9028 - val_loss: 3.8483 - val_acc: 0.9188 - val_f1_score: 0.9189
# Epoch 43/100
# 258/258 [==============================] - 73s 283ms/step - loss: 3.9742 - acc: 0.9066 - f1_score: 0.9065 - val_loss: 3.7956 - val_acc: 0.9113 - val_f1_score: 0.9107
# Epoch 44/100
# 258/258 [==============================] - 74s 287ms/step - loss: 3.9428 - acc: 0.9077 - f1_score: 0.9076 - val_loss: 3.9761 - val_acc: 0.9251 - val_f1_score: 0.9250
# Epoch 45/100
# 258/258 [==============================] - 76s 293ms/step - loss: 3.9383 - acc: 0.9071 - f1_score: 0.9070 - val_loss: 3.9461 - val_acc: 0.9106 - val_f1_score: 0.9103
# Epoch 46/100
# 258/258 [==============================] - 75s 291ms/step - loss: 3.9162 - acc: 0.9095 - f1_score: 0.9094 - val_loss: 3.9916 - val_acc: 0.9256 - val_f1_score: 0.9257
# Epoch 47/100
# 258/258 [==============================] - 75s 289ms/step - loss: 3.8810 - acc: 0.9096 - f1_score: 0.9095 - val_loss: 3.6488 - val_acc: 0.9246 - val_f1_score: 0.9248
# Epoch 48/100
# 258/258 [==============================] - 75s 291ms/step - loss: 3.8053 - acc: 0.9109 - f1_score: 0.9109 - val_loss: 3.7708 - val_acc: 0.9251 - val_f1_score: 0.9254
# Epoch 49/100
# 258/258 [==============================] - 74s 285ms/step - loss: 3.8188 - acc: 0.9122 - f1_score: 0.9121 - val_loss: 3.8658 - val_acc: 0.9271 - val_f1_score: 0.9269
# Epoch 50/100
# 258/258 [==============================] - 74s 285ms/step - loss: 3.8038 - acc: 0.9121 - f1_score: 0.9121 - val_loss: 3.8721 - val_acc: 0.9278 - val_f1_score: 0.9283
# Epoch 51/100
# 258/258 [==============================] - 74s 286ms/step - loss: 3.8008 - acc: 0.9131 - f1_score: 0.9130 - val_loss: 3.7723 - val_acc: 0.9225 - val_f1_score: 0.9229
# Epoch 52/100
# 258/258 [==============================] - 74s 287ms/step - loss: 3.8100 - acc: 0.9116 - f1_score: 0.9115 - val_loss: 3.6774 - val_acc: 0.9300 - val_f1_score: 0.9301
# Epoch 53/100
# 258/258 [==============================] - 74s 289ms/step - loss: 3.7450 - acc: 0.9139 - f1_score: 0.9138 - val_loss: 3.6622 - val_acc: 0.9292 - val_f1_score: 0.9294
# Epoch 54/100
# 258/258 [==============================] - 73s 282ms/step - loss: 3.7266 - acc: 0.9180 - f1_score: 0.9179 - val_loss: 3.6691 - val_acc: 0.9290 - val_f1_score: 0.9292
# Epoch 55/100
# 258/258 [==============================] - 74s 288ms/step - loss: 3.7210 - acc: 0.9140 - f1_score: 0.9139 - val_loss: 3.5911 - val_acc: 0.9256 - val_f1_score: 0.9254
# Epoch 56/100
# 258/258 [==============================] - 74s 285ms/step - loss: 3.6659 - acc: 0.9154 - f1_score: 0.9153 - val_loss: 3.7290 - val_acc: 0.9385 - val_f1_score: 0.9387
# Epoch 57/100
# 258/258 [==============================] - 73s 284ms/step - loss: 3.6530 - acc: 0.9189 - f1_score: 0.9189 - val_loss: 3.7024 - val_acc: 0.9215 - val_f1_score: 0.9218
# Epoch 58/100
# 258/258 [==============================] - 73s 284ms/step - loss: 3.7024 - acc: 0.9139 - f1_score: 0.9139 - val_loss: 3.5843 - val_acc: 0.9213 - val_f1_score: 0.9214
# Epoch 59/100
# 258/258 [==============================] - 74s 286ms/step - loss: 3.6545 - acc: 0.9167 - f1_score: 0.9166 - val_loss: 3.6969 - val_acc: 0.9309 - val_f1_score: 0.9313
# Epoch 60/100
# 258/258 [==============================] - 73s 284ms/step - loss: 3.7029 - acc: 0.9188 - f1_score: 0.9187 - val_loss: 3.7727 - val_acc: 0.9072 - val_f1_score: 0.9058
# Epoch 61/100
# 258/258 [==============================] - 73s 284ms/step - loss: 3.6740 - acc: 0.9188 - f1_score: 0.9187 - val_loss: 3.5153 - val_acc: 0.9290 - val_f1_score: 0.9293
# Epoch 62/100
# 258/258 [==============================] - 74s 286ms/step - loss: 3.6761 - acc: 0.9161 - f1_score: 0.9160 - val_loss: 3.7280 - val_acc: 0.9261 - val_f1_score: 0.9263
# Epoch 63/100
# 258/258 [==============================] - 74s 289ms/step - loss: 3.6108 - acc: 0.9229 - f1_score: 0.9228 - val_loss: 3.6338 - val_acc: 0.9380 - val_f1_score: 0.9383
# Epoch 64/100
# 258/258 [==============================] - 76s 295ms/step - loss: 3.6346 - acc: 0.9209 - f1_score: 0.9209 - val_loss: 3.6713 - val_acc: 0.9152 - val_f1_score: 0.9140
# Epoch 65/100
# 214/258 [=======================>......] - ETA: 12s - loss: 3.6353 - acc: 0.9198 - f1_score: 0.9195

# %% [markdown]
# ### Matrix de confusão

# %%
pd.DataFrame(cm, index=labels_map, columns=labels_map)

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# ## Base com SMOTE

# %%
# SMOTE
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train_balanced_smote, c_labels_train_balanced_smote, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test_smote, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test_smote, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test_smote, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')

# %% [markdown]
# ### Matrix de confusão

# %%
# matriz de confusao para base balanceada com BOOTSTRAP
pd.DataFrame(cm, index=labels_map, columns=labels_map)

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()
