# %% [markdown]
# <a href="https://colab.research.google.com/github/andssuu/moncattle/blob/master/notebooks/cnns_6_conv1d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação de bibliotecas

# %%
# !pip install --user tensorflow-addons
# restart runtime
import os
os.kill(os.getpid(), 9)
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 12.1 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
import pandas as pd
import numpy as np
from numpy import argmax
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#%matplotlib inline
plt.style.use('default')

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score, StratifiedKFold, KFold, StratifiedShuffleSplit
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, confusion_matrix, f1_score
from sklearn import metrics

import tensorflow_addons as tfa

from imblearn.over_sampling import SMOTE

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Reshape, BatchNormalization, Dropout, LayerNormalization, Activation, Input, ReLU, Add, DepthwiseConv2D, Conv1D
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import *
from tensorflow.keras.activations import *
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
import tensorflow as tf
tf.get_logger().setLevel('ERROR')
from tensorflow.keras import initializers
from tensorflow import Tensor
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from keras.initializers import glorot_uniform

# ignore all future warnings
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
from collections import Counter

seed = 1
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# # Leitura dos dados

# %%
# !git clone https://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@github.com/andssuu/moncattle.git
# Out:
# Cloning into 'moncattle'...
# remote: Enumerating objects: 1291, done.
# remote: Counting objects: 100% (1291/1291), done.
# remote: Compressing objects: 100% (1141/1141), done.
# remote: Total 1291 (delta 805), reused 167 (delta 65), pack-reused 0
# Receiving objects: 100% (1291/1291), 38.41 MiB | 5.48 MiB/s, done.
# Resolving deltas: 100% (805/805), done.

# %%
df = pd.read_csv("moncattle/data/dataset_6.csv", float_precision='high')
df_data = df.loc[:, ['acc_x', 'acc_y', 'acc_z', 'gir_x', 'gir_y', 'gir_z', 'mag_x', 'mag_y', 'mag_z', 'displacement_speed', 'label']]
df_data
# Out:
#        acc_x  acc_y  acc_z  gir_x  gir_y  gir_z  mag_x  mag_y  mag_z  \
# 0       1157   9002 -12840    243    195   -466   -460   1575   -205
# 1       1226   9986 -12546   -492   2209  -2189   -463   1585   -264
# 2        870   8224 -13117    590   -712    179   -527   1537   -248
# 3       2024   9428 -12521    212    662   -893   -515   1544   -226
# 4       1698   8163 -12980   1409     81    826   -501   1553   -281
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 13083  -1776   3679  -8874  -1623  -1838  -7536    615   1048   -310
# 13084   3468  14178 -12207  -3882   7653   2397    299    -25  -1089
# 13085  -6229  11638 -11286   1982  -1144    359  -1047   1164    599
# 13086  -2267  12908  -7665   2458  -1275  -1757  -1498    940    223
# 13087   2152   7619  -7736  -2980   3678  -1357  -1650    788     43
#
#        displacement_speed           label
# 0                     0.0  EmPe-Ruminando
# 1                     0.0  EmPe-Ruminando
# 2                     0.0  EmPe-Ruminando
# 3                     0.0  EmPe-Ruminando
# 4                     0.0  EmPe-Ruminando
# ...                   ...             ...
# 13083                 0.0        Pastando
# 13084                 0.0        Pastando
# 13085                 0.0        Pastando
# 13086                 0.0        Pastando
# 13087                 0.0        Pastando
#
# [13088 rows x 11 columns]

# %% [markdown]
# # Bases de treino e teste

# %%
data_train, data_test=train_test_split(df_data, test_size=0.4, random_state=seed, shuffle=True, stratify=df_data.iloc[:, -1])

# %%
data_train
# Out:
#        acc_x  acc_y  acc_z  gir_x  gir_y  gir_z  mag_x  mag_y  mag_z  \
# 10828   2597   4332 -13120    165   -303    297   -859   -943   -901
# 2917   -4986   5327 -12556   3847  -2034   2658    233   1628   -808
# 4901    4584   6297 -13411    301   -365    235   -662    -71  -1327
# 7789    9484   7361  -9784    360    908    138    734    724    538
# 514   -10408   9109 -12190  -1080  -5284  -1800   1032   1336   -529
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2029    1272  12118  -9678   3302   3764   1273    707    122  -1399
# 7620    6900   8807 -10525    -30    903    103  -1074    205  -1036
# 3736    5875   9050 -11423    518   -200     52    315   2395    704
# 4184   -6550   3759 -14521   1561   -917  -1021    759   1522   -457
# 7760    8419   7450 -10174   -133    914    291    776    706    449
#
#        displacement_speed              label
# 10828                 0.0        EmPe-Parado
# 2917                  0.0           Pastando
# 4901                  0.0        EmPe-Parado
# 7789                  0.0  Deitado-Ruminando
# 514                   0.0           Pastando
# ...                   ...                ...
# 2029                  2.9            Andando
# 7620                  0.0        EmPe-Parado
# 3736                  0.0  Deitado-Ruminando
# 4184                  0.0           Pastando
# 7760                  0.0  Deitado-Ruminando
#
# [7852 rows x 11 columns]

# %%
data_test
# Out:
#        acc_x  acc_y  acc_z  gir_x  gir_y  gir_z  mag_x  mag_y  mag_z  \
# 10910  -7029   -925 -14211   5011  -4076   5066   -536  -1126   -783
# 12352   5342   8473  -9971    558    385   -185  -1404    229   -861
# 5426    8846   7370 -10938    166   -420    229    737   1590   -113
# 6095    7820   9234  -9384   -677    648    351   -833     63  -1189
# 8312    1230   5861 -13535  -2821   -444   1281    815   -629   -541
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2281  -10243   3254  -8512   -828    984  -2425    -96   1586   -686
# 9329    2721   7331 -12368    404    276     28   1027    231   -236
# 12090   5305   7863 -11373     80     98     56  -1363    654   -624
# 7193    6456  10383  -9458    207    972    180   -562   1504    452
# 4797  -12538  13197 -10616  -2211  -9130   3770    -67   1361    119
#
#        displacement_speed           label
# 10910                 0.0        Pastando
# 12352                 0.0     EmPe-Parado
# 5426                  0.0  Deitado-Parado
# 6095                  0.0     EmPe-Parado
# 8312                  2.5         Andando
# ...                   ...             ...
# 2281                  0.0        Pastando
# 9329                  0.0  EmPe-Ruminando
# 12090                 0.0     EmPe-Parado
# 7193                  0.0  Deitado-Parado
# 4797                  0.0        Pastando
#
# [5236 rows x 11 columns]

# %% [markdown]
# ## Quantidade total de amostras na base completa

# %%
df_data['label'].value_counts()
# Out:
# Pastando             5732
# Deitado-Ruminando    2034
# Deitado-Parado       1702
# EmPe-Parado          1559
# Andando              1229
# EmPe-Ruminando        832
# Name: label, dtype: int64

# %% [markdown]
# ## Quantidade total de amostras na base de treino

# %%
data_train['label'].value_counts()
# Out:
# Pastando             3439
# Deitado-Ruminando    1220
# Deitado-Parado       1021
# EmPe-Parado           935
# Andando               738
# EmPe-Ruminando        499
# Name: label, dtype: int64

# %% [markdown]
# ## Quantidade total de amostras na base de teste

# %%
data_test['label'].value_counts()
# Out:
# Pastando             2293
# Deitado-Ruminando     814
# Deitado-Parado        681
# EmPe-Parado           624
# Andando               491
# EmPe-Ruminando        333
# Name: label, dtype: int64

# %% [markdown]
# ## Formatação dos tensores

# %%
labels_map = {"Pastando": 0, "Deitado-Ruminando": 1, "Deitado-Parado": 2, "EmPe-Parado": 3, "Andando": 4, "EmPe-Ruminando": 5}
r_reshape, c_reshape = 1, 10

# normalizaçao dos dados da base original
_data_train, _data_test = data_train.copy(), data_test.copy()
_mean = _data_train.iloc[:, :-1].mean()
_std = _data_test.iloc[:, :-1].std()
_data_train.iloc[:, :-1] = (_data_train.iloc[:, :-1] - _mean) / _std
_data_test.iloc[:, :-1] = (_data_test.iloc[:, :-1] - _mean) / _std

# reshape data to fit model
t_data_train = _data_train.iloc[:, :-1].values.reshape(_data_train.shape[0], r_reshape, c_reshape, 1)
t_data_test = _data_test.iloc[:, :-1].values.reshape(_data_test.shape[0], r_reshape, c_reshape, 1)
print(t_data_train.shape, t_data_test.shape)

_labels_train = np.array(list(map(lambda x: labels_map[x], data_train.iloc[:, -1])))
c_labels_train = to_categorical(_labels_train)

_labels_test = np.array(list(map(lambda x: labels_map[x], data_test.iloc[:, -1])))
c_labels_test = to_categorical(_labels_test)
# Out:
# (7852, 1, 10, 1) (5236, 1, 10, 1)

# %% [markdown]
# ### Reamostragem BOOTSTRAP

# %%
# BOOTSTRAP
_data=data_train.copy()
count_class_0, count_class_1, count_class_2, count_class_3, count_class_4, count_class_5 = _data['label'].value_counts()
# print(count_class_0, count_class_1, count_class_2, count_class_3)

df_class_0=_data[_data['label']=='Pastando']
df_class_1=_data[_data['label']=='Deitado-Ruminando']
df_class_2=_data[_data['label']=='Deitado-Parado']
df_class_3=_data[_data['label']=='EmPe-Parado']
df_class_4=_data[_data['label']=='Andando']
df_class_5=_data[_data['label']=='EmPe-Ruminando']

df_class_1_under=df_class_1.sample(count_class_0, replace=True, random_state=seed)
df_class_2_under=df_class_2.sample(count_class_0, replace=True, random_state=seed)
df_class_3_under=df_class_3.sample(count_class_0, replace=True, random_state=seed)
df_class_4_under=df_class_4.sample(count_class_0, replace=True, random_state=seed)
df_class_5_under=df_class_5.sample(count_class_0, replace=True, random_state=seed)

data_balanced_bootstrap=pd.concat([df_class_0, df_class_1_under, df_class_2_under, df_class_3_under, df_class_4_under, df_class_5_under], axis=0).reset_index(drop=True)
_mean = data_balanced_bootstrap.iloc[:, :-1].mean()
_std = data_balanced_bootstrap.iloc[:, :-1].std()
data_balanced_bootstrap.iloc[:, :-1] = (data_balanced_bootstrap.iloc[:, :-1] - _mean) / _std
_shuffle_bootstrap=np.random.RandomState(seed=seed).permutation(len(data_balanced_bootstrap))
t_data_train_balanced_bootstrap=data_balanced_bootstrap.iloc[:, :-1].values[_shuffle_bootstrap].reshape(data_balanced_bootstrap.shape[0], r_reshape, c_reshape, 1)
labels_train_balanced_bootstrap=np.array(list(map(lambda x: labels_map[x], data_balanced_bootstrap.iloc[:, -1].values[_shuffle_bootstrap])))
c_labels_train_balanced_bootstrap=to_categorical(labels_train_balanced_bootstrap)

data_test_bootstrap = data_test.copy()
data_test_bootstrap.iloc[:, :-1] = (data_test_bootstrap.iloc[:, :-1] - _mean) / _std
t_data_test_bootstrap = data_test_bootstrap.iloc[:, :-1].values.reshape(data_test_bootstrap.shape[0], r_reshape, c_reshape, 1)

print(t_data_train_balanced_bootstrap.shape, c_labels_train_balanced_bootstrap.shape, t_data_test_bootstrap.shape, c_labels_test.shape)
# Out:
# (20634, 1, 10, 1) (20634, 6) (5236, 1, 10, 1) (5236, 6)

# %% [markdown]
# ### Reamostragem SMOTE

# %%
# SMOTE
_data = data_train.copy()
smote = SMOTE(sampling_strategy='not majority', random_state=seed, k_neighbors=5)
data_balanced_smote, _label_balanced_smote = smote.fit_resample(_data.iloc[:, :-1].values, _data.iloc[:, -1].values)
_shuffle_smote = np.random.RandomState(seed=seed).permutation(len(data_balanced_smote))

data_balanced_smote = pd.DataFrame(data_balanced_smote[_shuffle_smote], columns=data_train.columns[:-1])
_mean = data_balanced_smote.mean()
_std = data_balanced_smote.std()
data_balanced_smote = (data_balanced_smote- _mean) / _std

t_data_train_balanced_smote = data_balanced_smote.values.reshape(data_balanced_smote.shape[0], r_reshape, c_reshape, 1)
label_balanced_smote = np.array(list(map(lambda x: labels_map[x], _label_balanced_smote[_shuffle_smote])))
c_labels_train_balanced_smote = to_categorical(label_balanced_smote)

data_test_smote = data_test.copy()
data_test_smote.iloc[:, :-1] = (data_test_smote.iloc[:, :-1] - _mean) / _std
t_data_test_smote = data_test_smote.iloc[:, :-1].values.reshape(data_test_smote.shape[0], r_reshape, c_reshape, 1)

print(t_data_train_balanced_smote.shape, c_labels_train_balanced_smote.shape, t_data_test_smote.shape, c_labels_test.shape)
_l = pd.DataFrame(_label_balanced_smote, columns=['label'])
print(_l.value_counts())
_l.value_counts().plot(kind='bar', title='Reamostragem com classe majoritária')
# Out:
# (20634, 1, 10, 1) (20634, 6) (5236, 1, 10, 1) (5236, 6)
# label
# Andando              3439
# Deitado-Parado       3439
# Deitado-Ruminando    3439
# EmPe-Parado          3439
# EmPe-Ruminando       3439
# Pastando             3439
# dtype: int64

# %% [markdown]
# ### Visualização dos inputs

# %%
plt.style.use('default')
fig = plt.figure()
for i in range(6):
  plt.subplot(3, 2, i+1)
  plt.tight_layout()
  plt.imshow(t_data_train[i].reshape(r_reshape, c_reshape), cmap='gray', interpolation='none')
  plt.title("Rótulo: {}".format(list(labels_map.keys())[list(labels_map.values()).index(argmax(c_labels_train[i]))]))
  plt.xticks([])
  plt.yticks([])

# %%
plt.style.use('default')
plt.imshow(t_data_train[0].reshape(r_reshape, c_reshape), cmap='gray')
plt.title(list(labels_map.keys())[list(labels_map.values()).index(argmax(c_labels_train[0]))])
# Out:
# Text(0.5, 1.0, 'EmPe-Parado')

# %%
def visualize_input(window, ax): 
    window = window * 255
    img = np.uint8(window)
    ax.imshow(img, cmap='gray')
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            #ax.annotate(str(round(img[x][y],2)), xy=(y,x),
            ax.annotate(str(img[x][y]), xy=(y,x),
                        horizontalalignment='center',
                        verticalalignment='center',
                        color='white' if img[x][y]<thresh else 'black')
plt.style.use('default')
fig = plt.figure(figsize = (12,12))
plt.title('Label: {}'.format(list(labels_map.keys())[list(labels_map.values()).index(argmax(c_labels_train[0]))]))
ax=fig.add_subplot(111)
visualize_input(t_data_train[0].reshape(r_reshape, c_reshape), ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# # CNN (dissertação)

# %%
epochs=100
batch_size=64
feature_dimensions=1024
input_shape=(32, 32, 1)
n_classes=6
labels_map = {"Pastando": 0, "Deitado-Ruminando": 1, "Deitado-Parado": 2, "EmPe-Parado": 3, "Andando": 4, "EmPe-Ruminando": 5}

def create_cnn():
    model = Sequential([
        Flatten(input_shape=(1, 10, 1)),
        Dense(feature_dimensions, activation='relu', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Reshape(input_shape, input_shape=(feature_dimensions,)),
        Conv1D(32, kernel_size=32, activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2), strides=2),
        Dropout(0.2, seed=seed),
        Conv1D(96, kernel_size=16, activation='relu', padding='same', kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2), strides=2),
        Dropout(0.2, seed=seed),
        Flatten(),
        Dense(384, activation='relu', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Dropout(0.2, seed=seed),
        Dense(128, activation='relu', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed)),
        BatchNormalization(),
        Dropout(0.2, seed=seed),
        Dense(n_classes, activation='softmax', kernel_regularizer=regularizers.l1(0.01), kernel_initializer=initializers.glorot_uniform(seed=seed))
    ])
    model.reset_metrics()
    optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False)
    #optimizer=SGD(learning_rate=0.005, momentum=0.9, nesterov=False, name="SGD")
    #optimizer=RMSprop(learning_rate=0.001, rho=0.9, momentum=0.9, epsilon=1e-07, centered=False, name="RMSprop")
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['acc', tfa.metrics.F1Score(num_classes=n_classes, name='f1_score', average='macro')])
    return model

def show_classification_report(results, n_splits):
    #print("Acurácia média: {:.4f}".format(np.mean(acc_per_fold)))
    #print("Desvio Padrão: {:}\n\n".format(np.std(acc_per_fold)))
    print('''\t\t        precision      recall     f1-score\n
        Pastando          {:.2f}        {:.2f}      {:.2f}
        Deitado-Ruminando {:.2f}        {:.2f}      {:.2f}
        Deitado-Parado    {:.2f}        {:.2f}      {:.2f}
        EmPe-Parado       {:.2f}        {:.2f}      {:.2f}
        Andando           {:.2f}        {:.2f}      {:.2f}
        EmPe-Ruminando    {:.2f}        {:.2f}      {:.2f}
        macro avg         {:.2f}        {:.2f}      {:.2f}
        accuracy          {:.2f}
    '''.format(
        100*results['Pastando']['precision']/n_splits, 100*results['Pastando']['recall']/n_splits, 100*results['Pastando']['f1-score']/n_splits,
        100*results['Deitado-Ruminando']['precision']/n_splits, 100*results['Deitado-Ruminando']['recall']/n_splits, 100*results['Deitado-Ruminando']['f1-score']/n_splits,
        100*results['Deitado-Parado']['precision']/n_splits, 100*results['Deitado-Parado']['recall']/n_splits, 100*results['Deitado-Parado']['f1-score']/n_splits,
        100*results['EmPe-Parado']['precision']/n_splits, 100*results['EmPe-Parado']['recall']/n_splits, 100*results['EmPe-Parado']['f1-score']/n_splits,
        100*results['Andando']['precision']/n_splits, 100*results['Andando']['recall']/n_splits, 100*results['Andando']['f1-score']/n_splits,
        100*results['EmPe-Ruminando']['precision']/n_splits, 100*results['EmPe-Ruminando']['recall']/n_splits, 100*results['EmPe-Ruminando']['f1-score']/n_splits,
        100*results['macro avg']['precision']/n_splits, 100*results['macro avg']['recall']/n_splits, 100*results['macro avg']['f1-score']/n_splits,
        100*results['accuracy']/n_splits
        )
    )

def update_report(results, new_results):
    for k in new_results.keys():
        if type(new_results[k]) is dict:
            for _k in results[k].keys():
                results[k][_k]+=new_results[k][_k]
        else:
            results[k] += new_results[k]
create_cnn().summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_10 (Flatten)        (None, 10)                0
#
#  dense_18 (Dense)            (None, 1024)              11264
#
#  batch_normalization_22 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  reshape_6 (Reshape)         (None, 32, 32, 1)         0
#
#  conv1d_9 (Conv1D)           (None, 32, 32, 32)        1056
#
#  batch_normalization_23 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_16 (Dropout)        (None, 16, 16, 32)        0
#
#  conv1d_10 (Conv1D)          (None, 16, 16, 96)        49248
#
#  batch_normalization_24 (Bat  (None, 16, 16, 96)       384
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  dropout_17 (Dropout)        (None, 8, 8, 96)          0
#
#  flatten_11 (Flatten)        (None, 6144)              0
#
#  dense_19 (Dense)            (None, 384)               2359680
#
#  batch_normalization_25 (Bat  (None, 384)              1536
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 384)               0
#
#  dense_20 (Dense)            (None, 128)               49280
#
#  batch_normalization_26 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 2,477,958
# Trainable params: 2,474,630
# Non-trainable params: 3,328
# _________________________________________________________________

# %% [markdown]
# ## Base original

# %%
# ORIGINAL
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train, c_labels_train, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 99/99 [==============================] - 6s 35ms/step - loss: 83.6364 - acc: 0.6636 - f1_score: 0.5444 - val_loss: 23.3836 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 2/100
# 99/99 [==============================] - 3s 27ms/step - loss: 16.2695 - acc: 0.7118 - f1_score: 0.5916 - val_loss: 12.9628 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 3/100
# 99/99 [==============================] - 3s 28ms/step - loss: 10.4516 - acc: 0.7357 - f1_score: 0.6101 - val_loss: 9.2282 - val_acc: 0.4252 - val_f1_score: 0.0994
# Epoch 4/100
# 99/99 [==============================] - 3s 30ms/step - loss: 7.4018 - acc: 0.7596 - f1_score: 0.6352 - val_loss: 8.6808 - val_acc: 0.4297 - val_f1_score: 0.1233
# Epoch 5/100
# 99/99 [==============================] - 3s 29ms/step - loss: 7.4163 - acc: 0.7763 - f1_score: 0.6558 - val_loss: 7.2751 - val_acc: 0.5863 - val_f1_score: 0.3522
# Epoch 6/100
# 99/99 [==============================] - 3s 29ms/step - loss: 6.3067 - acc: 0.7803 - f1_score: 0.6605 - val_loss: 5.9710 - val_acc: 0.7199 - val_f1_score: 0.5372
# Epoch 7/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.8938 - acc: 0.7900 - f1_score: 0.6827 - val_loss: 6.1107 - val_acc: 0.7919 - val_f1_score: 0.6491
# Epoch 8/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.7033 - acc: 0.8010 - f1_score: 0.7007 - val_loss: 5.7212 - val_acc: 0.7588 - val_f1_score: 0.6214
# Epoch 9/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.7084 - acc: 0.7967 - f1_score: 0.6937 - val_loss: 5.6538 - val_acc: 0.7428 - val_f1_score: 0.5915
# Epoch 10/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.7364 - acc: 0.8061 - f1_score: 0.7156 - val_loss: 6.7077 - val_acc: 0.5748 - val_f1_score: 0.5964
# Epoch 11/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.7975 - acc: 0.8075 - f1_score: 0.7116 - val_loss: 5.6922 - val_acc: 0.7441 - val_f1_score: 0.6247
# Epoch 12/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.7028 - acc: 0.8118 - f1_score: 0.7194 - val_loss: 6.8968 - val_acc: 0.5271 - val_f1_score: 0.6024
# Epoch 13/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.8818 - acc: 0.8185 - f1_score: 0.7248 - val_loss: 5.9019 - val_acc: 0.8230 - val_f1_score: 0.7330
# Epoch 14/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.6380 - acc: 0.8152 - f1_score: 0.7221 - val_loss: 5.5966 - val_acc: 0.7575 - val_f1_score: 0.6488
# Epoch 15/100
# 99/99 [==============================] - 3s 30ms/step - loss: 5.3541 - acc: 0.8175 - f1_score: 0.7290 - val_loss: 6.2885 - val_acc: 0.8211 - val_f1_score: 0.7494
# Epoch 16/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.7214 - acc: 0.8207 - f1_score: 0.7345 - val_loss: 6.0218 - val_acc: 0.8084 - val_f1_score: 0.7354
# Epoch 17/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.5686 - acc: 0.8242 - f1_score: 0.7407 - val_loss: 5.4830 - val_acc: 0.8415 - val_f1_score: 0.7877
# Epoch 18/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.2376 - acc: 0.8263 - f1_score: 0.7471 - val_loss: 5.4847 - val_acc: 0.7638 - val_f1_score: 0.6626
# Epoch 19/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.4117 - acc: 0.8314 - f1_score: 0.7563 - val_loss: 5.4141 - val_acc: 0.8377 - val_f1_score: 0.7860
# Epoch 20/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.3230 - acc: 0.8367 - f1_score: 0.7528 - val_loss: 7.6452 - val_acc: 0.3603 - val_f1_score: 0.4432
# Epoch 21/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.9150 - acc: 0.8257 - f1_score: 0.7440 - val_loss: 6.2251 - val_acc: 0.7314 - val_f1_score: 0.6513
# Epoch 22/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.6110 - acc: 0.8339 - f1_score: 0.7541 - val_loss: 5.2650 - val_acc: 0.8103 - val_f1_score: 0.7394
# Epoch 23/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.1010 - acc: 0.8371 - f1_score: 0.7577 - val_loss: 6.9384 - val_acc: 0.4036 - val_f1_score: 0.4863
# Epoch 24/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.3999 - acc: 0.8295 - f1_score: 0.7460 - val_loss: 6.0199 - val_acc: 0.7218 - val_f1_score: 0.6967
# Epoch 25/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.3040 - acc: 0.8343 - f1_score: 0.7547 - val_loss: 5.0165 - val_acc: 0.7740 - val_f1_score: 0.6527
# Epoch 26/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.0386 - acc: 0.8422 - f1_score: 0.7636 - val_loss: 5.4431 - val_acc: 0.8428 - val_f1_score: 0.7800
# Epoch 27/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.2128 - acc: 0.8448 - f1_score: 0.7691 - val_loss: 5.6111 - val_acc: 0.8332 - val_f1_score: 0.7721
# Epoch 28/100
# 99/99 [==============================] - 3s 29ms/step - loss: 5.2733 - acc: 0.8433 - f1_score: 0.7698 - val_loss: 5.6418 - val_acc: 0.8186 - val_f1_score: 0.6977
# Epoch 29/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.0572 - acc: 0.8459 - f1_score: 0.7712 - val_loss: 4.8504 - val_acc: 0.8109 - val_f1_score: 0.7332
# Epoch 30/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.8439 - acc: 0.8465 - f1_score: 0.7741 - val_loss: 5.5840 - val_acc: 0.8084 - val_f1_score: 0.7529
# Epoch 31/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.2166 - acc: 0.8457 - f1_score: 0.7706 - val_loss: 6.0548 - val_acc: 0.7753 - val_f1_score: 0.7364
# Epoch 32/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.3560 - acc: 0.8535 - f1_score: 0.7847 - val_loss: 5.6811 - val_acc: 0.7562 - val_f1_score: 0.6077
# Epoch 33/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.2352 - acc: 0.8456 - f1_score: 0.7683 - val_loss: 5.0279 - val_acc: 0.7613 - val_f1_score: 0.6163
# Epoch 34/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.7763 - acc: 0.8389 - f1_score: 0.7606 - val_loss: 4.7376 - val_acc: 0.8434 - val_f1_score: 0.7740
# Epoch 35/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.6834 - acc: 0.8518 - f1_score: 0.7806 - val_loss: 5.6880 - val_acc: 0.6983 - val_f1_score: 0.6222
# Epoch 36/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.9152 - acc: 0.8488 - f1_score: 0.7718 - val_loss: 5.8646 - val_acc: 0.8078 - val_f1_score: 0.7298
# Epoch 37/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.1924 - acc: 0.8460 - f1_score: 0.7757 - val_loss: 4.7892 - val_acc: 0.8250 - val_f1_score: 0.7189
# Epoch 38/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.6065 - acc: 0.8513 - f1_score: 0.7821 - val_loss: 5.2436 - val_acc: 0.8358 - val_f1_score: 0.7922
# Epoch 39/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.7151 - acc: 0.8550 - f1_score: 0.7876 - val_loss: 4.6315 - val_acc: 0.8351 - val_f1_score: 0.7744
# Epoch 40/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.5161 - acc: 0.8519 - f1_score: 0.7817 - val_loss: 4.9316 - val_acc: 0.8530 - val_f1_score: 0.8061
# Epoch 41/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.5837 - acc: 0.8612 - f1_score: 0.7930 - val_loss: 4.8176 - val_acc: 0.8351 - val_f1_score: 0.7596
# Epoch 42/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.5171 - acc: 0.8545 - f1_score: 0.7807 - val_loss: 5.1294 - val_acc: 0.8619 - val_f1_score: 0.8010
# Epoch 43/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.8251 - acc: 0.8596 - f1_score: 0.7950 - val_loss: 5.3360 - val_acc: 0.7594 - val_f1_score: 0.7403
# Epoch 44/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.7629 - acc: 0.8629 - f1_score: 0.7987 - val_loss: 4.8997 - val_acc: 0.8313 - val_f1_score: 0.7682
# Epoch 45/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.5430 - acc: 0.8615 - f1_score: 0.7949 - val_loss: 5.1816 - val_acc: 0.7893 - val_f1_score: 0.7162
# Epoch 46/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.7578 - acc: 0.8572 - f1_score: 0.7887 - val_loss: 4.3468 - val_acc: 0.8339 - val_f1_score: 0.7720
# Epoch 47/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.3751 - acc: 0.8511 - f1_score: 0.7799 - val_loss: 4.5402 - val_acc: 0.8109 - val_f1_score: 0.6958
# Epoch 48/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.3177 - acc: 0.8620 - f1_score: 0.7923 - val_loss: 5.5039 - val_acc: 0.6754 - val_f1_score: 0.6820
# Epoch 49/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.6675 - acc: 0.8610 - f1_score: 0.7906 - val_loss: 4.6486 - val_acc: 0.8491 - val_f1_score: 0.7981
# Epoch 50/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.3422 - acc: 0.8632 - f1_score: 0.7968 - val_loss: 4.6081 - val_acc: 0.8657 - val_f1_score: 0.8187
# Epoch 51/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.5085 - acc: 0.8618 - f1_score: 0.7955 - val_loss: 6.3451 - val_acc: 0.7568 - val_f1_score: 0.7555
# Epoch 52/100
# 99/99 [==============================] - 3s 27ms/step - loss: 5.3468 - acc: 0.8615 - f1_score: 0.7978 - val_loss: 5.4604 - val_acc: 0.8345 - val_f1_score: 0.7813
# Epoch 53/100
# 99/99 [==============================] - 3s 28ms/step - loss: 5.2397 - acc: 0.8596 - f1_score: 0.7939 - val_loss: 4.5495 - val_acc: 0.8402 - val_f1_score: 0.7693
# Epoch 54/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.3216 - acc: 0.8718 - f1_score: 0.8102 - val_loss: 4.3684 - val_acc: 0.8555 - val_f1_score: 0.8029
# Epoch 55/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.2619 - acc: 0.8701 - f1_score: 0.8092 - val_loss: 4.6224 - val_acc: 0.8453 - val_f1_score: 0.7915
# Epoch 56/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.4425 - acc: 0.8671 - f1_score: 0.8043 - val_loss: 4.5892 - val_acc: 0.8453 - val_f1_score: 0.7853
# Epoch 57/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.2533 - acc: 0.8755 - f1_score: 0.8128 - val_loss: 4.9421 - val_acc: 0.8447 - val_f1_score: 0.7951
# Epoch 58/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.7017 - acc: 0.8667 - f1_score: 0.8035 - val_loss: 4.6884 - val_acc: 0.8351 - val_f1_score: 0.7694
# Epoch 59/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.4618 - acc: 0.8651 - f1_score: 0.8007 - val_loss: 4.6894 - val_acc: 0.8587 - val_f1_score: 0.8118
# Epoch 60/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.4594 - acc: 0.8712 - f1_score: 0.8097 - val_loss: 5.4330 - val_acc: 0.6639 - val_f1_score: 0.6944
# Epoch 61/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.7184 - acc: 0.8624 - f1_score: 0.7973 - val_loss: 4.8296 - val_acc: 0.8466 - val_f1_score: 0.7930
# Epoch 62/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.4799 - acc: 0.8752 - f1_score: 0.8089 - val_loss: 4.6846 - val_acc: 0.8600 - val_f1_score: 0.8094
# Epoch 63/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.4923 - acc: 0.8785 - f1_score: 0.8182 - val_loss: 4.9441 - val_acc: 0.7645 - val_f1_score: 0.6686
# Epoch 64/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.5955 - acc: 0.8661 - f1_score: 0.7971 - val_loss: 4.8321 - val_acc: 0.8472 - val_f1_score: 0.7842
# Epoch 65/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.5030 - acc: 0.8640 - f1_score: 0.7970 - val_loss: 4.7346 - val_acc: 0.8542 - val_f1_score: 0.7990
# Epoch 66/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.5823 - acc: 0.8723 - f1_score: 0.8102 - val_loss: 4.4889 - val_acc: 0.8530 - val_f1_score: 0.7823
# Epoch 67/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.2718 - acc: 0.8771 - f1_score: 0.8153 - val_loss: 4.6735 - val_acc: 0.8619 - val_f1_score: 0.8148
# Epoch 68/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.4149 - acc: 0.8737 - f1_score: 0.8134 - val_loss: 4.5181 - val_acc: 0.8409 - val_f1_score: 0.7898
# Epoch 69/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.3696 - acc: 0.8737 - f1_score: 0.8135 - val_loss: 4.5387 - val_acc: 0.8663 - val_f1_score: 0.8113
# Epoch 70/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.2752 - acc: 0.8771 - f1_score: 0.8145 - val_loss: 4.8312 - val_acc: 0.8574 - val_f1_score: 0.8093
# Epoch 71/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.8871 - acc: 0.8803 - f1_score: 0.8255 - val_loss: 5.0592 - val_acc: 0.8281 - val_f1_score: 0.7617
# Epoch 72/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.7423 - acc: 0.8747 - f1_score: 0.8091 - val_loss: 4.7432 - val_acc: 0.8479 - val_f1_score: 0.7925
# Epoch 73/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.4143 - acc: 0.8760 - f1_score: 0.8147 - val_loss: 4.7191 - val_acc: 0.8498 - val_f1_score: 0.8043
# Epoch 74/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.3426 - acc: 0.8725 - f1_score: 0.8074 - val_loss: 4.1300 - val_acc: 0.8561 - val_f1_score: 0.8023
# Epoch 75/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.0593 - acc: 0.8819 - f1_score: 0.8242 - val_loss: 4.6489 - val_acc: 0.8606 - val_f1_score: 0.8096
# Epoch 76/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.2250 - acc: 0.8782 - f1_score: 0.8195 - val_loss: 4.7072 - val_acc: 0.7435 - val_f1_score: 0.6192
# Epoch 77/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.5104 - acc: 0.8733 - f1_score: 0.8120 - val_loss: 4.3665 - val_acc: 0.8549 - val_f1_score: 0.8080
# Epoch 78/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.1278 - acc: 0.8890 - f1_score: 0.8334 - val_loss: 5.0715 - val_acc: 0.8377 - val_f1_score: 0.7771
# Epoch 79/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.7482 - acc: 0.8761 - f1_score: 0.8152 - val_loss: 4.4939 - val_acc: 0.8651 - val_f1_score: 0.8151
# Epoch 80/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.2076 - acc: 0.8881 - f1_score: 0.8310 - val_loss: 4.2236 - val_acc: 0.8447 - val_f1_score: 0.7918
# Epoch 81/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.1390 - acc: 0.8862 - f1_score: 0.8319 - val_loss: 4.4163 - val_acc: 0.8631 - val_f1_score: 0.8106
# Epoch 82/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.2689 - acc: 0.8795 - f1_score: 0.8199 - val_loss: 4.0757 - val_acc: 0.8676 - val_f1_score: 0.8252
# Epoch 83/100
# 99/99 [==============================] - 3s 29ms/step - loss: 3.9856 - acc: 0.8866 - f1_score: 0.8307 - val_loss: 5.1138 - val_acc: 0.8460 - val_f1_score: 0.7929
# Epoch 84/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.7179 - acc: 0.8811 - f1_score: 0.8239 - val_loss: 4.7188 - val_acc: 0.8689 - val_f1_score: 0.8249
# Epoch 85/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.6865 - acc: 0.8833 - f1_score: 0.8257 - val_loss: 4.3311 - val_acc: 0.8345 - val_f1_score: 0.7787
# Epoch 86/100
# 99/99 [==============================] - 3s 27ms/step - loss: 4.1801 - acc: 0.8865 - f1_score: 0.8336 - val_loss: 4.6932 - val_acc: 0.8294 - val_f1_score: 0.7712
# Epoch 87/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.3453 - acc: 0.8827 - f1_score: 0.8251 - val_loss: 4.2403 - val_acc: 0.8530 - val_f1_score: 0.8002
# Epoch 88/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.0247 - acc: 0.8889 - f1_score: 0.8347 - val_loss: 4.3342 - val_acc: 0.8740 - val_f1_score: 0.8306
# Epoch 89/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.1263 - acc: 0.8827 - f1_score: 0.8274 - val_loss: 4.2712 - val_acc: 0.8625 - val_f1_score: 0.8086
# Epoch 90/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.0578 - acc: 0.8825 - f1_score: 0.8259 - val_loss: 4.1589 - val_acc: 0.8574 - val_f1_score: 0.8022
# Epoch 91/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.0072 - acc: 0.8863 - f1_score: 0.8299 - val_loss: 4.1237 - val_acc: 0.8587 - val_f1_score: 0.8046
# Epoch 92/100
# 99/99 [==============================] - 3s 28ms/step - loss: 3.9176 - acc: 0.8854 - f1_score: 0.8277 - val_loss: 4.1625 - val_acc: 0.8708 - val_f1_score: 0.8245
# Epoch 93/100
# 99/99 [==============================] - 3s 28ms/step - loss: 3.9494 - acc: 0.8846 - f1_score: 0.8264 - val_loss: 4.4011 - val_acc: 0.8542 - val_f1_score: 0.7956
# Epoch 94/100
# 99/99 [==============================] - 3s 29ms/step - loss: 3.9899 - acc: 0.8933 - f1_score: 0.8420 - val_loss: 4.1855 - val_acc: 0.8651 - val_f1_score: 0.8181
# Epoch 95/100
# 99/99 [==============================] - 3s 28ms/step - loss: 3.9272 - acc: 0.8948 - f1_score: 0.8455 - val_loss: 4.1770 - val_acc: 0.8269 - val_f1_score: 0.7212
# Epoch 96/100
# 99/99 [==============================] - 3s 28ms/step - loss: 3.9282 - acc: 0.8857 - f1_score: 0.8298 - val_loss: 4.2909 - val_acc: 0.8587 - val_f1_score: 0.8117
# Epoch 97/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.0881 - acc: 0.8908 - f1_score: 0.8379 - val_loss: 4.2427 - val_acc: 0.8440 - val_f1_score: 0.7706
# Epoch 98/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.0084 - acc: 0.8909 - f1_score: 0.8397 - val_loss: 4.3949 - val_acc: 0.8364 - val_f1_score: 0.7848
# Epoch 99/100
# 99/99 [==============================] - 3s 28ms/step - loss: 4.1031 - acc: 0.8841 - f1_score: 0.8306 - val_loss: 4.2006 - val_acc: 0.8663 - val_f1_score: 0.8093
# Epoch 100/100
# 99/99 [==============================] - 3s 29ms/step - loss: 4.1140 - acc: 0.8940 - f1_score: 0.8454 - val_loss: 4.2471 - val_acc: 0.8555 - val_f1_score: 0.8078
# 164/164 [==============================] - 1s 7ms/step - loss: 4.3647 - acc: 0.8562 - f1_score: 0.7987
# 164/164 [==============================] - 1s 4ms/step
# Score: loss of 4.364702224731445; acc of 85.61879396438599%

# %% [markdown]
# ### Matrix de confusão

# %%
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2209                  5               7           15
# Deitado-Ruminando         8                703              82           13
# Deitado-Parado           19                113             508           32
# EmPe-Parado              55                 41              34          393
# Andando                  40                  0               0            0
# EmPe-Ruminando           15                 28              10           59
#
#                    Andando  EmPe-Ruminando
# Pastando                50               7
# Deitado-Ruminando        0               8
# Deitado-Parado           0               9
# EmPe-Parado              3              98
# Andando                451               0
# EmPe-Ruminando           2             219

# %%
plt.style.use('default')
fig, ax = plt.subplots(figsize=(15, 10))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels_map)
disp.plot(ax=ax, cmap="Reds", values_format='')

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9416    0.9634    0.9524      2293
# Deitado-Ruminando     0.7899    0.8636    0.8251       814
#    Deitado-Parado     0.7925    0.7460    0.7685       681
#       EmPe-Parado     0.7676    0.6298    0.6919       624
#           Andando     0.8913    0.9185    0.9047       491
#    EmPe-Ruminando     0.6422    0.6577    0.6499       333
#
#          accuracy                         0.8562      5236
#         macro avg     0.8042    0.7965    0.7987      5236
#      weighted avg     0.8541    0.8562    0.8539      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# ## Base com Bootstrap

# %%
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train_balanced_bootstrap, c_labels_train_balanced_bootstrap, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test_bootstrap, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test_bootstrap, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test_bootstrap, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 258/258 [==============================] - 8s 21ms/step - loss: 44.7108 - acc: 0.6300 - f1_score: 0.6273 - val_loss: 14.2089 - val_acc: 0.1730 - val_f1_score: 0.0492
# Epoch 2/100
# 258/258 [==============================] - 5s 19ms/step - loss: 9.9185 - acc: 0.7122 - f1_score: 0.7100 - val_loss: 8.4184 - val_acc: 0.6838 - val_f1_score: 0.6787
# Epoch 3/100
# 258/258 [==============================] - 5s 18ms/step - loss: 7.7545 - acc: 0.7571 - f1_score: 0.7553 - val_loss: 7.7845 - val_acc: 0.7662 - val_f1_score: 0.7639
# Epoch 4/100
# 258/258 [==============================] - 5s 18ms/step - loss: 7.1842 - acc: 0.7771 - f1_score: 0.7758 - val_loss: 6.3760 - val_acc: 0.8268 - val_f1_score: 0.8250
# Epoch 5/100
# 258/258 [==============================] - 5s 18ms/step - loss: 6.7834 - acc: 0.7911 - f1_score: 0.7900 - val_loss: 6.3969 - val_acc: 0.7892 - val_f1_score: 0.7821
# Epoch 6/100
# 258/258 [==============================] - 5s 17ms/step - loss: 6.5102 - acc: 0.8009 - f1_score: 0.8001 - val_loss: 6.1273 - val_acc: 0.8498 - val_f1_score: 0.8488
# Epoch 7/100
# 258/258 [==============================] - 5s 18ms/step - loss: 6.2826 - acc: 0.8060 - f1_score: 0.8053 - val_loss: 5.9678 - val_acc: 0.8205 - val_f1_score: 0.8137
# Epoch 8/100
# 258/258 [==============================] - 5s 18ms/step - loss: 6.0210 - acc: 0.8177 - f1_score: 0.8170 - val_loss: 5.8319 - val_acc: 0.8364 - val_f1_score: 0.8368
# Epoch 9/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.8855 - acc: 0.8210 - f1_score: 0.8206 - val_loss: 5.5782 - val_acc: 0.8568 - val_f1_score: 0.8556
# Epoch 10/100
# 258/258 [==============================] - 5s 19ms/step - loss: 5.7941 - acc: 0.8295 - f1_score: 0.8291 - val_loss: 5.4436 - val_acc: 0.8658 - val_f1_score: 0.8654
# Epoch 11/100
# 258/258 [==============================] - 5s 17ms/step - loss: 5.5965 - acc: 0.8371 - f1_score: 0.8365 - val_loss: 5.4708 - val_acc: 0.8660 - val_f1_score: 0.8655
# Epoch 12/100
# 258/258 [==============================] - 4s 17ms/step - loss: 5.4398 - acc: 0.8430 - f1_score: 0.8426 - val_loss: 5.4206 - val_acc: 0.8653 - val_f1_score: 0.8645
# Epoch 13/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.3823 - acc: 0.8465 - f1_score: 0.8461 - val_loss: 4.9335 - val_acc: 0.8776 - val_f1_score: 0.8773
# Epoch 14/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.2422 - acc: 0.8496 - f1_score: 0.8491 - val_loss: 5.1538 - val_acc: 0.8876 - val_f1_score: 0.8871
# Epoch 15/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.2477 - acc: 0.8518 - f1_score: 0.8515 - val_loss: 4.8776 - val_acc: 0.8878 - val_f1_score: 0.8877
# Epoch 16/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.1248 - acc: 0.8568 - f1_score: 0.8565 - val_loss: 4.8096 - val_acc: 0.8854 - val_f1_score: 0.8851
# Epoch 17/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.0392 - acc: 0.8575 - f1_score: 0.8571 - val_loss: 5.1037 - val_acc: 0.8835 - val_f1_score: 0.8838
# Epoch 18/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.0445 - acc: 0.8610 - f1_score: 0.8608 - val_loss: 4.8059 - val_acc: 0.8864 - val_f1_score: 0.8862
# Epoch 19/100
# 258/258 [==============================] - 5s 17ms/step - loss: 4.9576 - acc: 0.8617 - f1_score: 0.8613 - val_loss: 5.0078 - val_acc: 0.8946 - val_f1_score: 0.8941
# Epoch 20/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.8858 - acc: 0.8671 - f1_score: 0.8669 - val_loss: 4.7749 - val_acc: 0.8902 - val_f1_score: 0.8896
# Epoch 21/100
# 258/258 [==============================] - 5s 19ms/step - loss: 4.8323 - acc: 0.8707 - f1_score: 0.8704 - val_loss: 4.5322 - val_acc: 0.9089 - val_f1_score: 0.9090
# Epoch 22/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.7796 - acc: 0.8723 - f1_score: 0.8721 - val_loss: 4.7194 - val_acc: 0.8987 - val_f1_score: 0.8982
# Epoch 23/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.8494 - acc: 0.8661 - f1_score: 0.8658 - val_loss: 4.7088 - val_acc: 0.8948 - val_f1_score: 0.8947
# Epoch 24/100
# 258/258 [==============================] - 5s 20ms/step - loss: 4.7234 - acc: 0.8725 - f1_score: 0.8722 - val_loss: 4.8719 - val_acc: 0.8994 - val_f1_score: 0.8992
# Epoch 25/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.6883 - acc: 0.8813 - f1_score: 0.8811 - val_loss: 4.6142 - val_acc: 0.8963 - val_f1_score: 0.8970
# Epoch 26/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.7322 - acc: 0.8799 - f1_score: 0.8797 - val_loss: 4.6305 - val_acc: 0.8987 - val_f1_score: 0.8986
# Epoch 27/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.5789 - acc: 0.8801 - f1_score: 0.8798 - val_loss: 4.5130 - val_acc: 0.9089 - val_f1_score: 0.9091
# Epoch 28/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.6085 - acc: 0.8821 - f1_score: 0.8819 - val_loss: 4.6660 - val_acc: 0.9072 - val_f1_score: 0.9073
# Epoch 29/100
# 258/258 [==============================] - 5s 19ms/step - loss: 4.6412 - acc: 0.8876 - f1_score: 0.8874 - val_loss: 4.3801 - val_acc: 0.9137 - val_f1_score: 0.9136
# Epoch 30/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.5246 - acc: 0.8853 - f1_score: 0.8852 - val_loss: 4.4455 - val_acc: 0.8977 - val_f1_score: 0.8977
# Epoch 31/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.4833 - acc: 0.8850 - f1_score: 0.8848 - val_loss: 4.3862 - val_acc: 0.8990 - val_f1_score: 0.8988
# Epoch 32/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.4682 - acc: 0.8893 - f1_score: 0.8891 - val_loss: 4.5074 - val_acc: 0.8738 - val_f1_score: 0.8718
# Epoch 33/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.4343 - acc: 0.8867 - f1_score: 0.8866 - val_loss: 4.3555 - val_acc: 0.9133 - val_f1_score: 0.9136
# Epoch 34/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.3612 - acc: 0.8926 - f1_score: 0.8925 - val_loss: 4.2838 - val_acc: 0.9203 - val_f1_score: 0.9200
# Epoch 35/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.3670 - acc: 0.8872 - f1_score: 0.8870 - val_loss: 4.2936 - val_acc: 0.8963 - val_f1_score: 0.8959
# Epoch 36/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.3203 - acc: 0.8947 - f1_score: 0.8945 - val_loss: 4.2044 - val_acc: 0.9203 - val_f1_score: 0.9205
# Epoch 37/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.3232 - acc: 0.8934 - f1_score: 0.8932 - val_loss: 4.3927 - val_acc: 0.9094 - val_f1_score: 0.9098
# Epoch 38/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.2371 - acc: 0.8953 - f1_score: 0.8952 - val_loss: 4.0660 - val_acc: 0.9159 - val_f1_score: 0.9160
# Epoch 39/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.1544 - acc: 0.9014 - f1_score: 0.9013 - val_loss: 4.1966 - val_acc: 0.9154 - val_f1_score: 0.9149
# Epoch 40/100
# 258/258 [==============================] - 5s 17ms/step - loss: 4.2045 - acc: 0.8968 - f1_score: 0.8966 - val_loss: 4.0804 - val_acc: 0.9130 - val_f1_score: 0.9134
# Epoch 41/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.1713 - acc: 0.8988 - f1_score: 0.8987 - val_loss: 4.2525 - val_acc: 0.9142 - val_f1_score: 0.9136
# Epoch 42/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.1333 - acc: 0.8983 - f1_score: 0.8981 - val_loss: 4.0092 - val_acc: 0.9074 - val_f1_score: 0.9074
# Epoch 43/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.0957 - acc: 0.9009 - f1_score: 0.9008 - val_loss: 4.1394 - val_acc: 0.9040 - val_f1_score: 0.9037
# Epoch 44/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.0752 - acc: 0.9017 - f1_score: 0.9015 - val_loss: 3.9698 - val_acc: 0.9193 - val_f1_score: 0.9194
# Epoch 45/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.0363 - acc: 0.9060 - f1_score: 0.9059 - val_loss: 4.1007 - val_acc: 0.9174 - val_f1_score: 0.9172
# Epoch 46/100
# 258/258 [==============================] - 5s 19ms/step - loss: 4.0112 - acc: 0.9040 - f1_score: 0.9039 - val_loss: 3.9442 - val_acc: 0.9297 - val_f1_score: 0.9298
# Epoch 47/100
# 258/258 [==============================] - 5s 17ms/step - loss: 4.0012 - acc: 0.9052 - f1_score: 0.9050 - val_loss: 3.8790 - val_acc: 0.9271 - val_f1_score: 0.9273
# Epoch 48/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.0128 - acc: 0.9093 - f1_score: 0.9092 - val_loss: 4.0426 - val_acc: 0.8825 - val_f1_score: 0.8821
# Epoch 49/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.0164 - acc: 0.9059 - f1_score: 0.9058 - val_loss: 3.8533 - val_acc: 0.9213 - val_f1_score: 0.9215
# Epoch 50/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.9095 - acc: 0.9072 - f1_score: 0.9071 - val_loss: 3.9526 - val_acc: 0.9181 - val_f1_score: 0.9182
# Epoch 51/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8948 - acc: 0.9117 - f1_score: 0.9116 - val_loss: 3.8295 - val_acc: 0.9222 - val_f1_score: 0.9224
# Epoch 52/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8674 - acc: 0.9129 - f1_score: 0.9129 - val_loss: 3.7707 - val_acc: 0.9263 - val_f1_score: 0.9263
# Epoch 53/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.8604 - acc: 0.9112 - f1_score: 0.9112 - val_loss: 3.9046 - val_acc: 0.9302 - val_f1_score: 0.9303
# Epoch 54/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8277 - acc: 0.9121 - f1_score: 0.9120 - val_loss: 3.7450 - val_acc: 0.9288 - val_f1_score: 0.9290
# Epoch 55/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.8661 - acc: 0.9107 - f1_score: 0.9106 - val_loss: 3.7174 - val_acc: 0.9341 - val_f1_score: 0.9341
# Epoch 56/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.8586 - acc: 0.9164 - f1_score: 0.9163 - val_loss: 3.7432 - val_acc: 0.9358 - val_f1_score: 0.9358
# Epoch 57/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.8538 - acc: 0.9137 - f1_score: 0.9135 - val_loss: 3.8430 - val_acc: 0.9251 - val_f1_score: 0.9249
# Epoch 58/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.8343 - acc: 0.9142 - f1_score: 0.9140 - val_loss: 3.6980 - val_acc: 0.9312 - val_f1_score: 0.9313
# Epoch 59/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.8127 - acc: 0.9171 - f1_score: 0.9171 - val_loss: 3.7189 - val_acc: 0.9440 - val_f1_score: 0.9442
# Epoch 60/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7778 - acc: 0.9152 - f1_score: 0.9151 - val_loss: 3.6661 - val_acc: 0.9329 - val_f1_score: 0.9329
# Epoch 61/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.7588 - acc: 0.9152 - f1_score: 0.9151 - val_loss: 3.7033 - val_acc: 0.9300 - val_f1_score: 0.9301
# Epoch 62/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7705 - acc: 0.9167 - f1_score: 0.9165 - val_loss: 3.9173 - val_acc: 0.9377 - val_f1_score: 0.9381
# Epoch 63/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.7697 - acc: 0.9177 - f1_score: 0.9177 - val_loss: 3.7119 - val_acc: 0.9288 - val_f1_score: 0.9287
# Epoch 64/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7454 - acc: 0.9193 - f1_score: 0.9192 - val_loss: 3.6757 - val_acc: 0.9300 - val_f1_score: 0.9301
# Epoch 65/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.7399 - acc: 0.9152 - f1_score: 0.9151 - val_loss: 3.6528 - val_acc: 0.9263 - val_f1_score: 0.9263
# Epoch 66/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6759 - acc: 0.9140 - f1_score: 0.9139 - val_loss: 3.5949 - val_acc: 0.9317 - val_f1_score: 0.9313
# Epoch 67/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6877 - acc: 0.9192 - f1_score: 0.9192 - val_loss: 3.7376 - val_acc: 0.9322 - val_f1_score: 0.9320
# Epoch 68/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7247 - acc: 0.9203 - f1_score: 0.9202 - val_loss: 3.5321 - val_acc: 0.9360 - val_f1_score: 0.9361
# Epoch 69/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.7029 - acc: 0.9161 - f1_score: 0.9160 - val_loss: 3.7763 - val_acc: 0.9271 - val_f1_score: 0.9271
# Epoch 70/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6756 - acc: 0.9212 - f1_score: 0.9212 - val_loss: 3.5956 - val_acc: 0.9309 - val_f1_score: 0.9308
# Epoch 71/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.6741 - acc: 0.9214 - f1_score: 0.9213 - val_loss: 3.6401 - val_acc: 0.9474 - val_f1_score: 0.9475
# Epoch 72/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6265 - acc: 0.9251 - f1_score: 0.9251 - val_loss: 3.6259 - val_acc: 0.9295 - val_f1_score: 0.9298
# Epoch 73/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6888 - acc: 0.9248 - f1_score: 0.9247 - val_loss: 3.6887 - val_acc: 0.9203 - val_f1_score: 0.9203
# Epoch 74/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6829 - acc: 0.9195 - f1_score: 0.9195 - val_loss: 3.6290 - val_acc: 0.9399 - val_f1_score: 0.9399
# Epoch 75/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6213 - acc: 0.9232 - f1_score: 0.9232 - val_loss: 3.4737 - val_acc: 0.9353 - val_f1_score: 0.9355
# Epoch 76/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.6009 - acc: 0.9231 - f1_score: 0.9229 - val_loss: 3.5362 - val_acc: 0.9295 - val_f1_score: 0.9294
# Epoch 77/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6043 - acc: 0.9215 - f1_score: 0.9214 - val_loss: 3.4694 - val_acc: 0.9365 - val_f1_score: 0.9367
# Epoch 78/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5718 - acc: 0.9240 - f1_score: 0.9239 - val_loss: 3.7401 - val_acc: 0.9280 - val_f1_score: 0.9281
# Epoch 79/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6499 - acc: 0.9221 - f1_score: 0.9220 - val_loss: 3.6521 - val_acc: 0.9285 - val_f1_score: 0.9285
# Epoch 80/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6225 - acc: 0.9212 - f1_score: 0.9212 - val_loss: 3.6412 - val_acc: 0.9302 - val_f1_score: 0.9301
# Epoch 81/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6117 - acc: 0.9276 - f1_score: 0.9275 - val_loss: 3.5485 - val_acc: 0.9421 - val_f1_score: 0.9422
# Epoch 82/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.6262 - acc: 0.9244 - f1_score: 0.9243 - val_loss: 3.6810 - val_acc: 0.9246 - val_f1_score: 0.9246
# Epoch 83/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6049 - acc: 0.9237 - f1_score: 0.9237 - val_loss: 3.4902 - val_acc: 0.9462 - val_f1_score: 0.9462
# Epoch 84/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5588 - acc: 0.9282 - f1_score: 0.9281 - val_loss: 3.4382 - val_acc: 0.9385 - val_f1_score: 0.9387
# Epoch 85/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.5309 - acc: 0.9275 - f1_score: 0.9275 - val_loss: 3.5354 - val_acc: 0.9452 - val_f1_score: 0.9453
# Epoch 86/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5458 - acc: 0.9257 - f1_score: 0.9256 - val_loss: 3.7178 - val_acc: 0.9227 - val_f1_score: 0.9231
# Epoch 87/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5637 - acc: 0.9266 - f1_score: 0.9266 - val_loss: 3.6278 - val_acc: 0.9428 - val_f1_score: 0.9431
# Epoch 88/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.5535 - acc: 0.9254 - f1_score: 0.9254 - val_loss: 3.6189 - val_acc: 0.9421 - val_f1_score: 0.9422
# Epoch 89/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5074 - acc: 0.9288 - f1_score: 0.9287 - val_loss: 3.5049 - val_acc: 0.9423 - val_f1_score: 0.9426
# Epoch 90/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5553 - acc: 0.9305 - f1_score: 0.9304 - val_loss: 3.4747 - val_acc: 0.9416 - val_f1_score: 0.9419
# Epoch 91/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5232 - acc: 0.9332 - f1_score: 0.9331 - val_loss: 3.4672 - val_acc: 0.9426 - val_f1_score: 0.9427
# Epoch 92/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5151 - acc: 0.9308 - f1_score: 0.9308 - val_loss: 3.5279 - val_acc: 0.9455 - val_f1_score: 0.9455
# Epoch 93/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.5195 - acc: 0.9272 - f1_score: 0.9271 - val_loss: 3.3554 - val_acc: 0.9489 - val_f1_score: 0.9490
# Epoch 94/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.4933 - acc: 0.9326 - f1_score: 0.9325 - val_loss: 3.4989 - val_acc: 0.9440 - val_f1_score: 0.9442
# Epoch 95/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5534 - acc: 0.9274 - f1_score: 0.9273 - val_loss: 3.6516 - val_acc: 0.9481 - val_f1_score: 0.9482
# Epoch 96/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5458 - acc: 0.9298 - f1_score: 0.9298 - val_loss: 3.4075 - val_acc: 0.9440 - val_f1_score: 0.9442
# Epoch 97/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5163 - acc: 0.9331 - f1_score: 0.9331 - val_loss: 3.6179 - val_acc: 0.9515 - val_f1_score: 0.9518
# Epoch 98/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.5569 - acc: 0.9280 - f1_score: 0.9279 - val_loss: 3.7241 - val_acc: 0.9438 - val_f1_score: 0.9440
# Epoch 99/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5055 - acc: 0.9310 - f1_score: 0.9309 - val_loss: 3.4214 - val_acc: 0.9402 - val_f1_score: 0.9402
# Epoch 100/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.4982 - acc: 0.9329 - f1_score: 0.9328 - val_loss: 3.4426 - val_acc: 0.9445 - val_f1_score: 0.9447
# 164/164 [==============================] - 1s 6ms/step - loss: 3.9761 - acc: 0.8675 - f1_score: 0.8204
# 164/164 [==============================] - 1s 3ms/step
# Score: loss of 3.9761388301849365; acc of 86.74560785293579%

# %% [markdown]
# ### Matrix de confusão

# %%
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2165                  4              14           38
# Deitado-Ruminando        12                670              91           22
# Deitado-Parado           20                 57             556           35
# EmPe-Parado              34                 23              25          455
# Andando                  29                  0               0            1
# EmPe-Ruminando           12                 10               5           67
#
#                    Andando  EmPe-Ruminando
# Pastando                65               7
# Deitado-Ruminando        0              19
# Deitado-Parado           0              13
# EmPe-Parado              5              82
# Andando                460               1
# EmPe-Ruminando           3             236

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9529    0.9442    0.9485      2293
# Deitado-Ruminando     0.8770    0.8231    0.8492       814
#    Deitado-Parado     0.8046    0.8164    0.8105       681
#       EmPe-Parado     0.7362    0.7292    0.7327       624
#           Andando     0.8630    0.9369    0.8984       491
#    EmPe-Ruminando     0.6592    0.7087    0.6831       333
#
#          accuracy                         0.8675      5236
#         macro avg     0.8155    0.8264    0.8204      5236
#      weighted avg     0.8689    0.8675    0.8678      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()

# %% [markdown]
# ## Base com SMOTE

# %%
# SMOTE
cnn_model=create_cnn()
print('Training ...')
cb = ModelCheckpoint('.best_model_holdout.hdf5', save_best_only=True, monitor='val_f1_score', mode='max')
hist=cnn_model.fit(t_data_train_balanced_smote, c_labels_train_balanced_smote, epochs=epochs, verbose=1,
                batch_size=batch_size, shuffle=True,
                validation_split=0.2,
                #validation_data=(t_data_test_smote, c_labels_test),
                #callbacks=[EarlyStopping(monitor='val_accuracy', patience=10)]
                callbacks=[cb]
                )
cnn_model.load_weights('.best_model_holdout.hdf5')
scores=cnn_model.evaluate(t_data_test_smote, c_labels_test, verbose=1)
predictions=cnn_model.predict(t_data_test_smote, verbose=1)
cm=confusion_matrix(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), labels=[0, 1, 2, 3, 4, 5])
print(f'Score: {cnn_model.metrics_names[0]} of {scores[0]}; {cnn_model.metrics_names[1]} of {scores[1]*100}%')
# Out:
# Training ...
# Epoch 1/100
# 258/258 [==============================] - 7s 21ms/step - loss: 45.0971 - acc: 0.6536 - f1_score: 0.6509 - val_loss: 12.9975 - val_acc: 0.1725 - val_f1_score: 0.0490
# Epoch 2/100
# 258/258 [==============================] - 5s 19ms/step - loss: 9.8025 - acc: 0.7309 - f1_score: 0.7295 - val_loss: 8.4377 - val_acc: 0.7284 - val_f1_score: 0.7271
# Epoch 3/100
# 258/258 [==============================] - 5s 18ms/step - loss: 7.5598 - acc: 0.7714 - f1_score: 0.7700 - val_loss: 7.6198 - val_acc: 0.7858 - val_f1_score: 0.7821
# Epoch 4/100
# 258/258 [==============================] - 5s 18ms/step - loss: 7.2127 - acc: 0.7943 - f1_score: 0.7932 - val_loss: 6.8005 - val_acc: 0.8076 - val_f1_score: 0.8072
# Epoch 5/100
# 258/258 [==============================] - 5s 18ms/step - loss: 6.7777 - acc: 0.8087 - f1_score: 0.8078 - val_loss: 6.7098 - val_acc: 0.8025 - val_f1_score: 0.7970
# Epoch 6/100
# 258/258 [==============================] - 5s 19ms/step - loss: 6.4444 - acc: 0.8172 - f1_score: 0.8164 - val_loss: 6.4694 - val_acc: 0.8360 - val_f1_score: 0.8341
# Epoch 7/100
# 258/258 [==============================] - 5s 19ms/step - loss: 6.3084 - acc: 0.8229 - f1_score: 0.8223 - val_loss: 6.2427 - val_acc: 0.8503 - val_f1_score: 0.8512
# Epoch 8/100
# 258/258 [==============================] - 5s 19ms/step - loss: 6.1886 - acc: 0.8309 - f1_score: 0.8302 - val_loss: 5.7059 - val_acc: 0.8406 - val_f1_score: 0.8374
# Epoch 9/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.9391 - acc: 0.8406 - f1_score: 0.8400 - val_loss: 5.6695 - val_acc: 0.8410 - val_f1_score: 0.8403
# Epoch 10/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.7920 - acc: 0.8436 - f1_score: 0.8431 - val_loss: 5.8510 - val_acc: 0.8352 - val_f1_score: 0.8350
# Epoch 11/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.6821 - acc: 0.8482 - f1_score: 0.8478 - val_loss: 5.5142 - val_acc: 0.8575 - val_f1_score: 0.8566
# Epoch 12/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.5230 - acc: 0.8517 - f1_score: 0.8513 - val_loss: 5.5411 - val_acc: 0.8801 - val_f1_score: 0.8806
# Epoch 13/100
# 258/258 [==============================] - 4s 17ms/step - loss: 5.4087 - acc: 0.8540 - f1_score: 0.8536 - val_loss: 5.5198 - val_acc: 0.8650 - val_f1_score: 0.8651
# Epoch 14/100
# 258/258 [==============================] - 4s 17ms/step - loss: 5.3223 - acc: 0.8587 - f1_score: 0.8583 - val_loss: 5.1723 - val_acc: 0.8643 - val_f1_score: 0.8634
# Epoch 15/100
# 258/258 [==============================] - 4s 17ms/step - loss: 5.2547 - acc: 0.8663 - f1_score: 0.8659 - val_loss: 5.1614 - val_acc: 0.8665 - val_f1_score: 0.8666
# Epoch 16/100
# 258/258 [==============================] - 5s 18ms/step - loss: 5.1552 - acc: 0.8691 - f1_score: 0.8686 - val_loss: 4.9248 - val_acc: 0.8832 - val_f1_score: 0.8836
# Epoch 17/100
# 258/258 [==============================] - 5s 19ms/step - loss: 5.0669 - acc: 0.8705 - f1_score: 0.8703 - val_loss: 5.1223 - val_acc: 0.8898 - val_f1_score: 0.8901
# Epoch 18/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.9753 - acc: 0.8707 - f1_score: 0.8704 - val_loss: 4.7367 - val_acc: 0.8779 - val_f1_score: 0.8791
# Epoch 19/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.9149 - acc: 0.8772 - f1_score: 0.8769 - val_loss: 4.7879 - val_acc: 0.8927 - val_f1_score: 0.8930
# Epoch 20/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.9126 - acc: 0.8759 - f1_score: 0.8757 - val_loss: 4.7540 - val_acc: 0.8849 - val_f1_score: 0.8851
# Epoch 21/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.9131 - acc: 0.8811 - f1_score: 0.8808 - val_loss: 4.8670 - val_acc: 0.8837 - val_f1_score: 0.8840
# Epoch 22/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.8648 - acc: 0.8821 - f1_score: 0.8819 - val_loss: 4.7597 - val_acc: 0.8696 - val_f1_score: 0.8691
# Epoch 23/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.7986 - acc: 0.8812 - f1_score: 0.8809 - val_loss: 4.6497 - val_acc: 0.8980 - val_f1_score: 0.8981
# Epoch 24/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.7175 - acc: 0.8827 - f1_score: 0.8824 - val_loss: 4.6064 - val_acc: 0.9033 - val_f1_score: 0.9038
# Epoch 25/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.7370 - acc: 0.8856 - f1_score: 0.8854 - val_loss: 4.7979 - val_acc: 0.9004 - val_f1_score: 0.9010
# Epoch 26/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.6220 - acc: 0.8897 - f1_score: 0.8895 - val_loss: 4.6687 - val_acc: 0.8987 - val_f1_score: 0.8992
# Epoch 27/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.6232 - acc: 0.8893 - f1_score: 0.8892 - val_loss: 4.6018 - val_acc: 0.9007 - val_f1_score: 0.9008
# Epoch 28/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.5848 - acc: 0.8916 - f1_score: 0.8914 - val_loss: 4.7271 - val_acc: 0.8805 - val_f1_score: 0.8794
# Epoch 29/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.5617 - acc: 0.8908 - f1_score: 0.8906 - val_loss: 4.3551 - val_acc: 0.9091 - val_f1_score: 0.9097
# Epoch 30/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.4856 - acc: 0.8931 - f1_score: 0.8929 - val_loss: 4.4339 - val_acc: 0.8929 - val_f1_score: 0.8928
# Epoch 31/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.4361 - acc: 0.8963 - f1_score: 0.8961 - val_loss: 4.5006 - val_acc: 0.9060 - val_f1_score: 0.9065
# Epoch 32/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.4705 - acc: 0.8992 - f1_score: 0.8990 - val_loss: 4.5594 - val_acc: 0.8975 - val_f1_score: 0.8976
# Epoch 33/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.4560 - acc: 0.8968 - f1_score: 0.8966 - val_loss: 4.3541 - val_acc: 0.9074 - val_f1_score: 0.9079
# Epoch 34/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.3633 - acc: 0.8974 - f1_score: 0.8972 - val_loss: 4.3314 - val_acc: 0.9106 - val_f1_score: 0.9109
# Epoch 35/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.3381 - acc: 0.9005 - f1_score: 0.9003 - val_loss: 4.2352 - val_acc: 0.9137 - val_f1_score: 0.9142
# Epoch 36/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.3288 - acc: 0.8986 - f1_score: 0.8985 - val_loss: 4.3066 - val_acc: 0.8878 - val_f1_score: 0.8874
# Epoch 37/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.2650 - acc: 0.9007 - f1_score: 0.9006 - val_loss: 4.3602 - val_acc: 0.9050 - val_f1_score: 0.9052
# Epoch 38/100
# 258/258 [==============================] - 5s 19ms/step - loss: 4.2342 - acc: 0.9026 - f1_score: 0.9025 - val_loss: 4.0783 - val_acc: 0.9150 - val_f1_score: 0.9153
# Epoch 39/100
# 258/258 [==============================] - 5s 18ms/step - loss: 4.1876 - acc: 0.9037 - f1_score: 0.9035 - val_loss: 4.3895 - val_acc: 0.9021 - val_f1_score: 0.9019
# Epoch 40/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.2202 - acc: 0.9028 - f1_score: 0.9026 - val_loss: 4.4136 - val_acc: 0.9125 - val_f1_score: 0.9130
# Epoch 41/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.1606 - acc: 0.9056 - f1_score: 0.9054 - val_loss: 4.2555 - val_acc: 0.9094 - val_f1_score: 0.9098
# Epoch 42/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.1405 - acc: 0.9038 - f1_score: 0.9036 - val_loss: 4.1673 - val_acc: 0.9036 - val_f1_score: 0.9038
# Epoch 43/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.1321 - acc: 0.9044 - f1_score: 0.9043 - val_loss: 4.0841 - val_acc: 0.8810 - val_f1_score: 0.8808
# Epoch 44/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.0684 - acc: 0.9079 - f1_score: 0.9077 - val_loss: 4.1598 - val_acc: 0.9089 - val_f1_score: 0.9097
# Epoch 45/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.0628 - acc: 0.9089 - f1_score: 0.9087 - val_loss: 4.0707 - val_acc: 0.9038 - val_f1_score: 0.9046
# Epoch 46/100
# 258/258 [==============================] - 4s 17ms/step - loss: 4.0492 - acc: 0.9109 - f1_score: 0.9108 - val_loss: 4.0601 - val_acc: 0.8871 - val_f1_score: 0.8872
# Epoch 47/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.9850 - acc: 0.9120 - f1_score: 0.9118 - val_loss: 3.9635 - val_acc: 0.9096 - val_f1_score: 0.9099
# Epoch 48/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.9239 - acc: 0.9102 - f1_score: 0.9101 - val_loss: 4.1188 - val_acc: 0.9128 - val_f1_score: 0.9129
# Epoch 49/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.9523 - acc: 0.9106 - f1_score: 0.9105 - val_loss: 3.8811 - val_acc: 0.9174 - val_f1_score: 0.9179
# Epoch 50/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.9634 - acc: 0.9105 - f1_score: 0.9104 - val_loss: 4.0152 - val_acc: 0.9169 - val_f1_score: 0.9173
# Epoch 51/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.9278 - acc: 0.9099 - f1_score: 0.9098 - val_loss: 3.7576 - val_acc: 0.9191 - val_f1_score: 0.9196
# Epoch 52/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.9187 - acc: 0.9121 - f1_score: 0.9119 - val_loss: 4.0233 - val_acc: 0.9159 - val_f1_score: 0.9163
# Epoch 53/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8869 - acc: 0.9128 - f1_score: 0.9127 - val_loss: 3.9536 - val_acc: 0.9174 - val_f1_score: 0.9174
# Epoch 54/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8399 - acc: 0.9155 - f1_score: 0.9153 - val_loss: 3.9914 - val_acc: 0.9188 - val_f1_score: 0.9194
# Epoch 55/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8246 - acc: 0.9129 - f1_score: 0.9127 - val_loss: 3.9467 - val_acc: 0.9174 - val_f1_score: 0.9175
# Epoch 56/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.8433 - acc: 0.9120 - f1_score: 0.9119 - val_loss: 3.7874 - val_acc: 0.9084 - val_f1_score: 0.9089
# Epoch 57/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.7930 - acc: 0.9189 - f1_score: 0.9188 - val_loss: 3.8143 - val_acc: 0.9179 - val_f1_score: 0.9181
# Epoch 58/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.8228 - acc: 0.9154 - f1_score: 0.9153 - val_loss: 3.7952 - val_acc: 0.9227 - val_f1_score: 0.9230
# Epoch 59/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.8144 - acc: 0.9174 - f1_score: 0.9173 - val_loss: 3.7692 - val_acc: 0.9130 - val_f1_score: 0.9133
# Epoch 60/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7879 - acc: 0.9172 - f1_score: 0.9171 - val_loss: 3.8371 - val_acc: 0.9171 - val_f1_score: 0.9175
# Epoch 61/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7754 - acc: 0.9185 - f1_score: 0.9184 - val_loss: 3.7500 - val_acc: 0.9220 - val_f1_score: 0.9224
# Epoch 62/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.7418 - acc: 0.9143 - f1_score: 0.9142 - val_loss: 3.7515 - val_acc: 0.9171 - val_f1_score: 0.9176
# Epoch 63/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7289 - acc: 0.9213 - f1_score: 0.9212 - val_loss: 3.7406 - val_acc: 0.9210 - val_f1_score: 0.9213
# Epoch 64/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.7398 - acc: 0.9169 - f1_score: 0.9168 - val_loss: 3.7877 - val_acc: 0.9232 - val_f1_score: 0.9235
# Epoch 65/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.6764 - acc: 0.9232 - f1_score: 0.9231 - val_loss: 3.5816 - val_acc: 0.9237 - val_f1_score: 0.9241
# Epoch 66/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6295 - acc: 0.9232 - f1_score: 0.9231 - val_loss: 3.7225 - val_acc: 0.9307 - val_f1_score: 0.9311
# Epoch 67/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6737 - acc: 0.9197 - f1_score: 0.9196 - val_loss: 3.6588 - val_acc: 0.9171 - val_f1_score: 0.9176
# Epoch 68/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.6529 - acc: 0.9189 - f1_score: 0.9188 - val_loss: 3.5406 - val_acc: 0.9203 - val_f1_score: 0.9207
# Epoch 69/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6356 - acc: 0.9241 - f1_score: 0.9240 - val_loss: 3.6182 - val_acc: 0.9174 - val_f1_score: 0.9176
# Epoch 70/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.5907 - acc: 0.9258 - f1_score: 0.9257 - val_loss: 3.5946 - val_acc: 0.9273 - val_f1_score: 0.9277
# Epoch 71/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6309 - acc: 0.9213 - f1_score: 0.9212 - val_loss: 3.8051 - val_acc: 0.9271 - val_f1_score: 0.9273
# Epoch 72/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6271 - acc: 0.9225 - f1_score: 0.9224 - val_loss: 3.4800 - val_acc: 0.9276 - val_f1_score: 0.9282
# Epoch 73/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6099 - acc: 0.9205 - f1_score: 0.9204 - val_loss: 3.5618 - val_acc: 0.9259 - val_f1_score: 0.9262
# Epoch 74/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.6241 - acc: 0.9206 - f1_score: 0.9205 - val_loss: 3.6909 - val_acc: 0.9162 - val_f1_score: 0.9166
# Epoch 75/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6033 - acc: 0.9233 - f1_score: 0.9232 - val_loss: 3.6554 - val_acc: 0.9309 - val_f1_score: 0.9313
# Epoch 76/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6042 - acc: 0.9248 - f1_score: 0.9247 - val_loss: 3.5748 - val_acc: 0.9157 - val_f1_score: 0.9158
# Epoch 77/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.6129 - acc: 0.9221 - f1_score: 0.9220 - val_loss: 3.5088 - val_acc: 0.9283 - val_f1_score: 0.9286
# Epoch 78/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5952 - acc: 0.9238 - f1_score: 0.9237 - val_loss: 3.6053 - val_acc: 0.9242 - val_f1_score: 0.9244
# Epoch 79/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5805 - acc: 0.9255 - f1_score: 0.9254 - val_loss: 3.6067 - val_acc: 0.9205 - val_f1_score: 0.9210
# Epoch 80/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5946 - acc: 0.9228 - f1_score: 0.9226 - val_loss: 3.5328 - val_acc: 0.9297 - val_f1_score: 0.9301
# Epoch 81/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5675 - acc: 0.9243 - f1_score: 0.9242 - val_loss: 3.6854 - val_acc: 0.9273 - val_f1_score: 0.9277
# Epoch 82/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5960 - acc: 0.9260 - f1_score: 0.9259 - val_loss: 3.8105 - val_acc: 0.9213 - val_f1_score: 0.9216
# Epoch 83/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5983 - acc: 0.9269 - f1_score: 0.9268 - val_loss: 3.7099 - val_acc: 0.9249 - val_f1_score: 0.9253
# Epoch 84/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5651 - acc: 0.9261 - f1_score: 0.9260 - val_loss: 3.6066 - val_acc: 0.9244 - val_f1_score: 0.9248
# Epoch 85/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.5490 - acc: 0.9312 - f1_score: 0.9312 - val_loss: 3.6355 - val_acc: 0.9263 - val_f1_score: 0.9268
# Epoch 86/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5409 - acc: 0.9306 - f1_score: 0.9305 - val_loss: 3.6448 - val_acc: 0.9229 - val_f1_score: 0.9232
# Epoch 87/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5948 - acc: 0.9270 - f1_score: 0.9269 - val_loss: 3.7128 - val_acc: 0.9181 - val_f1_score: 0.9181
# Epoch 88/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5388 - acc: 0.9294 - f1_score: 0.9293 - val_loss: 3.5288 - val_acc: 0.9326 - val_f1_score: 0.9330
# Epoch 89/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5896 - acc: 0.9286 - f1_score: 0.9285 - val_loss: 3.4728 - val_acc: 0.9326 - val_f1_score: 0.9330
# Epoch 90/100
# 258/258 [==============================] - 5s 19ms/step - loss: 3.5132 - acc: 0.9312 - f1_score: 0.9312 - val_loss: 3.4973 - val_acc: 0.9341 - val_f1_score: 0.9344
# Epoch 91/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5716 - acc: 0.9294 - f1_score: 0.9293 - val_loss: 3.6783 - val_acc: 0.9237 - val_f1_score: 0.9240
# Epoch 92/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.4968 - acc: 0.9298 - f1_score: 0.9297 - val_loss: 3.5419 - val_acc: 0.9290 - val_f1_score: 0.9293
# Epoch 93/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5111 - acc: 0.9326 - f1_score: 0.9326 - val_loss: 3.5506 - val_acc: 0.9302 - val_f1_score: 0.9304
# Epoch 94/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5035 - acc: 0.9308 - f1_score: 0.9307 - val_loss: 3.5300 - val_acc: 0.9365 - val_f1_score: 0.9368
# Epoch 95/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5832 - acc: 0.9276 - f1_score: 0.9275 - val_loss: 3.4922 - val_acc: 0.9326 - val_f1_score: 0.9331
# Epoch 96/100
# 258/258 [==============================] - 4s 17ms/step - loss: 3.5432 - acc: 0.9310 - f1_score: 0.9309 - val_loss: 3.7004 - val_acc: 0.9280 - val_f1_score: 0.9283
# Epoch 97/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5347 - acc: 0.9303 - f1_score: 0.9302 - val_loss: 3.6257 - val_acc: 0.9273 - val_f1_score: 0.9277
# Epoch 98/100
# 258/258 [==============================] - 5s 17ms/step - loss: 3.5320 - acc: 0.9298 - f1_score: 0.9297 - val_loss: 3.5534 - val_acc: 0.9278 - val_f1_score: 0.9282
# Epoch 99/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.4964 - acc: 0.9310 - f1_score: 0.9309 - val_loss: 3.4868 - val_acc: 0.9331 - val_f1_score: 0.9335
# Epoch 100/100
# 258/258 [==============================] - 5s 18ms/step - loss: 3.5581 - acc: 0.9296 - f1_score: 0.9296 - val_loss: 3.4545 - val_acc: 0.9314 - val_f1_score: 0.9318
# 164/164 [==============================] - 1s 7ms/step - loss: 3.8589 - acc: 0.8615 - f1_score: 0.8107
# 164/164 [==============================] - 1s 4ms/step
# Score: loss of 3.858872890472412; acc of 86.15355491638184%

# %% [markdown]
# ### Matrix de confusão

# %%
# matriz de confusao para base balanceada com BOOTSTRAP
pd.DataFrame(cm, index=labels_map, columns=labels_map)
# Out:
#                    Pastando  Deitado-Ruminando  Deitado-Parado  EmPe-Parado  \
# Pastando               2193                  8              17           24
# Deitado-Ruminando         5                690              66           28
# Deitado-Parado           12                116             509           33
# EmPe-Parado              41                 30              35          432
# Andando                  38                  1               0            3
# EmPe-Ruminando           12                 16               7           54
#
#                    Andando  EmPe-Ruminando
# Pastando                45               6
# Deitado-Ruminando        0              25
# Deitado-Parado           0              11
# EmPe-Parado              2              84
# Andando                445               4
# EmPe-Ruminando           2             242

# %% [markdown]
# ### Métricas

# %%
print(classification_report(c_labels_test.argmax(axis=1), predictions.argmax(axis=1), target_names=labels_map, output_dict=False, digits=4))
# Out:
#                    precision    recall  f1-score   support
#
#          Pastando     0.9531    0.9564    0.9547      2293
# Deitado-Ruminando     0.8014    0.8477    0.8239       814
#    Deitado-Parado     0.8028    0.7474    0.7741       681
#       EmPe-Parado     0.7526    0.6923    0.7212       624
#           Andando     0.9008    0.9063    0.9036       491
#    EmPe-Ruminando     0.6505    0.7267    0.6865       333
#
#          accuracy                         0.8615      5236
#         macro avg     0.8102    0.8128    0.8107      5236
#      weighted avg     0.8619    0.8615    0.8612      5236

# %% [markdown]
# ### Gráfico de métricas

# %%
plt.style.use("ggplot")
plt.figure(figsize=(15, 8))
plt.plot(np.arange(0, epochs)[5:], hist.history["loss"][5:], label="Loss (treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_loss"][5:], label="Loss (validação)")
#plt.plot(np.arange(0, epochs)[5:], hist.history["acc"][5:], label="Acurácia (treino)", alpha=1)
#plt.plot(np.arange(0, epochs)[5:], hist.history["val_acc"][5:], label="Acurácia (validação)", alpha=1)
plt.plot(np.arange(0, epochs)[5:], hist.history["f1_score"][5:], label="F1-Score (Treino)")
plt.plot(np.arange(0, epochs)[5:], hist.history["val_f1_score"][5:], label="F1-Score (Validação)")
#plt.title("TREINO - Loss, Acurácia e F1-Score")
plt.xlabel("Época", size=20)
#plt.ylabel("Loss/Acurácia/F1-Score", size=20)
plt.ylabel("Loss/F1-Score", size=20)
plt.legend(prop={"size":15})
plt.show()
